# %% [markdown]
# # Developing Models for the Most Frequently Appearing Bridges
#
# ```
# Material_Description                  Design_Description
# Steel continuous                      Stringer/Multi-beam or Girder    4771
# Concrete                              Culvert                          2676
# Concrete continuous                   Slab                             1849
# Prestressed concrete                  Box Beam Multiple                1180
# Steel                                 Culvert                           943
# Concrete                              Slab                              721
# ```

# %% [markdown]
# # Concrete Slabs

# %% [markdown]
# ## Simple Span Concrete Slab

# %% [markdown]
# Relevant Standards:
#
# [SB-1-24](https://www.dot.state.oh.us/SCDs/Structural/SB-1-24.pdf) - Simple Span Slab Bridges

# %%
simple_concrete_slab = {
  11: { 'thickness': 11.25,
        'a_bar': {'size': 7, 'spacing': 6},
        'b_bar': {'size': 5, 'spacing': 12},
        'm_bar': {'size': 5, 'spacing': 10},
        'n_bar': {'size': 5, 'spacing': 12},
        'over_side_drainage': {'d': 20.0, 'x': 45, 'd_bar_size': 7, 'd_bar_num': 8},
        'parapet': {'d': 18.0, 'x': 57, 'e_bar_size': 7, 'e_bar_num': 8}
      },
  12: { 'thickness': 11.75,
        'a_bar': {'size': 7, 'spacing': 6},
        'b_bar': {'size': 5, 'spacing': 12},
        'm_bar': {'size': 5, 'spacing': 10},
        'n_bar': {'size': 5, 'spacing': 12},
        'over_side_drainage': {'d': 20.0, 'x': 45, 'd_bar_size': 7, 'd_bar_num': 8},
        'parapet': {'d': 18.0, 'x': 57, 'e_bar_size': 7, 'e_bar_num': 8}
      },
    13: {'thickness': 12.5,
         'a_bar': {'size': 7, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 45, 'd_bar_size': 7, 'd_bar_num': 8},
         'parapet': {'d': 18.0, 'x': 57, 'e_bar_size': 7, 'e_bar_num': 8}
         },
    14: {'thickness': 13.0,
         'a_bar': {'size': 7, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 45, 'd_bar_size': 7, 'd_bar_num': 8},
         'parapet': {'d': 18.0, 'x': 57, 'e_bar_size': 7, 'e_bar_num': 8}
         },
    15: {'thickness': 13.5,
         'a_bar': {'size': 7, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 45, 'd_bar_size': 7, 'd_bar_num': 8},
         'parapet': {'d': 18.0, 'x': 57, 'e_bar_size': 7, 'e_bar_num': 8}
         },
    16: {'thickness': 14.0,
         'a_bar': {'size': 7, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 45, 'd_bar_size': 7, 'd_bar_num': 8},
         'parapet': {'d': 18.0, 'x': 57, 'e_bar_size': 8, 'e_bar_num': 7}
         },
    17: {'thickness': 14.75,
         'a_bar': {'size': 8, 'spacing': 7},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 45, 'd_bar_size': 8, 'd_bar_num': 7},
         'parapet': {'d': 18.0, 'x': 57, 'e_bar_size': 8, 'e_bar_num': 8}
         },
    18: {'thickness': 15.25,
         'a_bar': {'size': 8, 'spacing': 7},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 45, 'd_bar_size': 8, 'd_bar_num': 7},
         'parapet': {'d': 18.0, 'x': 57, 'e_bar_size': 8, 'e_bar_num': 8}
         },
    19: {'thickness': 15.75,
         'a_bar': {'size': 8, 'spacing': 7},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 48, 'd_bar_size': 8, 'd_bar_num': 8},
         'parapet': {'d': 18.0, 'x': 60, 'e_bar_size': 8, 'e_bar_num': 9}
         },
    20: {'thickness': 16.25,
         'a_bar': {'size': 8, 'spacing': 7},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 48, 'd_bar_size': 8, 'd_bar_num': 8},
         'parapet': {'d': 18.0, 'x': 60, 'e_bar_size': 8, 'e_bar_num': 10}
         },
    21: {'thickness': 16.75,
         'a_bar': {'size': 8, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 48, 'd_bar_size': 9, 'd_bar_num': 8},
         'parapet': {'d': 18.0, 'x': 60, 'e_bar_size': 8, 'e_bar_num': 10}
         },
    22: {'thickness': 17.25,
         'a_bar': {'size': 8, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 48, 'd_bar_size': 9, 'd_bar_num': 8},
         'parapet': {'d': 18.0, 'x': 60, 'e_bar_size': 9, 'e_bar_num': 9}
         },
    23: {'thickness': 17.75,
         'a_bar': {'size': 8, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 48, 'd_bar_size': 9, 'd_bar_num': 8},
         'parapet': {'d': 18.0, 'x': 60, 'e_bar_size': 9, 'e_bar_num': 10}
         },
    24: {'thickness': 18.25,
         'a_bar': {'size': 8, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 48, 'd_bar_size': 9, 'd_bar_num': 9},
         'parapet': {'d': 18.25, 'x': 60, 'e_bar_size': 9, 'e_bar_num': 10}
         },
    25: {'thickness': 18.75,
         'a_bar': {'size': 8, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 48, 'd_bar_size': 9, 'd_bar_num': 9},
         'parapet': {'d': 18.75, 'x': 60, 'e_bar_size': 9, 'e_bar_num': 10}
         },
    26: {'thickness': 19.25,
         'a_bar': {'size': 9, 'spacing': 7},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 8},
         'parapet': {'d': 19.25, 'x': 60, 'e_bar_size': 9, 'e_bar_num': 11}
         },
    27: {'thickness': 19.75,
         'a_bar': {'size': 9, 'spacing': 7},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.0, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 8},
         'parapet': {'d': 19.75, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 9}
         },
    28: {'thickness': 20.5,
         'a_bar': {'size': 9, 'spacing': 7},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 20.5, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 9},
         'parapet': {'d': 20.5, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 10}
         },
    29: {'thickness': 21.0,
         'a_bar': {'size': 9, 'spacing': 7},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 21.0, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 9},
         'parapet': {'d': 21.0, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 10}
         },
    30: {'thickness': 21.5,
         'a_bar': {'size': 9, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 21.5, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 9},
         'parapet': {'d': 21.5, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 10}
         },
    31: {'thickness': 22.25,
         'a_bar': {'size': 9, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 22.25, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 9},
         'parapet': {'d': 22.0, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 10}
         },
    32: {'thickness': 22.75,
         'a_bar': {'size': 9, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 22.75, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 9},
         'parapet': {'d': 22.75, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 10}
         },
    33: {'thickness': 23.25,
         'a_bar': {'size': 9, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 23.25, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 9},
         'parapet': {'d': 23.25, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 11}
         },
    34: {'thickness': 23.75,
         'a_bar': {'size': 9, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 23.75, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 10},
         'parapet': {'d': 23.75, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 11}
         },
    35: {'thickness': 24.25,
         'a_bar': {'size': 9, 'spacing': 6},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 24.25, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 10},
         'parapet': {'d': 24.25, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 11}
         },
    36: {'thickness': 25.0,
         'a_bar': {'size': 10, 'spacing': 7},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 25.0, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 10},
         'parapet': {'d': 25.0, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 11}
         },
    37: {'thickness': 25.5,
         'a_bar': {'size': 10, 'spacing': 7},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 25.5, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 10},
         'parapet': {'d': 25.5, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 12}
         },
    38: {'thickness': 26.0,
         'a_bar': {'size': 10, 'spacing': 7},
         'b_bar': {'size': 5, 'spacing': 12},
         'm_bar': {'size': 5, 'spacing': 10},
         'n_bar': {'size': 5, 'spacing': 12},
         'over_side_drainage': {'d': 26.0, 'x': 48, 'd_bar_size': 10, 'd_bar_num': 10},
         'parapet': {'d': 26.0, 'x': 63, 'e_bar_size': 10, 'e_bar_num': 12}
    },
}

# %% [markdown]
# ```python
# # Example cont. span for comparison,
#     14: {  # QC'd
#         'thickness': 11,
#         'a_bar': {'size': 8, 'spacing': 7, 'a': 16.583, 'length': 17.5},
#         'b_bar': {'size': 8, 'spacing': 7, 'length': 21.5},
#         'c_bar': {'size': 5, 'spacing': 7, 'length': 7.5},
#         'd_bar': {'size': 8, 'spacing': 7, 'length': 21.167},
#         'e_bar': {'size': 0, 'spacing': 0, 'length': 0.0},
#         'n_bar': {'size': 6, 'spacing': 15, 'no': 47},
#         'm_bar': {'size': 4, 'spacing': 12, 'no': 47},
#         'u_bar_lap': 78,
#
#         'over_side_drainage': {
#             'd': 20, 'x': 45,
#             'f_bar': {'size': 8, 'no': 7, 'f': 16.583, 'length': 17.5},
#             'g_bar': {'size': 8, 'no': 7, 'length': 21.5},
#             'h_bar': {'size': 5, 'no': 7, 'length': 7.5},
#             'j_bar': {'size': 8, 'no': 7, 'length': 21.167},
#             'k_bar': {'size': 0, 'no': 0, 'length': 0}
#         },
#
#         'parapet': {
#             'd': 18, 'x': 60,
#             'f_bar': {'size': 8, 'no': 9, 'f': 16.583, 'length': 17.5},
#             'g_bar': {'size': 8, 'no': 9, 'length': 21.5},
#             'h_bar': {'size': 5, 'no': 9, 'length': 7.5},
#             'j_bar': {'size': 8, 'no': 7, 'length': 21.167},
#             'k_bar': {'size': 0, 'no': 0, 'length': 0}
#         }
#     },

# %%
def get_deck_parameters(span_length: int, continuous_span: bool = False, over_side_drainage: bool = True) -> dict:
    """
    Retrieve bridge deck parameters based on span length and bridge type.
    """
    all_slab_data = continuous_concrete_slab if continuous_span else simple_concrete_slab
    params = all_slab_data[span_length]
    thickness = params['thickness']

    # compatibility flag (not returned)
    U401 = thickness > 20

    top_cover = 2.5
    bot_cover = 1.5
    side_cover = 3

    edge_type = 'over_side_drainage' if over_side_drainage else 'parapet'
    edge_params = params[edge_type]

    result = {
        'span_length': span_length,
        'span_type': 'continuous' if continuous_span else 'simple',
        'thickness': thickness,
        'top_cover': top_cover,
        'bot_cover': bot_cover,
        'side_cover': side_cover,
        'edge_type': edge_type,
    }

    if not continuous_span:
        # Simple: return nested bar dicts directly
        for bar_key in ['a_bar', 'b_bar', 'm_bar', 'n_bar']:
            if bar_key in params:
                result[bar_key] = {
                    'size': params[bar_key]['size'],
                    'spacing': params[bar_key]['spacing'],
                }

        # Edge details (keep D/E metadata as requested)
        result['edge_beam'] = {
            'd': edge_params['d'],
            'x': edge_params['x'],
            'd_bar': {
                'size': edge_params.get('d_bar_size', 0) if over_side_drainage else 0,
                'spacing': edge_params.get('d_bar_num', 0) if over_side_drainage else 0,
            },
            'e_bar': {
                'size': 0 if over_side_drainage else edge_params.get('e_bar_size', 0),
                'spacing': 0 if over_side_drainage else edge_params.get('e_bar_num', 0),
            }
        }
    else:
        # Continuous: mirror the same nested style
        for bar_key in ['a_bar', 'b_bar', 'm_bar', 'n_bar']:
            if bar_key in params:
                # base fields
                bar_obj = {
                    'size': params[bar_key]['size'],
                    'spacing': params[bar_key]['spacing'],
                }
                # optional extras
                if 'a' in params[bar_key]:
                    bar_obj['a'] = params[bar_key]['a']
                if 'length' in params[bar_key]:
                    bar_obj['length'] = params[bar_key]['length']
                if 'no' in params[bar_key]:
                    bar_obj['no'] = params[bar_key]['no']
                result[bar_key] = bar_obj

        # Optional C/D/E bars (include only if present)
        for bar_key in ['c_bar', 'd_bar', 'e_bar']:
            if bar_key in params:
                result[bar_key] = {
                    'size': params[bar_key]['size'],
                    'spacing': params[bar_key]['spacing'],
                    'length': params[bar_key]['length'],
                }

        if 'u_bar_lap' in params:
            result['u_bar_lap'] = params['u_bar_lap']

        # Edge details grouped as in simple, but with F/G/H/J/K nested
        edge_beam = {
            'd': edge_params['d'],
            'x': edge_params['x'],
        }
        for bar_key in ['f_bar', 'g_bar', 'h_bar', 'j_bar', 'k_bar']:
            if bar_key in edge_params:
                bar = edge_params[bar_key]
                eb_entry = {
                    'size': bar['size'],
                    'no': bar.get('no', 0),
                    'length': bar.get('length', 0),
                }
                if bar_key == 'f_bar' and 'f' in bar:
                    eb_entry['f'] = bar['f']
                edge_beam[bar_key] = eb_entry
        result['edge_beam'] = edge_beam

    return result

# %%
values = get_deck_parameters(17, True, False)

# %%
def print_parameters(params: dict) -> None:
    """Pretty print the retrieved parameters."""
    print(f"\n{'='*60}")
    print(f"Bridge Deck Parameters - {params['span_type'].upper()} SPAN")
    print(f"Edge Type: {params['edge_type'].replace('_', ' ').title()}")
    print(f"{'='*60}")
    print(f"Span Length:               {params['span_length']} ft")
    print(f"Deck Thickness:            {params['thickness']} in")
    print(f"Concrete Cover (top/bot/side):  {params['top_cover']} / {params.get('bot_cover', '')} / {params.get('side_cover', '')} in")

    # Determine if bars are nested (simple and new continuous) or flattened (legacy continuous)
    a_bar = params.get('a_bar')
    b_bar = params.get('b_bar')
    m_bar = params.get('m_bar')
    n_bar = params.get('n_bar')

    print(f"\n{'Main Rebar Configuration:':<40}")
    if isinstance(a_bar, dict) and isinstance(b_bar, dict) and isinstance(m_bar, dict) and isinstance(n_bar, dict):
        # Nested structure
        print(f"  Transverse (A) Bar:    #{a_bar['size']} @ {a_bar['spacing']}\" o.c.")
        print(f"  Transverse (B) Bar:    #{b_bar['size']} @ {b_bar['spacing']}\" o.c.")
        print(f"  Longitudinal (M) Bar:  #{m_bar['size']} @ {m_bar['spacing']}\" o.c.")
        print(f"  Longitudinal (N) Bar:  #{n_bar['size']} @ {n_bar['spacing']}\" o.c.")
    else:
        # Backward compatibility with flattened keys
        print(f"  Transverse (A) Bar:    #{params['a_bar_size']} @ {params['a_bar_spacing']}\" o.c.")
        print(f"  Transverse (B) Bar:    #{params['b_bar_size']} @ {params['b_bar_spacing']}\" o.c.")
        print(f"  Longitudinal (M) Bar:  #{params['m_bar_size']} @ {params['m_bar_spacing']}\" o.c.")
        print(f"  Longitudinal (N) Bar:  #{params['n_bar_size']} @ {params['n_bar_spacing']}\" o.c.")
    print(f"{'='*60}\n")

# %%
print_parameters(values)
# Out:
# ...
# Bridge Deck Parameters - CONTINUOUS SPAN
# Edge Type: Parapet
# ...
# Span Length:               17 ft
# Deck Thickness:            12.5 in
# Concrete Cover (top/bot/side):  2.5 / 1.5 / 3 in
#
# Main Rebar Configuration:
#   Transverse (A) Bar:    #8 @ 7" o.c.
#   Transverse (B) Bar:    #8 @ 7" o.c.
#   Longitudinal (M) Bar:  #4 @ 12" o.c.
#   Longitudinal (N) Bar:  #6 @ 15" o.c.
# ...

# %%
def get_aci_bend_radius(bar_size: int) -> float:
    """
    Get the ACI 318 minimum bend diameter *to the centerline of the bar*.
    (ACI specifies *inside* bend radius, so we add 0.5 * bar_diameter)

    Args:
        bar_size: Bar size number (e.g., 8 for #8)

    Returns:
        Centerline bend radius in inches
    """
    bar_diameter = bar_size / 8.0
    inside_bend_diameter = 0.0

    if bar_size >= 3 and bar_size <= 8:
        # ACI 318-14 Table 25.3.2: 6 * db
        inside_bend_diameter = 3 * bar_diameter
    elif bar_size >= 9 and bar_size <= 11:
        # ACI 318-14 Table 25.3.2: 8 * db
        inside_bend_diameter = 8 * bar_diameter
    elif bar_size >= 14 and bar_size <= 18:
        # ACI 318-14 Table 25.3.2: 10 * db
        inside_bend_diameter = 10 * bar_diameter
    else:
        # Default for #2 or other small bars
        inside_bend_diameter = 6 * bar_diameter

    # Return centerline radius
    centerline_bend_diameter = inside_bend_diameter + 0.5 * bar_diameter
    return centerline_bend_diameter

# %%
def generate_a_bars(span_length,
                    a_bar_size=None,
                    a_bar_spacing=None,
                    deck_thickness=None,
                    deck_width=24.0,
                    bot_cover=1.5,
                    top_cover=2.0,
                    side_cover=3.0,
                    b_bar_size=None): # Added to check clearance
    """
    Generate A-bar geometry (bottom, with hooks).
    PLOTLY (TROUBLESHOOTING) VERSION.
    """
    if a_bar_size is None or a_bar_spacing is None:
        raise ValueError("a_bar_size and a_bar_spacing are required.")
    if deck_thickness is None or top_cover is None or b_bar_size is None:
        raise ValueError("deck_thickness, top_cover, and b_bar_size are required for A-Bar hook clearance.")

    # --- 1. Calculate Hook Geometry ---
    bar_diameter = a_bar_size / 8.0

    # --- START HOOK CLAMPING LOGIC ---
    r_aci = get_aci_bend_radius(a_bar_size)
    b_bar_diameter = b_bar_size / 8.0
    max_z_clearance = deck_thickness - top_cover - b_bar_diameter
    z_bot = bot_cover + bar_diameter / 2.0
    available_hook_height = max_z_clearance - z_bot
    r_max = available_hook_height / 2.0

    if r_aci > r_max:
        print(f"--- WARNING (A-Bar): ACI radius ({r_aci:.3f}\") is too large.")
        print(f"                     Clamping hook radius to max allowed: {r_max:.3f}\"")
        r = r_max
    else:
        print(f"--- INFO (A-Bar): Using ACI hook radius: {r_aci:.3f}\"")
        r = r_aci
    # --- END HOOK CLAMPING LOGIC ---

    ext = max(4 * bar_diameter, 2.5) # Hook extension length
    plot_line_width = bar_diameter * 8.0

    # --- 2. Calculate Bar Positions ---
    span_length_in = span_length * 12.0
    deck_width_in = deck_width * 12.0
    num_bars = int(deck_width_in / a_bar_spacing) + 1

    z_top_of_hook = z_bot + 2 * r # Z-coord of top of 180-deg hook

    # --- 3. Build Plotly Coordinates ---
    x_coords, y_coords, z_coords = [], [], []

    arc_segments = 16 # More segments for smoother arcs

    for i in range(num_bars):
        y = side_cover + (bar_diameter / 2) + i * a_bar_spacing

        # NOTE: Using simplified bar end logic from your version
        L = span_length_in + 10
        bar_end_L_x = 2
        bar_end_R_x = L - 4

        cen_z = z_bot + r # Z-center of the hook arcs

        # --- LEFT HOOK ---
        # L1: Left Extension
        x_coords.extend([bar_end_L_x + r + ext, bar_end_L_x + r])
        y_coords.extend([y, y])
        z_coords.extend([z_top_of_hook, z_top_of_hook])

        # L2: Left Top Arc (90-deg)
        for j in range(arc_segments + 1):
            t = j / arc_segments
            angle = (math.pi / 2) + t * (math.pi / 2) # 90 to 180 deg
            x_coords.append(bar_end_L_x + r * math.cos(angle))
            y_coords.append(y)
            z_coords.append(cen_z + r * math.sin(angle))

        # L3: Left Bottom Arc (90-deg)
        for j in range(arc_segments + 1):
            t = j / arc_segments
            angle = math.pi + t * (math.pi / 2) # 180 to 270 deg
            x_coords.append(bar_end_L_x + r * math.cos(angle))
            y_coords.append(y)
            z_coords.append(cen_z + r * math.sin(angle))

        # --- MAIN STRAIGHT "A" BAR ---
        x_coords.extend([bar_end_L_x, bar_end_R_x])
        y_coords.extend([y, y])
        z_coords.extend([z_bot, z_bot])

        # --- RIGHT HOOK ---
        # R1: Right Bottom Arc (90-deg)
        for j in range(arc_segments + 1):
            t = j / arc_segments
            angle = (3 * math.pi / 2) + t * (math.pi / 2) # 270 to 360 deg
            x_coords.append(bar_end_R_x + r * math.cos(angle))
            y_coords.append(y)
            z_coords.append(cen_z + r * math.sin(angle))

        # R2: Right Top Arc (90-deg)
        for j in range(arc_segments + 1):
            t = j / arc_segments
            angle = 0 + t * (math.pi / 2) # 0 to 90 deg
            x_coords.append(bar_end_R_x + r * math.cos(angle))
            y_coords.append(y)
            z_coords.append(cen_z + r * math.sin(angle))

        # R3: Right Extension
        x_coords.extend([bar_end_R_x - r, bar_end_R_x - ext - r])
        y_coords.extend([y, y])
        z_coords.extend([z_top_of_hook, z_top_of_hook])

        # Break for next bar
        x_coords.append(None); y_coords.append(None); z_coords.append(None)

    # --- 4. Create the Figure ---
    fig = go.Figure()
    fig.add_trace(go.Scatter3d(
        x=x_coords, y=y_coords, z=z_coords, mode='lines',
        name=f'A-Bars (#{a_bar_size})',
        line=dict(color='blue', width=plot_line_width)
    ))
    fig.update_layout(title=f'A-Bar Layout ({num_bars} bars)')
    return fig

# %%
def generate_b_bars(span_length,
                    b_bar_size=None,
                    b_bar_spacing=None,
                    deck_thickness=None, # NOW REQUIRED
                    deck_width=24.0,
                    top_cover=2.0,
                    side_cover=3.0):
    """
    Generate B-bar geometry (top, straight, transverse X-dir).
    PLOTLY (TROUBLESHOOTING) VERSION.
    """
    if b_bar_size is None or b_bar_spacing is None:
        raise ValueError("b_bar_size and b_bar_spacing are required.")
    if deck_thickness is None:
        raise ValueError("deck_thickness is required to calculate B-bar elevation.")

    # --- 1. Calculate Bar Geometry ---
    bar_diameter = b_bar_size / 8.0
    plot_line_width = bar_diameter * 8.0

    # --- 2. Calculate Bar Positions ---
    span_length_in = span_length * 12.0
    deck_width_in = deck_width * 12.0
    num_bars = int(deck_width_in / b_bar_spacing) + 1

    # Z-coord of the *center* of the top B-bar
    z_pos = deck_thickness - top_cover - (bar_diameter / 2.0)

    # --- 3. Build Plotly Coordinates ---
    x_coords, y_coords, z_coords = [], [], []

    for i in range(num_bars):
        y = side_cover + (bar_diameter / 2) + i * b_bar_spacing
        L = span_length_in + 10
        bar_end_L_x = 2
        bar_end_R_x = L - 4

        # --- MAIN STRAIGHT "B" BAR ---
        x_coords.extend([bar_end_L_x, bar_end_R_x])
        y_coords.extend([y, y])
        z_coords.extend([z_pos, z_pos]) # Use the new z_pos

        x_coords.append(None); y_coords.append(None); z_coords.append(None)

    # --- 4. Create the Figure ---
    fig = go.Figure()
    fig.add_trace(go.Scatter3d(
        x=x_coords, y=y_coords, z=z_coords, mode='lines',
        name=f'B-Bars (#{b_bar_size})',
        line=dict(color='red', width=plot_line_width)
    ))
    fig.update_layout(title=f'B-Bar Layout ({num_bars} bars)')
    return fig

# %%
def generate_m_bars(span_length,
                    m_bar_size=None,
                    m_bar_spacing=None,
                    deck_width=24.0,
                    bot_cover=1.5,
                    side_cover=3.0,
                    a_bar_size=None):
    """
    Generate M-bar geometry (bottom, straight, longitudinal Y-dir).
    PLOTLY (TROUBLESHOOTING) VERSION.
    """
    if m_bar_size is None or m_bar_spacing is None:
        raise ValueError("m_bar_size and m_bar_spacing are required.")
    if a_bar_size is None:
        raise ValueError("a_bar_size is required to calculate M-bar elevation.")

    # --- 1. Calculate Bar Geometry ---
    bar_diameter = m_bar_size / 8.0
    a_bar_diameter = a_bar_size / 8.0
    plot_line_width = bar_diameter * 8.0

    # --- 2. Calculate Bar Positions ---
    span_length_in = span_length * 12.0
    deck_width_in = deck_width * 12.0

    # Z-coord: Center of M-bar is just above top of A-bar
    z_pos = bot_cover + a_bar_diameter + (bar_diameter / 2.0)

    # Use X-direction end/side cover logic from A/B bars
    L_span = span_length_in + 10
    bar_end_L_x = 2
    bar_end_R_x = L_span - 4

    # Use Y-direction side cover
    y_start = side_cover
    y_end = deck_width_in - side_cover

    # Bars are spaced along the X-axis
    num_bars = int((bar_end_R_x - bar_end_L_x) / m_bar_spacing) + 1

    # --- 3. Build Plotly Coordinates ---
    x_coords, y_coords, z_coords = [], [], []

    for i in range(num_bars):
        # Each bar is at a constant X, spaced by m_bar_spacing
        x = bar_end_L_x + i * m_bar_spacing

        # --- MAIN STRAIGHT "M" BAR (Y-direction) ---
        x_coords.extend([x, x]) # X is constant
        y_coords.extend([y_start, y_end]) # Y changes
        z_coords.extend([z_pos, z_pos]) # Z is constant

        x_coords.append(None); y_coords.append(None); z_coords.append(None)

    # --- 4. Create the Figure ---
    fig = go.Figure()
    fig.add_trace(go.Scatter3d(
        x=x_coords, y=y_coords, z=z_coords, mode='lines',
        name=f'M-Bars (#{m_bar_size})',
        line=dict(color='green', width=plot_line_width)
    ))
    fig.update_layout(title=f'M-Bar Layout ({num_bars} bars)')
    return fig


def generate_n_bars(span_length,
                    n_bar_size=None,
                    n_bar_spacing=None,
                    deck_thickness=None,
                    deck_width=24.0,
                    top_cover=2.0,
                    side_cover=3.0,
                    b_bar_size=None):
    """
    Generate N-bar geometry (top, straight, longitudinal Y-dir).
    PLOTLY (TROUBLESHOOTING) VERSION.
    """
    if n_bar_size is None or n_bar_spacing is None:
        raise ValueError("n_bar_size and n_bar_spacing are required.")
    if deck_thickness is None or b_bar_size is None:
        raise ValueError("deck_thickness and b_bar_size are required to calculate N-bar elevation.")

    # --- 1. Calculate Bar Geometry ---
    bar_diameter = n_bar_size / 8.0
    b_bar_diameter = b_bar_size / 8.0
    plot_line_width = bar_diameter * 8.0

    # --- 2. Calculate Bar Positions ---
    span_length_in = span_length * 12.0
    deck_width_in = deck_width * 12.0

    # Z-coord: Center of N-bar is just below bottom of B-bar
    z_b_bar_bottom = (deck_thickness - top_cover) - b_bar_diameter
    z_pos = z_b_bar_bottom - (bar_diameter / 2.0)

    # Use X-direction end/side cover logic from A/B bars
    L_span = span_length_in + 10
    bar_end_L_x = 2
    bar_end_R_x = L_span - 4

    # Use Y-direction side cover
    y_start = side_cover
    y_end = deck_width_in - side_cover

    # Bars are spaced along the X-axis
    num_bars = int((bar_end_R_x - bar_end_L_x) / n_bar_spacing) + 1

    # --- 3. Build Plotly Coordinates ---
    x_coords, y_coords, z_coords = [], [], []

    for i in range(num_bars):
        # Each bar is at a constant X, spaced by n_bar_spacing
        x = bar_end_L_x + i * n_bar_spacing

        # --- MAIN STRAIGHT "N" BAR (Y-direction) ---
        x_coords.extend([x, x]) # X is constant
        y_coords.extend([y_start, y_end]) # Y changes
        z_coords.extend([z_pos, z_pos]) # Z is constant

        x_coords.append(None); y_coords.append(None); z_coords.append(None)

    # --- 4. Create the Figure ---
    fig = go.Figure()
    fig.add_trace(go.Scatter3d(
        x=x_coords, y=y_coords, z=z_coords, mode='lines',
        name=f'N-Bars (#{n_bar_size})',
        line=dict(color='purple', width=plot_line_width)
    ))
    fig.update_layout(title=f'N-Bar Layout ({num_bars} bars)')
    return fig

# %%
import sys
import math
import json
import plotly.graph_objects as go

# %%
# ======================================================================
# --- MAIN EXECUTION BLOCK (FOR PLOTTING/TESTING) ---
# ======================================================================
if __name__ == '__main__':

    # --- Set Test Parameters ---
    span_length = 20
    # Set to False for simple span (per user request)
    continuous_span = False
    over_side_drainage = False
    deck_width = 24.0 # feet

    try:
        # 1. Get all parameters from the lookup function
        print(f"Looking up parameters for {span_length} ft {'continuous' if continuous_span else 'simple'} span...")
        params = get_deck_parameters(span_length, continuous_span, over_side_drainage)
        print_parameters(params) # Show what we found

        # 2. Extract values needed for bar generation
        thickness = params['thickness']
        top_cover = params['top_cover']
        bot_cover = params['bot_cover']
        side_cover = params['side_cover']

        # Get Bar info from the nested dictionaries
        a_bar_info = params.get('a_bar', {})
        b_bar_info = params.get('b_bar', {})
        m_bar_info = params.get('m_bar', {})
        n_bar_info = params.get('n_bar', {})

        a_size = a_bar_info.get('size')
        a_spacing = a_bar_info.get('spacing')

        b_size = b_bar_info.get('size')
        b_spacing = b_bar_info.get('spacing')

        m_size = m_bar_info.get('size')
        m_spacing = m_bar_info.get('spacing')

        n_size = n_bar_info.get('size')
        n_spacing = n_bar_info.get('spacing')

        # 3. Create the final figure
        fig_final = go.Figure()
        print("Generating plots...")

        # 4. Generate and Add A-Bars
        if a_size and a_spacing:
            if not b_size: raise ValueError("B-Bar size is needed to calculate A-Bar hook clearance.")
            print(f"-> Plotting A-Bars (#{a_size} @ {a_spacing}\") at Z ~ {bot_cover:.2f}\"")
            fig_a = generate_a_bars(
                span_length=span_length, a_bar_size=a_size, a_bar_spacing=a_spacing,
                deck_thickness=thickness, deck_width=deck_width, bot_cover=bot_cover,
                top_cover=top_cover, side_cover=side_cover, b_bar_size=b_size
            )
            fig_final.add_trace(fig_a.data[0])
        else:
            print("-> A-Bar data not found. Skipping A-Bar plot.")

        # 5. Generate and Add B-Bars
        if b_size and b_spacing:
            z_b_bar = thickness - top_cover - (b_size / 8.0 / 2.0)
            print(f"-> Plotting B-Bars (#{b_size} @ {b_spacing}\") at Z = {z_b_bar:.4f}\"")
            fig_b = generate_b_bars(
                span_length=span_length, b_bar_size=b_size, b_bar_spacing=b_spacing,
                deck_thickness=thickness, deck_width=deck_width, top_cover=top_cover,
                side_cover=side_cover
            )
            fig_final.add_trace(fig_b.data[0])
        else:
            print("-> B-Bar data not found. Skipping B-Bar plot.")

        # 6. Generate and Add M-Bars
        if m_size and m_spacing:
            if not a_size: raise ValueError("A-Bar size is needed to calculate M-Bar elevation.")
            z_m_bar = bot_cover + (a_size / 8.0) + (m_size / 8.0 / 2.0)
            print(f"-> Plotting M-Bars (#{m_size} @ {m_spacing}\") at Z = {z_m_bar:.4f}\"")
            fig_m = generate_m_bars(
                span_length=span_length, m_bar_size=m_size, m_bar_spacing=m_spacing,
                deck_width=deck_width, bot_cover=bot_cover, side_cover=side_cover,
                a_bar_size=a_size
            )
            fig_final.add_trace(fig_m.data[0])
        else:
            print("-> M-Bar data not found. Skipping M-Bar plot.")

        # 7. Generate and Add N-Bars
        if n_size and n_spacing:
            if not b_size: raise ValueError("B-Bar size is needed to calculate N-Bar elevation.")
            z_n_bar_bot = (thickness - top_cover) - (b_size / 8.0)
            z_n_bar = z_n_bar_bot - (n_size / 8.0 / 2.0)
            print(f"-> Plotting N-Bars (#{n_size} @ {n_spacing}\") at Z = {z_n_bar:.4f}\"")
            fig_n = generate_n_bars(
                span_length=span_length, n_bar_size=n_size, n_bar_spacing=n_spacing,
                deck_thickness=thickness, deck_width=deck_width, top_cover=top_cover,
                side_cover=side_cover, b_bar_size=b_size
            )
            fig_final.add_trace(fig_n.data[0])
        else:
            print("-> N-Bar data not found. Skipping N-Bar plot.")

        # 8. Style and Show the Combined Plot
        fig_final.update_layout(
            title=f'Rebar Layout: {span_length} ft Span (Plotly)',
            scene=dict(
                xaxis_title='X (Transverse, in)',
                yaxis_title='Y (Longitudinal, in)',
                zaxis_title='Z (Elevation, in)',
                aspectmode='data' # This is critical!
            ),
            margin=dict(l=0, r=0, b=0, t=40)
        )

        print("\nShowing combined plot...")
        fig_final.show()

    except ValueError as e:
        print(f"\n--- ERROR ---: {e}", file=sys.stderr)
    except Exception as e:
        print(f"\n--- UNEXPECTED ERROR ---: {e}", file=sys.stderr)
        import traceback
        print(traceback.format_exc())
# Out:
# Looking up parameters for 20 ft simple span...
#
# ...
# Bridge Deck Parameters - SIMPLE SPAN
# Edge Type: Parapet
# ...
# Span Length:               20 ft
# Deck Thickness:            16.25 in
# Concrete Cover (top/bot/side):  2.5 / 1.5 / 3 in
#
# Main Rebar Configuration:
#   Transverse (A) Bar:    #8 @ 7" o.c.
#   Transverse (B) Bar:    #5 @ 12" o.c.
#   Longitudinal (M) Bar:  #5 @ 10" o.c.
#   Longitudinal (N) Bar:  #5 @ 12" o.c.
# ...
#
# Generating plots...
# -> Plotting A-Bars (#8 @ 7") at Z ~ 1.50"
# --- INFO (A-Bar): Using ACI hook radius: 3.500"
# -> Plotting B-Bars (#5 @ 12") at Z = 13.4375"
# -> Plotting M-Bars (#5 @ 10") at Z = 2.8125"
# -> Plotting N-Bars (#5 @ 12") at Z = 12.8125"
#
# Showing combined plot...

# %% [markdown]
# ## Continous Span Concrete Slabs
#
# [CS-1-24](https://www.dot.state.oh.us/SCDs/Structural/CS-1-24.pdf) - Continuous Slab Bridges

# %%
continuous_concrete_slab = {
    14: {  # QC'd
        'thickness': 11,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 16.583, 'length': 17.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 21.5},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 7.5},
        'd_bar': {'size': 8, 'spacing': 7, 'length': 21.167},
        'e_bar': {'size': 0, 'spacing': 0, 'length': 0.0},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 47},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 47},
        'u_bar_lap': 78,

        'over_side_drainage': {
            'd': 20, 'x': 45,
            'f_bar': {'size': 8, 'no': 7, 'f': 16.583, 'length': 17.5},
            'g_bar': {'size': 8, 'no': 7, 'length': 21.5},
            'h_bar': {'size': 5, 'no': 7, 'length': 7.5},
            'j_bar': {'size': 8, 'no': 7, 'length': 21.167},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        },

        'parapet': {
            'd': 18, 'x': 60,
            'f_bar': {'size': 8, 'no': 9, 'f': 16.583, 'length': 17.5},
            'g_bar': {'size': 8, 'no': 9, 'length': 21.5},
            'h_bar': {'size': 5, 'no': 9, 'length': 7.5},
            'j_bar': {'size': 8, 'no': 7, 'length': 21.167},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        }
    },
    15: {  # QC'd
        'thickness': 11.5,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 17.583, 'length': 18.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 22.75},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 7.833},
        'd_bar': {'size': 8, 'spacing': 7, 'length': 22.5},
        'e_bar': {'size': 0, 'spacing': 0, 'length': 0.0},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 49},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 50},
        'u_bar_lap': 82,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 7, 'f': 17.58, 'length': 18.5},
            'g_bar': {'size': 8, 'no': 7, 'length': 22.75},
            'h_bar': {'size': 5, 'no': 7, 'length': 7.83},
            'j_bar': {'size': 8, 'no': 7, 'length': 22.5},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        },

        'parapet': {
            'd': 18, 'x': 60,
            'f_bar': {'size': 8, 'no': 9, 'f': 17.583, 'length': 18.5},
            'g_bar': {'size': 8, 'no': 9, 'length': 22.75},
            'h_bar': {'size': 5, 'no': 9, 'length': 7.83},
            'j_bar': {'size': 8, 'no': 9, 'length': 22.5},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        }
    },
    16: {  # QC'd
        'thickness': 12,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 18.58, 'length': 19.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 24.0},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 8.25},
        'd_bar': {'size': 8, 'spacing': 7, 'length': 23.67},
        'e_bar': {'size': 0, 'spacing': 0, 'length': 0},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 52},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 53},
        'u_bar_lap': 88,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 7, 'f': 18.58, 'length': 19.5},
            'g_bar': {'size': 8, 'no': 7, 'length': 24.0},
            'h_bar': {'size': 5, 'no': 7, 'length': 8.25},
            'j_bar': {'size': 8, 'no': 7, 'length': 23.67},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        },

        'parapet': {
            'd': 18, 'x': 60,
            'f_bar': {'size': 8, 'no': 9, 'f': 18.58, 'length': 19.5},
            'g_bar': {'size': 8, 'no': 9, 'length': 24.0},
            'h_bar': {'size': 5, 'no': 9, 'length': 8.25},
            'j_bar': {'size': 8, 'no': 9, 'length': 23.67},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        }
    },
    17: {  # QC'd
        'thickness': 12.5,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 19.58, 'length': 20.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 25.25},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 8.583},
        'd_bar': {'size': 8, 'spacing': 7, 'length': 25.0},
        'e_bar': {'size': 0, 'spacing': 0, 'length': 0.0},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 54},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 56},
        'u_bar_lap': 92,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 8, 'f': 19.58, 'length': 20.5},
            'g_bar': {'size': 8, 'no': 8, 'length': 25.25},
            'h_bar': {'size': 5, 'no': 8, 'length': 8.583},
            'j_bar': {'size': 8, 'no': 8, 'length': 25.0},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        },

        'parapet': {
            'd': 18, 'x': 60,
            'f_bar': {'size': 8, 'no': 9, 'f': 19.58, 'length': 20.5},
            'g_bar': {'size': 8, 'no': 9, 'length': 25.25},
            'h_bar': {'size': 5, 'no': 9, 'length': 8.583},
            'j_bar': {'size': 8, 'no': 9, 'length': 25.0},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        }
    },
    18: {  # QC'd
        'thickness': 13,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 20.58, 'length': 21.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 26.5},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 9},
        'd_bar': {'size': 8, 'spacing': 7, 'length': 26.167},
        'e_bar': {'size': 0, 'spacing': 0, 'length': 0.0},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 57},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 60},
        'u_bar_lap': 98,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 8, 'f': 20.58, 'length': 21.5},
            'g_bar': {'size': 8, 'no': 8, 'length': 26.5},
            'h_bar': {'size': 5, 'no': 8, 'length': 9},
            'j_bar': {'size': 8, 'no': 8, 'length': 26.167},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        },

        'parapet': {
            'd': 18, 'x': 60,
            'f_bar': {'size': 8, 'no': 9, 'f': 20.58, 'length': 21.5},
            'g_bar': {'size': 8, 'no': 9, 'length': 26.5},
            'h_bar': {'size': 5, 'no': 9, 'length': 9},
            'j_bar': {'size': 9, 'no': 9, 'length': 26.167},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        }
    },
    19: {  # QC'd
        'thickness': 13.5,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 21.58, 'length': 22.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 27.75},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 9.333},
        'd_bar': {'size': 8, 'spacing': 7, 'length': 27.5},
        'e_bar': {'size': 0, 'spacing': 0, 'length': 0.0},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 60},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 63},
        'u_bar_lap': 104,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 8, 'f': 21.58, 'length': 22.5},
            'g_bar': {'size': 8, 'no': 8, 'length': 27.75},
            'h_bar': {'size': 5, 'no': 8, 'length': 9.333},
            'j_bar': {'size': 8, 'no': 8, 'length': 27.5},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        },

        'parapet': {
            'd': 18, 'x': 60,
            'f_bar': {'size': 8, 'no': 9, 'f': 21.58, 'length': 22.5},
            'g_bar': {'size': 8, 'no': 9, 'length': 27.75},
            'h_bar': {'size': 5, 'no': 9, 'length': 9.333},
            'j_bar': {'size': 9, 'no': 9, 'length': 27.5},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        }
    },
    20: {  # QC'd
        'thickness': 14,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 22.58, 'length': 23.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 29.0},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 9.75},
        'd_bar': {'size': 8, 'spacing': 7, 'length': 28.67},
        'e_bar': {'size': 0, 'spacing': 0, 'length': 0.0},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 62},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 66},
        'u_bar_lap': 108,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 8, 'f': 22.58, 'length': 23.5},
            'g_bar': {'size': 8, 'no': 8, 'length': 29.0},
            'h_bar': {'size': 5, 'no': 8, 'length': 9.75},
            'j_bar': {'size': 8, 'no': 8, 'length': 28.667},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        },

        'parapet': {
            'd': 18, 'x': 60,
            'f_bar': {'size': 8, 'no': 9, 'f': 22.58, 'length': 23.5},
            'g_bar': {'size': 8, 'no': 9, 'length': 29.0},
            'h_bar': {'size': 5, 'no': 9, 'length': 9.75},
            'j_bar': {'size': 8, 'no': 9, 'length': 28.67},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        }
    },
    21: {  # QC'd
        'thickness': 14.5,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 23.58, 'length': 24.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 30.25},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 10.08},
        'd_bar': {'size': 8, 'spacing': 7, 'length': 30.0},
        'e_bar': {'size': 0, 'spacing': 0, 'length': 0.0},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 65},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 69},
        'u_bar_lap': 114,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 8, 'f': 23.58, 'length': 24.5},
            'g_bar': {'size': 8, 'no': 8, 'length': 30.25},
            'h_bar': {'size': 5, 'no': 8, 'length': 10.08},
            'j_bar': {'size': 8, 'no': 8, 'length': 30.0},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        },

        'parapet': {
            'd': 18, 'x': 63,
            'f_bar': {'size': 8, 'no': 10, 'f': 23.58, 'length': 24.5},
            'g_bar': {'size': 8, 'no': 10, 'length': 30.25},
            'h_bar': {'size': 5, 'no': 10, 'length': 10.08},
            'j_bar': {'size': 8, 'no': 10, 'length': 30.0},
            'k_bar': {'size': 0, 'no': 0, 'length': 0}
        }
    },
    22: {  # QC'd
        'thickness': 15,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 24.58, 'length': 25.6},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 31.5},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 13.67},
        'd_bar': {'size': 8, 'spacing': 7, 'length': 24.83},
        'e_bar': {'size': 6, 'spacing': 7, 'length': 9.92},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 67},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 73},
        'u_bar_lap': 118,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 8, 'f': 24.58, 'length': 25.5},
            'g_bar': {'size': 8, 'no': 8, 'length': 31.5},
            'h_bar': {'size': 5, 'no': 8, 'length': 13.66},
            'j_bar': {'size': 8, 'no': 8, 'length': 24.83},
            'k_bar': {'size': 5, 'no': 8, 'length': 9.92}
        },
        'parapet': {
            'd': 18, 'x': 63,
            'f_bar': {'size': 8, 'no': 10, 'f': 24.58, 'length': 25.5},
            'g_bar': {'size': 8, 'no': 10, 'length': 31.5},
            'h_bar': {'size': 5, 'no': 10, 'length': 13.67},
            'j_bar': {'size': 8, 'no': 10, 'length': 24.83},
            'k_bar': {'size': 5, 'no': 10, 'length': 9.92}
        }
    },
    23: {  # QC'd
        'thickness': 15.5,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 25.58, 'length': 26.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 32.75},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 14.25},
        'd_bar': {'size': 8, 'spacing': 7, 'length': 25.67},
        'e_bar': {'size': 5, 'spacing': 7, 'length': 10.33},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 70},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 76},
        'u_bar_lap': 124,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 8, 'f': 25.58, 'length': 26.5},
            'g_bar': {'size': 8, 'no': 8, 'length': 32.75},
            'h_bar': {'size': 5, 'no': 8, 'length': 14.25},
            'j_bar': {'size': 8, 'no': 8, 'length': 25.67},
            'k_bar': {'size': 5, 'no': 8, 'length': 10.33}
        },

        'parapet': {
            'd': 18, 'x': 63,
            'f_bar': {'size': 8, 'no': 10, 'f': 25.58, 'length': 26.5},
            'g_bar': {'size': 8, 'no': 10, 'length': 32.75},
            'h_bar': {'size': 5, 'no': 10, 'length': 14.25},
            'j_bar': {'size': 8, 'no': 10, 'length': 25.67},
            'k_bar': {'size': 5, 'no': 10, 'length': 10.33}
        }
    },
    24: {  # QC'd
        'thickness': 16,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 26.58, 'length': 27.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 34.0},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 14.83},
        'd_bar': {'size': 8, 'spacing': 6, 'length': 26.58},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 10.83},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 70},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 79},
        'u_bar_lap': 130,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 9, 'f': 26.58, 'length': 27.5},
            'g_bar': {'size': 8, 'no': 9, 'length': 34.0},
            'h_bar': {'size': 5, 'no': 9, 'length': 14.83},
            'j_bar': {'size': 8, 'no': 9, 'length': 26.58},
            'k_bar': {'size': 5, 'no': 9, 'length': 10.83}
        },

        'parapet': {
            'd': 18, 'x': 63,
            'f_bar': {'size': 10, 'no': 10, 'f': 26.58, 'length': 27.5},
            'g_bar': {'size': 8, 'no': 10, 'length': 34.0},
            'h_bar': {'size': 5, 'no': 11, 'length': 14.83},
            'j_bar': {'size': 8, 'no': 11, 'length': 26.583},
            'k_bar': {'size': 5, 'no': 11, 'length': 10.83}
        }
    },
    25: {  # QC'd
        'thickness': 16.5,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 27.58, 'length': 28.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 35.25},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 15.417},
        'd_bar': {'size': 8, 'spacing': 6, 'length': 27.333},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 11.25},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 75},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 82},
        'u_bar_lap': 134,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 10, 'f': 28.583, 'length': 29.5},
            'g_bar': {'size': 8, 'no': 10, 'length': 36.5},
            'h_bar': {'size': 5, 'no': 10, 'length': 16.083},
            'j_bar': {'size': 8, 'no': 10, 'length': 28.083},
            'k_bar': {'size': 5, 'no': 10, 'length': 11.667}
        },

        'parapet': {
            'd': 18, 'x': 63,
            'f_bar': {'size': 8, 'no': 10, 'f': 27.583, 'length': 28.5},
            'g_bar': {'size': 8, 'no': 10, 'length': 35.25},
            'h_bar': {'size': 5, 'no': 12, 'length': 15.417},
            'j_bar': {'size': 8, 'no': 12, 'length': 27.333},
            'k_bar': {'size': 5, 'no': 12, 'length': 11.25}
        }
    },
    26: {  # QC'd
        'thickness': 17,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 28.583, 'length': 29.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 36.5},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 16.083},
        'd_bar': {'size': 8, 'spacing': 6, 'length': 28.083},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 11.667},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 78},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 86},
        'u_bar_lap': 140,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 10, 'f': 28.583, 'length': 29.5},
            'g_bar': {'size': 8, 'no': 10, 'length': 36.5},
            'h_bar': {'size': 5, 'no': 10, 'length': 16.083},
            'j_bar': {'size': 8, 'no': 10, 'length': 28.083},
            'k_bar': {'size': 5, 'no': 10, 'length': 11.667}
        },

        'parapet': {
            'd': 18, 'x': 63,
            'f_bar': {'size': 8, 'no': 11, 'f': 28.583, 'length': 29.5},
            'g_bar': {'size': 8, 'no': 11, 'length': 36.5},
            'h_bar': {'size': 5, 'no': 12, 'length': 16.083},
            'j_bar': {'size': 8, 'no': 12, 'length': 28.083},
            'k_bar': {'size': 5, 'no': 12, 'length': 11.667}
        }
    },
    27: {  # QC'd
        'thickness': 17.5,
        'a_bar': {'size': 8, 'spacing': 7, 'a': 29.583, 'length': 30.5},
        'b_bar': {'size': 8, 'spacing': 7, 'length': 37.750},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 16.667},
        'd_bar': {'size': 8, 'spacing': 6, 'length': 28.833},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 12.167},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 80},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 89},
        'u_bar_lap': 144,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 8, 'no': 10, 'f': 29.583, 'length': 30.5},
            'g_bar': {'size': 8, 'no': 10, 'length': 37.75},
            'h_bar': {'size': 5, 'no': 10, 'length': 16.667},
            'j_bar': {'size': 8, 'no': 10, 'length': 28.833},
            'k_bar': {'size': 5, 'no': 10, 'length': 12.167}
        },

        'parapet': {
            'd': 18, 'x': 63,
            'f_bar': {'size': 9, 'no': 9, 'f': 29.833, 'length': 31.083},
            'g_bar': {'size': 9, 'no': 9, 'length': 38.250},
            'h_bar': {'size': 5, 'no': 11, 'length': 16.667},
            'j_bar': {'size': 9, 'no': 11, 'length': 30.5},
            'k_bar': {'size': 5, 'no': 11, 'length': 12.167}
        }
    },
    28: {  # QC'd
        'thickness': 18,
        'a_bar': {'size': 8, 'spacing': 6, 'a': 30.583, 'length': 31.5},
        'b_bar': {'size': 8, 'spacing': 6, 'length': 39.0},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 17.25},
        'd_bar': {'size': 8, 'spacing': 6, 'length': 29.667},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 12.583},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 83},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 92},
        'u_bar_lap': 150,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 9, 'no': 9, 'f': 30.833, 'length': 32.083},
            'g_bar': {'size': 9, 'no': 9, 'length': 39.5},
            'h_bar': {'size': 5, 'no': 9, 'length': 17.25},
            'j_bar': {'size': 9, 'no': 9, 'length': 31.333},
            'k_bar': {'size': 5, 'no': 9, 'length': 12.583}
        },

        'parapet': {
            'd': 18, 'x': 63,
            'f_bar': {'size': 9, 'no': 10, 'f': 30.833, 'length': 32.083},
            'g_bar': {'size': 9, 'no': 10, 'length': 39.5},
            'h_bar': {'size': 5, 'no': 11, 'length': 17.25},
            'j_bar': {'size': 9, 'no': 11, 'length': 31.333},
            'k_bar': {'size': 5, 'no': 11, 'length': 12.583}
        }
    },
    29: {  # QC'd
        'thickness': 18.5,
        'a_bar': {'size': 8, 'spacing': 6, 'a': 31.583, 'length': 32.5},
        'b_bar': {'size': 8, 'spacing': 6, 'length': 40.25},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 17.833},
        'd_bar': {'size': 8, 'spacing': 6, 'length': 30.583},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 13},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 86},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 95},
        'u_bar_lap': 156,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 9, 'no': 9, 'f': 31.833, 'length': 33.083},
            'g_bar': {'size': 9, 'no': 9, 'length': 40.75},
            'h_bar': {'size': 5, 'no': 9, 'length': 17.833},
            'j_bar': {'size': 9, 'no': 9, 'length': 32.25},
            'k_bar': {'size': 5, 'no': 9, 'length': 13}
        },

        'parapet': {
            'd': 18.5, 'x': 66,
            'f_bar': {'size': 9, 'no': 10, 'f': 31.833, 'length': 33.083},
            'g_bar': {'size': 9, 'no': 10, 'length': 40.75},
            'h_bar': {'size': 5, 'no': 12, 'length': 17.833},
            'j_bar': {'size': 9, 'no': 12, 'length': 32.250},
            'k_bar': {'size': 5, 'no': 12, 'length': 13.0}
        }
    },
    30: {  # QC'd
        'thickness': 19,
        'a_bar': {'size': 8, 'spacing': 6, 'a': 32.583, 'length': 33.5},
        'b_bar': {'size': 8, 'spacing': 6, 'length': 41.5},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 18.417},
        'd_bar': {'size': 9, 'spacing': 7, 'length': 33.0},
        'e_bar': {'size': 5, 'spacing': 7, 'length': 13.5},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 88},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 99},
        'u_bar_lap': 160,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 9, 'no': 9, 'f': 32.833, 'length': 34.083},
            'g_bar': {'size': 9, 'no': 9, 'length': 42.0},
            'h_bar': {'size': 5, 'no': 10, 'length': 18.417},
            'j_bar': {'size': 9, 'no': 10, 'length': 33.0},
            'k_bar': {'size': 5, 'no': 10, 'length': 13.5}
        },

        'parapet': {
            'd': 19, 'x': 66,
            'f_bar': {'size': 9, 'no': 10, 'f': 32.833, 'length': 34.083},
            'g_bar': {'size': 9, 'no': 10, 'length': 42.0},
            'h_bar': {'size': 5, 'no': 13, 'length': 18.417},
            'j_bar': {'size': 9, 'no': 13, 'length': 33.0},
            'k_bar': {'size': 5, 'no': 13, 'length': 13.5}
        }
    },
    31: {  # QC'd
        'thickness': 19.5,
        'a_bar': {'size': 8, 'spacing': 6, 'a': 33.583, 'length': 34.5},
        'b_bar': {'size': 8, 'spacing': 6, 'length': 42.75},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 19},
        'd_bar': {'size': 9, 'spacing': 7, 'length': 33.833},
        'e_bar': {'size': 5, 'spacing': 7, 'length': 13.917},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 91},
        'm_bar': {'size': 4, 'spacing': 12, 'no': 102},
        'u_bar_lap': 166,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 9, 'no': 9, 'f': 33.833, 'length': 35.083},
            'g_bar': {'size': 9, 'no': 9, 'length': 43.25},
            'h_bar': {'size': 5, 'no': 10, 'length': 19.0},
            'j_bar': {'size': 9, 'no': 10, 'length': 33.833},
            'k_bar': {'size': 5, 'no': 10, 'length': 13.917}
        },

        'parapet': {
            'd': 19.5, 'x': 66,
            'f_bar': {'size': 9, 'no': 11, 'f': 33.833, 'length': 35.083},
            'g_bar': {'size': 9, 'no': 11, 'length': 43.25},
            'h_bar': {'size': 5, 'no': 13, 'length': 19.0},
            'j_bar': {'size': 9, 'no': 13, 'length': 33.833},
            'k_bar': {'size': 5, 'no': 13, 'length': 13.917}
        }
    },
    32: {  # QC'd
        'thickness': 20,
        'a_bar': {'size': 8, 'spacing': 6, 'a': 34.583, 'length': 35.5},
        'b_bar': {'size': 8, 'spacing': 6, 'length': 44},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 19.667},
        'd_bar': {'size': 9, 'spacing': 7, 'length': 34.5},
        'e_bar': {'size': 5, 'spacing': 7, 'length': 14.333},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 93},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 105},
        'u_bar_lap': 170,

        'over_side_drainage': {
            'd': 20, 'x': 48,
            'f_bar': {'size': 9, 'no': 10, 'f': 34.833, 'length': 36.083},
            'g_bar': {'size': 9, 'no': 10, 'length': 44.5},
            'h_bar': {'size': 5, 'no': 11, 'length': 19.667},
            'j_bar': {'size': 9, 'no': 11, 'length': 34.5},
            'k_bar': {'size': 5, 'no': 11, 'length': 14.333}
        },

        'parapet': {
            'd': 20, 'x': 66,
            'f_bar': {'size': 9, 'no': 11, 'f': 34.833, 'length': 36.083},
            'g_bar': {'size': 9, 'no': 11, 'length': 44.5},
            'h_bar': {'size': 5, 'no': 13, 'length': 19.667},
            'j_bar': {'size': 9, 'no': 13, 'length': 34.5},
            'k_bar': {'size': 5, 'no': 13, 'length': 14.333}
        }
    },
    33: {  # QC'd
        'thickness': 20.5,
        'a_bar': {'size': 8, 'spacing': 6, 'a': 35.583, 'length': 36.6},
        'b_bar': {'size': 8, 'spacing': 6, 'length': 45.25},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 20.25},
        'd_bar': {'size': 9, 'spacing': 6, 'length': 35.33},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 14.75},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 96},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 108},
        'u_bar_lap': 176,

        'over_side_drainage': {
            'd': 20.5, 'x': 51,
            'f_bar': {'size': 10, 'no': 9, 'f': 36.083, 'length': 37.5},
            'g_bar': {'size': 10, 'no': 9, 'length': 46.25},
            'h_bar': {'size': 5, 'no': 10, 'length': 20.25},
            'j_bar': {'size': 10, 'no': 10, 'length': 37.333},
            'k_bar': {'size': 5, 'no': 10, 'length': 14.750}
        },

        'parapet': {
            'd': 20.5, 'x': 66,
            'f_bar': {'size': 9, 'no': 11, 'f': 35.833, 'length': 37.083},
            'g_bar': {'size': 9, 'no': 11, 'length': 45.75},
            'h_bar': {'size': 5, 'no': 13, 'length': 20.25},
            'j_bar': {'size': 9, 'no': 13, 'length': 35.33},
            'k_bar': {'size': 5, 'no': 13, 'length': 14.75}
        }
    },
    34: {  # QC'd
        'thickness': 21,
        'a_bar': {'size': 8, 'spacing': 6, 'a': 36.583, 'length': 37.5},
        'b_bar': {'size': 8, 'spacing': 6, 'length': 46.5},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 20.83},
        'd_bar': {'size': 9, 'spacing': 6, 'length': 36.25},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 15.167},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 99},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 112},
        'u_bar_lap': 182,

        'over_side_drainage': {
            'd': 21, 'x': 51,
            'f_bar': {'size': 10, 'no': 9, 'f': 37.083, 'length': 38.5},
            'g_bar': {'size': 10, 'no': 9, 'length': 47.5},
            'h_bar': {'size': 5, 'no': 10, 'length': 20.833},
            'j_bar': {'size': 10, 'no': 10, 'length': 38.25},
            'k_bar': {'size': 5, 'no': 10, 'length': 15.167}
        },

        'parapet': {
            'd': 21, 'x': 66,
            'f_bar': {'size': 9, 'no': 11, 'f': 36.83, 'length': 38.083},
            'g_bar': {'size': 9, 'no': 11, 'length': 47.0},
            'h_bar': {'size': 5, 'no': 11, 'length': 20.833},
            'j_bar': {'size': 10, 'no': 11, 'length': 38.25},
            'k_bar': {'size': 5, 'no': 11, 'length': 15.167}
        }
    },
    35: {  # QC'd
        'thickness': 21.5,
        'a_bar': {'size': 9, 'spacing': 7, 'a': 37.833, 'length': 39.083},
        'b_bar': {'size': 9, 'spacing': 7, 'length': 48.25},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 21.417},
        'd_bar': {'size': 9, 'spacing': 6, 'length': 37.0},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 15.667},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 101},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 115},
        'u_bar_lap': 186,

        'over_side_drainage': {
            'd': 21.5, 'x': 51,
            'f_bar': {'size': 10, 'no': 9, 'f': 38.083, 'length': 39.5},
            'g_bar': {'size': 10, 'no': 9, 'length': 48.75},
            'h_bar': {'size': 5, 'no': 10, 'length': 21.417},
            'j_bar': {'size': 10, 'no': 10, 'length': 39.0},
            'k_bar': {'size': 5, 'no': 10, 'length': 15.667}
        },

        'parapet': {
            'd': 21.5, 'x': 66,
            'f_bar': {'size': 10, 'no': 9, 'f': 38.083, 'length': 39.5},
            'g_bar': {'size': 10, 'no': 9, 'length': 48.75},
            'h_bar': {'size': 5, 'no': 12, 'length': 21.417},
            'j_bar': {'size': 10, 'no': 12, 'length': 39.0},
            'k_bar': {'size': 5, 'no': 12, 'length': 15.667}
        }
    },
    36: {  # QC'd
        'thickness': 22,
        'a_bar': {'size': 9, 'spacing': 7, 'a': 38.83, 'length': 40.08},
        'b_bar': {'size': 9, 'spacing': 7, 'length': 49.5},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 22.0},
        'd_bar': {'size': 9, 'spacing': 6, 'length': 37.83},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 16.083},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 104},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 118},
        'u_bar_lap': 192,

        'over_side_drainage': {
            'd': 22, 'x': 51,
            'f_bar': {'size': 10, 'no': 9, 'f': 39.083, 'length': 40.5},
            'g_bar': {'size': 10, 'no': 9, 'length': 50.0},
            'h_bar': {'size': 5, 'no': 10, 'length': 22.0},
            'j_bar': {'size': 10, 'no': 10, 'length': 39.83},
            'k_bar': {'size': 5, 'no': 10, 'length': 16.083}
        },

        'parapet': {
            'd': 22, 'x': 66,
            'f_bar': {'size': 10, 'no': 9, 'f': 39.083, 'length': 40.5},
            'g_bar': {'size': 10, 'no': 9, 'length': 50.0},
            'h_bar': {'size': 5, 'no': 12, 'length': 22.0},
            'j_bar': {'size': 10, 'no': 12, 'length': 39.833},
            'k_bar': {'size': 5, 'no': 12, 'length': 16.083}
        }
    },
    37: {  # QC'd
        'thickness': 22.5,
        'a_bar': {'size': 9, 'spacing': 7, 'a': 39.833, 'length': 41.083},
        'b_bar': {'size': 9, 'spacing': 7, 'length': 50.75},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 22.583},
        'd_bar': {'size': 9, 'spacing': 6, 'length': 38.75},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 16.583},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 106},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 121},
        'u_bar_lap': 196,

        'over_side_drainage': {
            'd': 22.5, 'x': 51,
            'f_bar': {'size': 10, 'no': 9, 'f': 40.083, 'length': 41.5},
            'g_bar': {'size': 10, 'no': 9, 'length': 51.25},
            'h_bar': {'size': 5, 'no': 10, 'length': 22.583},
            'j_bar': {'size': 10, 'no': 10, 'length': 40.75},
            'k_bar': {'size': 5, 'no': 10, 'length': 16.583}
        },

        'parapet': {
            'd': 22.5, 'x': 66,
            'f_bar': {'size': 10, 'no': 10, 'f': 40.083, 'length': 41.5},
            'g_bar': {'size': 10, 'no': 10, 'length': 51.25},
            'h_bar': {'size': 5, 'no': 12, 'length': 22.583},
            'j_bar': {'size': 10, 'no': 12, 'length': 40.75},
            'k_bar': {'size': 5, 'no': 12, 'length': 16.583}
        }
    },
    38: {  # QC'd
        'thickness': 23,
        'a_bar': {'size': 9, 'spacing': 7, 'a': 40.833, 'length': 42.083},
        'b_bar': {'size': 9, 'spacing': 7, 'length': 52.0},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 23.25},
        'd_bar': {'size': 10, 'spacing': 7, 'length': 41.33},
        'e_bar': {'size': 5, 'spacing': 7, 'length': 17.0},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 109},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 125},
        'u_bar_lap': 202,

        'over_side_drainage': {
            'd': 23, 'x': 51,
            'f_bar': {'size': 10, 'no': 9, 'f': 41.083, 'length': 42.5},
            'g_bar': {'size': 10, 'no': 9, 'length': 52.5},
            'h_bar': {'size': 5, 'no': 11, 'length': 23.250},
            'j_bar': {'size': 10, 'no': 11, 'length': 41.333},
            'k_bar': {'size': 5, 'no': 11, 'length': 17.0}
        },

        'parapet': {
            'd': 23, 'x': 66,
            'f_bar': {'size': 10, 'no': 10, 'f': 41.083, 'length': 42.5},
            'g_bar': {'size': 10, 'no': 10, 'length': 52.5},
            'h_bar': {'size': 5, 'no': 12, 'length': 23.25},
            'j_bar': {'size': 10, 'no': 12, 'length': 41.33},
            'k_bar': {'size': 5, 'no': 12, 'length': 17.0}
        }
    },
    39: {
        'thickness': 23.5,
        'a_bar': {'size': 9, 'spacing': 7, 'a': 41.833, 'length': 43.083},
        'b_bar': {'size': 9, 'spacing': 7, 'length': 53.25},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 23.833},
        'd_bar': {'size': 10, 'spacing': 7, 'length': 42.25},
        'e_bar': {'size': 5, 'spacing': 7, 'length': 17.5},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 112},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 128},
        'u_bar_lap': 208,

        'over_side_drainage': {
            'd': 23.5, 'x': 51,
            'f_bar': {'size': 10, 'no': 9, 'f': 42.083, 'length': 43.5},
            'g_bar': {'size': 10, 'no': 9, 'length': 53.75},
            'h_bar': {'size': 5, 'no': 11, 'length': 23.833},
            'j_bar': {'size': 10, 'no': 11, 'length': 42.25},
            'k_bar': {'size': 5, 'no': 11, 'length': 17.5}
        },

        'parapet': {
            'd': 23.5, 'x': 66,
            'f_bar': {'size': 10, 'no': 10, 'f': 42.083, 'length': 43.5},
            'g_bar': {'size': 10, 'no': 10, 'length': 53.75},
            'h_bar': {'size': 5, 'no': 13, 'length': 23.833},
            'j_bar': {'size': 10, 'no': 13, 'length': 42.25},
            'k_bar': {'size': 5, 'no': 13, 'length': 17.5}
        }
    },
    40: {  # QC'd
        'thickness': 24,
        'a_bar': {'size': 9, 'spacing': 7, 'a': 42.083, 'length': 44.083},
        'b_bar': {'size': 9, 'spacing': 7, 'length': 54.5},
        'c_bar': {'size': 5, 'spacing': 7, 'length': 24.417},
        'd_bar': {'size': 10, 'spacing': 7, 'length': 43.0},
        'e_bar': {'size': 5, 'spacing': 7, 'length': 17.917},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 114},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 131},
        'u_bar_lap': 212,

        'over_side_drainage': {
            'd': 24, 'x': 54,
            'f_bar': {'size': 10, 'no': 10, 'f': 43.083, 'length': 44.5},
            'g_bar': {'size': 10, 'no': 10, 'length': 55.0},
            'h_bar': {'size': 5, 'no': 12, 'length': 24.417},
            'j_bar': {'size': 10, 'no': 12, 'length': 43.0},
            'k_bar': {'size': 5, 'no': 12, 'length': 17.917}
        },

        'parapet': {
            'd': 24, 'x': 66,
            'f_bar': {'size': 10, 'no': 10, 'f': 43.083, 'length': 44.5},
            'g_bar': {'size': 10, 'no': 10, 'length': 55.0},
            'h_bar': {'size': 5, 'no': 13, 'length': 24.417},
            'j_bar': {'size': 10, 'no': 13, 'length': 43.0},
            'k_bar': {'size': 5, 'no': 13, 'length': 17.917}
        }
    },
    41: {  # QC'd
        'thickness': 24.5,
        'a_bar': {'size': 9, 'spacing': 6, 'a': 43.83, 'length': 45.083},
        'b_bar': {'size': 9, 'spacing': 6, 'length': 55.750},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 25.0},
        'd_bar': {'size': 10, 'spacing': 6, 'length': 43.833},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 18.417},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 117},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 134},
        'u_bar_lap': 218,

        'over_side_drainage': {
            'd': 24.5, 'x': 54,
            'f_bar': {'size': 10, 'no': 10, 'f': 42.833, 'length': 43.833},
            'g_bar': {'size': 10, 'no': 10, 'length': 56.25},
            'h_bar': {'size': 5, 'no': 12, 'length': 25.0},
            'j_bar': {'size': 10, 'no': 12, 'length': 43.833},
            'k_bar': {'size': 5, 'no': 12, 'length': 18.417}
        },

        'parapet': {
            'd': 24.5, 'x': 66,
            'f_bar': {'size': 10, 'no': 10, 'f': 44.083, 'length': 45.5},
            'g_bar': {'size': 10, 'no': 10, 'length': 56.25},
            'h_bar': {'size': 5, 'no': 13, 'length': 25.0},
            'j_bar': {'size': 10, 'no': 13, 'length': 43.833},
            'k_bar': {'size': 5, 'no': 13, 'length': 18.417}
        }
    },
    42: {  # QC'd
        'thickness': 25,
        'a_bar': {'size': 9, 'spacing': 6, 'a': 44.833, 'length': 46.083},
        'b_bar': {'size': 9, 'spacing': 6, 'length': 57.0},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 25.667},
        'd_bar': {'size': 10, 'spacing': 6, 'length': 44.5},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 18.83},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 119},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 138},
        'u_bar_lap': 222,

        'over_side_drainage': {
            'd': 25, 'x': 54,
            'f_bar': {'size': 10, 'no': 10, 'f': 45.083, 'length': 46.6},
            'g_bar': {'size': 10, 'no': 10, 'length': 57.5},
            'h_bar': {'size': 5, 'no': 12, 'length': 25.667},
            'j_bar': {'size': 10, 'no': 12, 'length': 44.5},
            'k_bar': {'size': 5, 'no': 12, 'length': 18.583}
        },

        'parapet': {
            'd': 25, 'x': 66,
            'f_bar': {'size': 10, 'no': 11, 'f': 45.083, 'length': 46.5},
            'g_bar': {'size': 10, 'no': 11, 'length': 57.5},
            'h_bar': {'size': 5, 'no': 13, 'length': 25.667},
            'j_bar': {'size': 10, 'no': 13, 'length': 44.5},
            'k_bar': {'size': 5, 'no': 13, 'length': 18.833}
        }
    },
    43: {  # QC'd
        'thickness': 25.5,
        'a_bar': {'size': 9, 'spacing': 6, 'a': 45.833, 'length': 47.083},
        'b_bar': {'size': 9, 'spacing': 6, 'length': 58.25},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 26.25},
        'd_bar': {'size': 10, 'spacing': 6, 'length': 45.333},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 19.250},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 122},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 141},
        'u_bar_lap': 228,
        'over_side_drainage': {
            'd': 25.5, 'x': 54,
            'f_bar': {'size': 10, 'no': 10, 'f': 46.083, 'length': 47.5},
            'g_bar': {'size': 10, 'no': 10, 'length': 58.75},
            'h_bar': {'size': 5, 'no': 12, 'length': 26.25},
            'j_bar': {'size': 10, 'no': 12, 'length': 45.333},
            'k_bar': {'size': 5, 'no': 12, 'length': 19.25}
        },
        'parapet': {
            'd': 25.5, 'x': 66,
            'f_bar': {'size': 10, 'no': 11, 'f': 46.083, 'length': 47.5},
            'g_bar': {'size': 10, 'no': 11, 'length': 58.75},
            'h_bar': {'size': 5, 'no': 14, 'length': 26.25},
            'j_bar': {'size': 10, 'no': 14, 'length': 45.333},
            'k_bar': {'size': 5, 'no': 14, 'length': 19.750}
        }
    },
    44: {
        'thickness': 26,
        'a_bar': {'size': 9, 'spacing': 6, 'a': 46.833, 'length': 48.083},
        'b_bar': {'size': 9, 'spacing': 6, 'length': 59.5},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 26.833},
        'd_bar': {'size': 10, 'spacing': 6, 'length': 46.25},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 19.667},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 125},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 144},
        'u_bar_lap': 234,
        'over_side_drainage': {
            'd': 26, 'x': 54,
            'f_bar': {'size': 10, 'no': 11, 'f': 47.083, 'length': 48.5},
            'g_bar': {'size': 10, 'no': 11, 'length': 60},
            'h_bar': {'size': 5, 'no': 12, 'length': 26.833},
            'j_bar': {'size': 10, 'no': 12, 'length': 46.25},
            'k_bar': {'size': 5, 'no': 12, 'length': 19.667}
        },
        'parapet': {
            'd': 26, 'x': 69,
            'f_bar': {'size': 10, 'no': 11, 'f': 47.083, 'length': 48.5},
            'g_bar': {'size': 10, 'no': 11, 'length': 60.0},
            'h_bar': {'size': 5, 'no': 15, 'length': 26.83},
            'j_bar': {'size': 10, 'no': 15, 'length': 46.25},
            'k_bar': {'size': 5, 'no': 15, 'length': 19.667}
        }
    },
    45: {
        'thickness': 26.5,
        'a_bar': {'size': 10, 'spacing': 7, 'a': 48.083, 'length': 49.5},
        'b_bar': {'size': 10, 'spacing': 7, 'length': 61.25},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 27.417},
        'd_bar': {'size': 10, 'spacing': 6, 'length': 47.0},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 20.167},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 127},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 147},
        'u_bar_lap': 238,
        'over_side_drainage': {
            'd': 26.5, 'x': 54,
            'f_bar': {'size': 10, 'no': 11, 'f': 48.083, 'length': 49.5},
            'g_bar': {'size': 10, 'no': 11, 'length': 61.25},
            'h_bar': {'size': 5, 'no': 13, 'length': 27.417},
            'j_bar': {'size': 10, 'no': 13, 'length': 47.0},
            'k_bar': {'size': 5, 'no': 13, 'length': 20.167}
        },
        'parapet': {
            'd': 26.5, 'x': 69,
            'f_bar': {'size': 10, 'no': 12, 'f': 48.083, 'length': 49.5},
            'g_bar': {'size': 10, 'no': 12, 'length': 61.25},
            'h_bar': {'size': 5, 'no': 15, 'length': 27.417},
            'j_bar': {'size': 10, 'no': 15, 'length': 47.0},
            'k_bar': {'size': 5, 'no': 14, 'length': 20.167}
        }
    },
    46: {
        'thickness': 27,
        'a_bar': {'size': 10, 'spacing': 7, 'a': 49.083, 'length': 50.5},
        'b_bar': {'size': 10, 'spacing': 7, 'length': 62.5},
        'c_bar': {'size': 5, 'spacing': 6, 'length': 28.083},
        'd_bar': {'size': 10, 'spacing': 6, 'length': 47.75},
        'e_bar': {'size': 5, 'spacing': 6, 'length': 20.667},
        'n_bar': {'size': 6, 'spacing': 15, 'no': 130},
        'm_bar': {'size': 5, 'spacing': 12, 'no': 151},
        'u_bar_lap': 244,
        'over_side_drainage': {
            'd': 27, 'x': 57,
            'f_bar': {'size': 10, 'no': 11, 'f': 49.083, 'length': 50.5},
            'g_bar': {'size': 10, 'no': 11, 'length': 62.5},
            'h_bar': {'size': 5, 'no': 13, 'length': 28.083},
            'j_bar': {'size': 10, 'no': 13, 'length': 47.75},
            'k_bar': {'size': 5, 'no': 13, 'length': 20.667}
        },
        'parapet': {
            'd': 27, 'x': 69,
            'f_bar': {'size': 10, 'no': 12, 'f': 49.083, 'length': 50.5},
            'g_bar': {'size': 10, 'no': 12, 'length': 62.5},
            'h_bar': {'size': 5, 'no': 15, 'length': 28.083},
            'j_bar': {'size': 10, 'no': 15, 'length': 47.75},
            'k_bar': {'size': 5, 'no': 15, 'length': 20.667}
        }
    }
}

# %% [markdown]
# # API Calls (Assetwise/BrR/TIMs)

# %%
from civilpy.state.ohio.DOT.AssetWise import AssetWiseBridge

# 5901057
sfn = "5901057"
for e in AssetWiseBridge(sfn).elements:
    print(f"{e['se_display_id']} - {e['se_name']}: CS1={e['state1']}, CS2={e['state2']}, CS3={e['state3']}, CS4={e['state4']}")
# Out:
# Fetching element data...
# 38 - Reinforced Concrete Slab: CS1=3634, CS2=18, CS3=0, CS4=0
# 215 - Reinforced Concrete Abutment: CS1=81, CS2=9, CS3=0, CS4=0
# 225 - Steel Pile: CS1=18, CS2=0, CS3=0, CS4=0
# 234 - Reinforced Concrete Pier Cap: CS1=89, CS2=1, CS3=0, CS4=0
# 321 - Reinforced Concrete Approach Slab: CS1=2282, CS2=68, CS3=50, CS4=0
# 331 - Reinforced Concrete Bridge Railing: CS1=133, CS2=33, CS3=0, CS4=0
# 815 - Drainage: CS1=2, CS2=0, CS3=0, CS4=0
# 510 - Wearing Surfaces: CS1=3158, CS2=245, CS3=0, CS4=0

# %%
from civilpy.state.ohio.DOT.AssetWise import AssetWiseBridge

bridge = AssetWiseBridge(sfn)

print(f"\n--- Bridge Data for SFN: {sfn} ---")

# 1. Try to get high-level type from the asset header
# Note: We use (.. or {}) to handle cases where asset_type might be None
print(f"Asset Type: {(bridge.asset_type or {}).get('at_name', 'N/A')}")

# 2. Search SNBI details for specific structural info
# Keywords cover: Bridge Type (Material/Design), Count, and Dimensions
search_terms = ["Material", "Design", "Span", "Length"]

for group in bridge.snbi_data.values():
    for item in group:
        label = item.get('label', '')
        value = item.get('value', '')
        
        # Case-insensitive match for any of our search terms
        if any(term.lower() in label.lower() for term in search_terms):
            print(f"{label}: {value}")
# Out:
# --- Bridge Data for SFN: 5901057 ---
# Asset Type: N/A
# Fetching and formatting all SNBI data...
# --- Starting Dynamic SNBI Data Discovery for Asset 80184 ---
# [SKIP]  Template 1000012 - Error 400
# [SKIP]  Template 1000013 - Error 400
# --- Discovery Complete. Retrieved 11 forms. ---
# B.H.17: Bypass Detour Length: 1
# B.H.17: Bypass Detour Length: 5
# B.H.05: STRAHNET Designation: 1
# B.H.05: STRAHNET Designation: N
# B.H.03: NHS Designation: Y
# B.H.03: NHS Designation: N
# B.RT.01: Route Designation: R01
# B.RT.01: Route Designation: R01
# B.SP.01.1: Span Type Selection (1): M
# B.SP.01: Span Configuration Designation (1): M01
# B.SP.02: Number of Spans (1): 3
# B.SP.04: Span Material (1): CR-T
# B.SP.05: Span Continuity (1): C-T
# B.SP.06: Span Type (1): S-T
# B.SP.06: Span Type (1): S-T
# B.SP.07: Span Protective System: None
# B.SP.09: Deck Material and Type (1): CR-T
# B.SB.03: Substructure Material: C01
# B.SB.03: Substructure Material: C01
# ...

# %%
import requests
from requests.auth import HTTPBasicAuth

# 1. Setup Context
bridge_asset_id = bridge.as_id
username, password = get_assetwise_secrets()
base_url = "https://ohiodot-it-api.bentley.com"

# 2. Target Template 1000004 (Where NBI items 47, 100, 104 live)
target_template = 1000005
url = f"{base_url}/api/FormElement/GetRfgTemplateElements/{bridge_asset_id}/0/{target_template}"

print(f"--- Validating Raw JSON for Template {target_template} ---")

try:
    response = requests.get(url, auth=HTTPBasicAuth(username, password))
    response.raise_for_status()
    data = response.json()

    if not data.get('success') or not data.get('data'):
        print("API returned 200 OK but no data payload.")
    else:
        # 3. Dump any value that looks like a Length or is Unnamed
        for instance in data['data']:
            if 'elements' in instance:
                for el in instance['elements']:
                    val = el.get('value')
                    label = (el.get('field') or {}).get('fe_name', 'UNNAMED')
                    
                    # Print if it has a value
                    if val is not None and val != "":
                        # Highlight likely candidates
                        prefix = ""
                        if "UNNAMED" in label: prefix = ">>> [Possible Missing Label] "
                        if "Length" in label or "Span" in label: prefix = ">>> [MATCH] "
                        
                        print(f"{prefix}ID: {el.get('el_id')} | Label: {label} | Value: {val}")

except Exception as e:
    print(f"Request failed: {e}")
# Out:
# --- Validating Raw JSON for Template 1000005 ---
# API returned 200 OK but no data payload.

# %%
data
# Out:
# {'data': [{'instance_id': 100100,
#    'ti_order': 1,
#    'ti_label': 'Substructure Material and Type 1',
#    'elements': [{'el_id': 217645,
#      'tp_id': 1000004,
#      'tm_id': 5021,
#      'el_col_binding': None,
#      'el_parent': 0,
#      'el_name': 'Dropdown6',
#      'et_id': 6,
#      'el_text': '',
#      'el_xpos': 1,
#      'el_ypos': 183,
#      'el_width': 200,
#      'el_height': 20,
#      'el_tabindex': 8,
#      'el_fontname': 'Arial',
#      'el_fontsize': 12.0,
#      'el_fontbold': False,
#      'el_fontunderline': False,
#      'el_fontitalic': False,
#      'el_fontforecolor': 'Black',
#      'el_fontbackcolor': '',
#      'el_borderstyle': None,
#      'el_textalign': None,
#      'el_image': None,
#      'el_show_fc_name': True,
#      'el_readonly': False,
#      'el_zindex': 10,
#      'child_tp_id': None,
#      'el_canexpand': False,
#      'el_datasource': None,
#      'el_order': None,
#      'parent_el_id': None,
#      'child_tp_type': None,
# ...
