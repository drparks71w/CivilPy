# %% [markdown]
# # Bid Tabs Website
#
# [ODOT Bid Tabs (excel format)](https://www.dot.state.oh.us/Divisions/ContractAdmin/Contracts/BidTabulations/Forms/BidTabs.aspx?RootFolder=%2FDivisions%2FContractAdmin%2FContracts%2FBidTabulations%2FExcel&FolderCTID=0x01200075F2298F9AB0EA4199CCABAD2294DB83&View=%7B91D63B7C%2D3CAA%2D493A%2D87EF%2DC5708BEA8EFC%7D)
#
# [Historic Values](https://www.dot.state.oh.us/Divisions/ContractAdmin/Contracts/BidTabs/Forms/Tabs.aspx)

# %% [markdown]
# ## Data Gathering

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.microsoft import EdgeChromiumDriverManager

# Set up the Edge browser driver using the older method
driver = webdriver.Edge()

url = 'https://www.dot.state.oh.us/Divisions/ContractAdmin/Contracts/BidTabulations/Forms/BidTabs.aspx?RootFolder=%2FDivisions%2FContractAdmin%2FContracts%2FBidTabulations%2FExcel#'
driver.get(url)

# Optional: Maximize the browser window
driver.maximize_window()

# %%
import codecs

# Get First page
list_of_excel_links = []

elements = driver.find_elements(By.CLASS_NAME, "ms-listlink")

for element in elements:
    text = element.get_attribute('onclick').split(',')
    list_of_excel_links.append("https://www.dot.state.oh.us" + codecs.decode(text[5][1:-21], 'unicode-escape'))

# %%
len(list_of_excel_links)
# Out:
# 300

# %%
time.sleep(3)
next_button = driver.find_element(By.ID, "pagingWPQ1next")
next_button.click()

# %%
# Clicks the next page button, then runs the same scraping
elements = driver.find_elements(By.CLASS_NAME, "ms-listlink")

for element in elements:
    text = element.get_attribute('onclick').split(',')
    list_of_excel_links.append("https://www.dot.state.oh.us" + codecs.decode(text[5][1:-21], 'unicode-escape'))

# %%
len(list_of_excel_links)
# Out:
# 470

# %%
list_of_excel_links = set(list_of_excel_links)
len(list_of_excel_links)
# Out:
# 470

# %%
from pathlib import Path
import requests
import re

download_folder = "C:\\Users\\dparks1\\Documents\\ODOT Bid tabs"

# %%
file_name = list(list_of_excel_links)[-1].split('/')[-1]
print(file_name)

download_path = Path(download_folder) / file_name
print(download_path)
# Out:
# 2024-10-31.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-10-31.xls

# %%
import os
files = os.listdir(download_folder)

# %%
from pathlib import Path

for link in list_of_excel_links:
    file_name = link.split('/')[-1]

    if file_name in files:  # Skips the files if they've already been dl'd
        continue
    else:
        file_response = requests.get(link)
        
        download_path = Path(download_folder) / file_name
    
        with open(download_path, "wb") as f:
            f.write(file_response.content)
            print(f"Saved file to : {download_path}")

# %%
verification_list = [
    "2024-05-23	Daniel Stacy",
    "2024-05-16	Daniel Stacy",
    "2024-05-09	Daniel Stacy",
    "2024-04-18	Daniel Stacy",
    "2024-04-04	Daniel Stacy",
    "2024-03-21	Daniel Stacy",
    "2024-03-01	Daniel Stacy",
    "2024-02-22	Daniel Stacy",
    "2024-02-09	Daniel Stacy",
    "2024-02-08	Daniel Stacy",
    "2024-01-25	Daniel Stacy",
    "2024-01-18	Daniel Stacy",
    "2024-01-11	Daniel Stacy",
    "2023-12-14	Daniel Stacy",
    "2023-11-30	Daniel Stacy",
    "2023-11-17	Daniel Stacy",
    "2023-11-09	Daniel Stacy",
    "2023-11-08	Daniel Stacy",
    "2023-10-26	Daniel Stacy",
    "2023-10-12	Daniel Stacy",
    "2023-09-28	Daniel Stacy",
    "2023-09-14	Daniel Stacy",
    "2023-08-31	Daniel Stacy",
    "2023-08-24	Daniel Stacy",
    "2023-08-10	Daniel Stacy",
    "2023-07-27	Daniel Stacy",
    "2023-07-13	Daniel Stacy",
    "2023-06-22	Daniel Stacy",
    "2023-06-08	Daniel Stacy",
    "2023-05-25	Daniel Stacy",
    "2023-05-24	Daniel Stacy",
    "2023-05-11	Daniel Stacy",
    "2023-04-27	Daniel Stacy",
    "2023-04-20	Daniel Stacy",
    "2023-04-13	Daniel Stacy",
    "2023-03-30	Daniel Stacy",
    "2023-03-09	Daniel Stacy",
    "2023-02-23	Daniel Stacy",
    "2023-02-16	Daniel Stacy",
    "2023-01-26	Daniel Stacy",
    "2023-01-12	Daniel Stacy",
    "2022-12-15	Daniel Stacy",
    "2022-12-01	Daniel Stacy",
    "2022-11-17	Daniel Stacy",
    "2022-11-03	Daniel Stacy",
    "2022-10-13	Daniel Stacy",
    "2022-09-29	Daniel Stacy",
    "2022-09-15	Daniel Stacy",
    "2022-08-25	Daniel Stacy",
    "2022-08-11	Daniel Stacy",
    "2022-07-28	Daniel Stacy",
    "2022-07-14	Daniel Stacy",
    "2022-06-30	Daniel Stacy",
    "2022-06-16	Daniel Stacy",
    "2022-05-26	Daniel Stacy",
    "2022-05-12	Daniel Stacy",
    "2022-04-28	Daniel Stacy",
    "2022-04-14	Daniel Stacy",
    "2022-03-31	Daniel Stacy",
    "2022-03-17	Daniel Stacy",
    "2022-03-10	Daniel Stacy",
    "2022-02-17	Daniel Stacy",
    "2022-01-27	Daniel Stacy",
    "2022-01-13	Daniel Stacy",
    "2021-12-17	Daniel Stacy",
    "2021-12-16	Daniel Stacy",
    "2021-12-15	Daniel Stacy",
    "2021-12-02	Daniel Stacy",
    "2021-11-18	Daniel Stacy",
    "2021-10-28	Daniel Stacy",
    "2021-10-14	Daniel Stacy",
    "2021-09-30	Daniel Stacy",
    "2021-09-16	Daniel Stacy",
    "2021-09-15	Daniel Stacy",
    "2021-08-26	Daniel Stacy",
    "2021-08-12	Daniel Stacy",
    "2021-07-29	Daniel Stacy",
    "2021-07-16	Daniel Stacy",
    "2021-07-15	Daniel Stacy",
    "2021-07-01	Daniel Stacy",
    "2021-06-17	Daniel Stacy",
    "2021-05-27	Daniel Stacy",
    "2021-05-13	Daniel Stacy",
    "2021-05-06	Daniel Stacy",
    "2021-04-29	Daniel Stacy",
    "2021-04-16	Daniel Stacy",
    "2021-04-15	Daniel Stacy",
    "2021-04-01	Daniel Stacy",
    "2021-03-11	Daniel Stacy",
    "2021-03-04	Daniel Stacy",
    "2021-02-25	Daniel Stacy",
    "2021-02-11	Daniel Stacy",
    "2021-01-28	Daniel Stacy",
    "2021-01-14	Daniel Stacy",
    "2020-12-17	Daniel Stacy",
    "2020-12-03	Daniel Stacy",
    "2020-11-19	Daniel Stacy",
    "2020-11-05	Daniel Stacy",
    "2020-10-15	Daniel Stacy",
    "2020-10-01	Daniel Stacy",
    "2020-09-17	Daniel Stacy",
    "2020-08-27	Daniel Stacy",
    "2020-08-13	Daniel Stacy",
    "2020-07-30	Daniel Stacy",
    "2020-07-16	Daniel Stacy",
    "2020-07-02	Daniel Stacy",
    "2020-06-18	Daniel Stacy",
    "2020-06-09	Daniel Stacy",
    "2020-06-04	Daniel Stacy",
    "2020-05-21	Daniel Stacy",
    "2020-05-08	Daniel Stacy",
    "2020-05-07	Daniel Stacy",
    "2020-04-24	Daniel Stacy",
    "2020-04-23	Daniel Stacy",
    "2020-04-16	Daniel Stacy",
    "2020-04-10	Daniel Stacy",
    "2020-04-09	Daniel Stacy",
    "2020-03-26	Daniel Stacy",
    "2020-03-12	Daniel Stacy",
    "2020-02-27	Daniel Stacy",
    "2020-02-20	Daniel Stacy",
    "2020-02-13	Daniel Stacy",
    "2020-01-24	Daniel Stacy",
    "2020-01-23	Daniel Stacy",
    "2020-01-16	Daniel Stacy",
    "2019-12-19	Daniel Stacy",
    "2019-12-13	Daniel Stacy",
    "2019-12-12	Daniel Stacy",
    "2019-11-21	Daniel Stacy",
    "2019-11-07	Daniel Stacy",
    "2019-10-24	Daniel Stacy",
    "2019-10-10	Daniel Stacy",
    "2019-09-26	Daniel Stacy",
    "2019-09-19	Daniel Stacy",
    "2019-09-12	Daniel Stacy",
    "2019-08-22	Daniel Stacy",
    "2019-08-15	Daniel Stacy",
    "2019-08-09	Daniel Stacy",
    "2019-08-08	Daniel Stacy",
    "2019-07-25	Daniel Stacy",
    "2019-07-11	Daniel Stacy",
    "2019-06-20	Daniel Stacy",
    "2019-06-06	Daniel Stacy",
    "2019-05-23	Daniel Stacy",
    "2019-05-16	Daniel Stacy",
    "2019-05-03	Daniel Stacy",
    "2019-05-02	Daniel Stacy",
    "2019-04-19	Daniel Stacy",
    "2019-04-18	Daniel Stacy",
    "2019-04-11	Daniel Stacy",
    "2019-04-04	Daniel Stacy",
    "2019-03-21	Daniel Stacy",
    "2019-03-08	Daniel Stacy",
    "2019-03-07	Daniel Stacy",
    "2019-02-21	Daniel Stacy",
    "2019-02-01	Daniel Stacy",
    "2019-01-31	Daniel Stacy",
    "2019-01-24	Daniel Stacy",
    "2019-01-10	Daniel Stacy",
    "2018-12-20	Daniel Stacy",
    "2018-12-14	Daniel Stacy",
    "2018-12-13	Daniel Stacy",
    "2018-11-30	Daniel Stacy",
    "2018-11-29	Daniel Stacy",
    "2018-11-08	Daniel Stacy",
    "2018-10-25	Daniel Stacy",
    "2018-10-12	Daniel Stacy",
    "2018-10-11	Daniel Stacy",
    "2018-09-13	Daniel Stacy",
    "2018-08-23	Daniel Stacy",
    "2018-08-09	Daniel Stacy",
    "2018-07-26	Daniel Stacy",
    "2018-07-20	Daniel Stacy",
    "2018-07-12	Rebecca Greer",
    "2018-06-21	Rebecca Greer",
    "2018-06-14	Rebecca Greer",
    "2018-06-12	Rebecca Greer",
    "2018-06-08	Rebecca Greer",
    "2018-06-07	Rebecca Greer",
    "2018-06-01	Rebecca Greer",
    "2018-05-25	Rebecca Greer",
    "2018-05-24	Rebecca Greer",
    "2018-05-17	Rebecca Greer",
    "2018-05-03	Rebecca Greer",
    "2018-04-19	Rebecca Greer",
    "2018-04-06	Rebecca Greer",
    "2018-04-05	Rebecca Greer",
    "2018-03-23	Rebecca Greer",
    "2018-03-22	Rebecca Greer",
    "2018-03-09	Norketta Carter",
    "2018-03-08	Daniel Stacy",
    "2018-02-16	Rebecca Greer",
    "2018-02-15	Rebecca Greer",
    "2018-02-02	Rebecca Greer",
    "2018-02-01	Rebecca Greer",
    "2018-01-25	Daniel Stacy",
    "2018-01-11	Rebecca Greer",
    "2017-12-21	Rebecca Greer",
    "2017-12-14	Rebecca Greer",
    "2017-11-30	Rebecca Greer",
    "2017-11-16	Rebecca Greer",
    "2017-11-02	Rebecca Greer",
    "2017-10-19	Rebecca Greer",
    "2017-10-05	Rebecca Greer",
    "2017-09-22	Daniel Stacy",
    "2017-09-21	Rebecca Greer",
    "2017-09-07	Rebecca Greer",
    "2017-08-24	Rebecca Greer",
    "2017-08-10	Rebecca Greer",
    "2017-07-27	Rebecca Greer",
    "2017-07-13	Rebecca Greer",
    "2017-06-29	Daniel Stacy",
    "2017-06-22	Rebecca Greer",
    "2017-06-08	Rebecca Greer",
    "2017-06-02	Rebecca Greer",
    "2017-05-26	Rebecca Greer",
    "2017-05-25	Rebecca Greer",
    "2017-05-18	Daniel Stacy",
    "2017-05-11	Rebecca Greer",
    "2017-05-04	Rebecca Greer",
    "2017-04-27	Rebecca Greer",
    "2017-04-13	Rebecca Greer",
    "2017-04-06	Rebecca Greer",
    "2017-03-30	Rebecca Greer",
    "2017-03-17	Daniel Stacy",
    "2017-03-09	Rebecca Greer",
    "2017-03-02	Rebecca Greer",
    "2017-02-23	Rebecca Greer",
    "2017-02-17	Rebecca Greer",
    "2017-02-09	Rebecca Greer",
    "2017-02-02	Rebecca Greer",
    "2017-01-19	Daniel Stacy",
    "2016-12-16	Rebecca Greer",
    "2016-12-15	Rebecca Greer",
    "2016-12-06	Rebecca Greer",
    "2016-12-01	Rebecca Greer",
    "2016-11-17	Rebecca Greer",
    "2016-11-03	Rebecca Greer",
    "2016-10-20	Rebecca Greer",
    "2016-10-07	Rebecca Greer",
    "2016-10-06	Rebecca Greer",
    "2016-09-22	Rebecca Greer",
    "2016-09-08	Rebecca Greer",
    "2016-08-25	Rebecca Greer",
    "2016-08-12	Rebecca Greer",
    "2016-08-11	Rebecca Greer",
    "2016-07-28	Rebecca Greer",
    "2016-07-14	Rebecca Greer",
    "2016-06-30	Rebecca Greer",
    "2016-06-16	Rebecca Greer",
    "2016-06-02	Rebecca Greer",
    "2016-05-26	Rebecca Greer",
    "2016-05-19	Rebecca Greer",
    "2016-05-12	Rebecca Greer",
    "2016-05-05	Rebecca Greer",
    "2016-04-21	Rebecca Greer",
    "2016-04-07	Rebecca Greer",
    "2016-03-24	Rebecca Greer",
    "2016-03-01	Rebecca Greer",
    "2016-02-18	Rebecca Greer",
    "2016-02-11	Rebecca Greer",
    "2016-01-28	Rebecca Greer",
    "2016-01-20	Rebecca Greer",
    "2016-01-15	Rebecca Greer",
    "2016-01-14	Rebecca Greer",
    "2015-12-22	Rebecca Greer",
    "2015-12-17	Rebecca Greer",
    "2015-12-03	Rebecca Greer",
    "2015-11-19	Rebecca Greer",
    "2015-11-05	Rebecca Greer",
    "2015-10-29	Rebecca Greer",
    "2015-10-22	Rebecca Greer",
    "2015-10-08	Rebecca Greer",
    "2015-09-25	Rebecca Greer",
    "2015-09-24	Rebecca Greer",
    "2015-09-10	Rebecca Greer",
    "2015-09-03	Rebecca Greer",
    "2015-08-27	Rebecca Greer",
    "2015-08-13	Rebecca Greer",
    "2015-08-06	Rebecca Greer",
    "2015-07-31	Rebecca Greer",
    "2015-07-30	Rebecca Greer",
    "2015-07-23	Rebecca Greer",
    "2015-07-17	Rebecca Greer",
    "2015-07-16	Rebecca Greer",
    "2015-07-10	Rebecca Greer",
    "2015-07-02	Rebecca Greer",
    "2015-06-25	Rebecca Greer",
    "2015-06-19	Rebecca Greer",
    "2015-06-18	Rebecca Greer",
    "2015-06-04	Rebecca Greer",
    "2015-05-29	Rebecca Greer",
    "2015-05-21	Daniel Stacy",
    "2015-05-07	Rebecca Greer",
    "2015-04-23	Rebecca Greer",
    "2015-04-09	Rebecca Greer",
    "2015-04-02	Rebecca Greer",
    "2015-03-20	Rebecca Greer",
    "2015-03-05	Rebecca Greer",
    "2015-02-26	Rebecca Greer",
    "2015-02-10	Rebecca Greer",
    "2015-02-05	Rebecca Greer",
    "2015-01-30	Rebecca Greer",
    "2015-01-29	Rebecca Greer",
    "2015-01-15	Rebecca Greer",
    "2014-12-18	Rebecca Greer",
    "2014-12-12	Rebecca Greer",
    "2014-12-11	Rebecca Greer",
    "2014-11-26	Rebecca Greer",
    "2014-11-20	Rebecca Greer",
    "2014-11-13	Rebecca Greer",
    "2014-11-06	Rebecca Greer",
    "2014-10-31	Rebecca Greer",
    "2014-10-30	Rebecca Greer",
    "2014-10-23	Rebecca Greer",
    "2014-10-17	Rebecca Greer",
    "2014-10-16	Rebecca Greer",
    "2014-10-02	Daniel Stacy",
    "2014-09-19	Rebecca Greer",
    "2014-09-18	Rebecca Greer",
    "2014-09-04	Rebecca Greer",
    "2014-08-21	Rebecca Greer",
    "2014-08-08	Rebecca Greer",
    "2014-08-07	Rebecca Greer",
    "2014-07-24	Rebecca Greer",
    "2014-07-10	Rebecca Greer",
    "2014-06-26	Rebecca Greer",
    "2014-06-06	Rebecca Greer",
    "2014-06-05	Rebecca Greer",
    "2014-05-29	Rebecca Greer",
    "2014-05-22	Rebecca Greer",
    "2014-05-15	Rebecca Greer",
    "2014-05-09	Rebecca Greer",
    "2014-05-08	Rebecca Greer",
    "2014-04-24	Rebecca Greer",
    "2014-04-17	Rebecca Greer",
    "2014-04-11	Rebecca Greer",
    "2014-04-10	Rebecca Greer",
    "2014-04-08	Rebecca Greer",
    "2014-03-27	Daniel Stacy",
    "2014-03-14	Daniel Stacy",
    "2014-03-13	Rebecca Greer",
    "2014-02-28	Rebecca Greer",
    "2014-02-18	Rebecca Greer",
    "2014-02-07	Rebecca Greer",
    "2014-02-06	Rebecca Greer",
    "2014-01-30	Rebecca Greer",
    "2014-01-23	Rebecca Greer",
    "2014-01-16	Daniel Stacy",
    "2014-01-09	Daniel Stacy",
    "2013-12-19	Daniel Stacy",
    "2013-12-05	Rebecca Greer",
    "2013-11-26	Rebecca Greer",
    "2013-11-21	Rebecca Greer",
    "2013-11-08	Daniel Stacy",
    "2013-11-07	Rebecca Greer",
    "2013-10-24	Rebecca Greer",
    "2013-10-17	Rebecca Greer",
    "2013-10-10	Rebecca Greer",
    "2013-09-27	Rebecca Greer",
    "2013-09-26	Rebecca Greer",
    "2013-09-12	Rebecca Greer",
    "2013-08-29	Rebecca Greer",
    "2013-08-22	Rebecca Greer",
    "2013-08-16	Rebecca Greer",
    "2013-08-15	Rebecca Greer",
    "2013-08-01	Rebecca Greer",
    "2013-07-26	Rebecca Greer",
    "2013-07-25	Rebecca Greer",
    "2013-07-19	Rebecca Greer",
    "2013-07-18	Rebecca Greer",
    "2013-06-27	Rebecca Greer",
    "2013-06-13	Rebecca Greer",
    "2013-06-07	Rebecca Greer",
    "2013-05-31	Rebecca Greer",
    "2013-05-30	Daniel Stacy",
    "2013-05-24	Rebecca Greer",
    "2013-05-23	Rebecca Greer",
    "2013-05-09	Rebecca Greer",
    "2013-05-02	Rebecca Greer",
    "2013-04-30	Rebecca Greer",
    "2013-04-25	Rebecca Greer",
    "2013-04-11	Rebecca Greer",
    "2013-04-04	Daniel Stacy",
    "2013-03-28	Daniel Stacy",
    "2013-03-21	Daniel Stacy",
    "2013-03-14	Daniel Stacy",
    "2013-03-07	Daniel Stacy",
    "2013-02-21	Daniel Stacy",
    "2013-02-15	Daniel Stacy",
    "2013-02-14	Daniel Stacy",
    "2013-02-01	Daniel Stacy",
    "2013-01-31	Daniel Stacy",
    "2013-01-17	Daniel Stacy",
    "2013-01-10	Daniel Stacy",
    "2012-12-20	Daniel Stacy",
    "2012-12-14	Daniel Stacy",
    "2012-12-13	Daniel Stacy",
    "2012-11-30	Daniel Stacy",
    "2012-11-29	Daniel Stacy",
    "2012-11-15	Daniel Stacy",
    "2012-11-08	Daniel Stacy",
    "2012-11-01	Daniel Stacy",
    "2012-10-18	Daniel Stacy",
    "2012-10-04	Daniel Stacy",
    "2012-09-28	Daniel Stacy",
    "2012-09-20	Daniel Stacy",
    "2012-09-06	Daniel Stacy",
    "2012-08-23	Daniel Stacy",
    "2012-08-16	Daniel Stacy",
    "2012-08-10	Daniel Stacy",
    "2012-08-09	Daniel Stacy",
    "2012-08-02	Daniel Stacy",
    "2012-07-27	Daniel Stacy",
    "2012-07-26	Daniel Stacy",
    "2012-07-19	Daniel Stacy",
    "2012-07-12	Daniel Stacy",
    "2012-06-22	Daniel Stacy",
    "2012-06-21	Daniel Stacy",
    "2012-06-08	Daniel Stacy",
    "2012-06-07	Daniel Stacy",
    "2012-05-24	Daniel Stacy",
    "2012-05-10	Daniel Stacy",
    "2012-04-26	Daniel Stacy",
    "2012-04-13	Daniel Stacy",
    "2012-04-12	Daniel Stacy",
    "2012-03-23	Daniel Stacy",
    "2012-03-22	Daniel Stacy",
    "2012-03-08	Daniel Stacy",
    "2012-02-24	Daniel Stacy",
    "2012-02-23	Daniel Stacy",
    "2012-02-16	Daniel Stacy",
    "2012-02-10	Daniel Stacy",
    "2012-02-09	Daniel Stacy",
    "2012-01-27	Daniel Stacy",
    "2012-01-26	Daniel Stacy",
    "2012-01-12	Daniel Stacy",
    "2011-12-29	Daniel Stacy",
]

len(verification_list)
# Out:
# 438

# %%
import os
files = os.listdir(download_folder)

# %%
files = [file[:-4] for file in files]  # Removes the .xls extension

# %%
missing_list = []

for value in verification_list:
    if value.split('\t')[0] not in files:
        missing_list.append(value.split('\t')[0])

# %%
missing_list
# Out:
# []

# %% [markdown]
# # Converting Data from Excel Files to a DB

# %% [markdown]
# ## County Data From Project Number Helper Function
#
# Need to be able to get the county data name to figure out which district the contract occurs in.

# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# Getting Counties from digital paper
driver = webdriver.Edge()

# %%
ohio_counties = {
    "ADAMS": "ADA",
    "ALLEN": "ALL",
    "ASHLAND": "ASD",
    "ASHTABULA": "ATB",
    "ATHENS": "ATH",
    "AUGLAIZE": "AUG",
    "BELMONT": "BEL",
    "BROWN": "BRO",
    "BUTLER": "BUT",
    "CARROLL": "CAR",
    "CHAMPAIGN": "CHP",
    "CLARK": "CLA",
    "CLERMONT": "CLE",
    "CLINTON": "CLI",
    "COLUMBIANA": "COL",
    "COSHOCTON": "COS",
    "CRAWFORD": "CRA",
    "CUYAHOGA": "CUY",
    "DARKE": "DAR",
    "DEFIANCE": "DEF",
    "DELAWARE": "DEL",
    "ERIE": "ERI",
    "FAIRFIELD": "FAI",
    "FAYETTE": "FAY",
    "FRANKLIN": "FRA",
    "FULTON": "FUL",
    "GALLIA": "GAL",
    "GEAUGA": "GEA",
    "GREENE": "GRE",
    "GUERNSEY": "GUE",
    "HAMILTON": "HAM",
    "HANCOCK": "HAN",
    "HARDIN": "HAR",
    "HARRISON": "HAS",
    "HENRY": "HEN",
    "HIGHLAND": "HIG",
    "HOCKING": "HOC",
    "HOLMES": "HOL",
    "HURON": "HUR",
    "JACKSON": "JAC",
    "JEFFERSON": "JEF",
    "KNOX": "KNO",
    "LAKE": "LAK",
    "LAWRENCE": "LAW",
    "LICKING": "LIC",
    "LOGAN": "LOG",
    "LORAIN": "LOR",
    "LUCAS": "LUC",
    "MADISON": "MAD",
    "MAHONING": "MAH",
    "MARION": "MAR",
    "MEDINA": "MED",
    "MEIGS": "MEG",
    "MERCER": "MER",
    "MIAMI": "MIA",
    "MONROE": "MOE",
    "MONTGOMERY": "MOT",
    "MORGAN": "MRG",
    "MORROW": "MRW",
    "MUSKINGUM": "MUS",
    "NOBLE": "NOB",
    "OTTAWA": "OTT",
    "PAULDING": "PAU",
    "PERRY": "PER",
    "PICKAWAY": "PIC",
    "PIKE": "PIK",
    "PORTAGE": "POR",
    "PREBLE": "PRE",
    "PUTNAM": "PUT",
    "RICHLAND": "RIC",
    "ROSS": "ROS",
    "SANDUSKY": "SAN",
    "SCIOTO": "SCI",
    "SENECA": "SEN",
    "SHELBY": "SHE",
    "STARK": "STA",
    "SUMMIT": "SUM",
    "TRUMBULL": "TRU",
    "TUSCARAWAS": "TUS",
    "UNION": "UNI",
    "VAN WERT": "VAN",
    "VINTON": "VIN",
    "WARREN": "WAR",
    "WASHINGTON": "WAS",
    "WAYNE": "WAY",
    "WILLIAMS": "WIL",
    "WOOD": "WOO",
    "WYANDOT": "WYA",
}

# %%
import numpy as np
# from civilpy.state.ohio.dot import ohio_counties


def get_county_from_proj_no(proj_no):
    """
    Utilizes digital paper to retrieve the 3 letter county code by searching for that Project Number
    """
    # //TODO - Sometimes the first value doesn't have a county, rewrite to try the second or third if so
    driver.get("https://contracts.dot.state.oh.us/home.do")

    search_box = driver.find_element(By.ID, "DP.PROJECT_NUM.TEXT")
    search_box.send_keys(proj_no)
    go_button = driver.find_element(
        By.XPATH,
        "/html/body/table[3]/tbody/tr[3]/td[2]/table/tbody/tr[1]/td/form/table/tbody/tr[3]/td/table/tbody/tr[2]/td[1]/input[2]",
    )
    go_button.click()

    row_data = driver.find_element(By.CLASS_NAME, "rowdata")

    for column in row_data.text.split("   "):
        if column[:5] == "COUNT":
            county = column.split("  ")[1]
        elif column[:7] == "PID_NUM":
            pid = column.split("  ")[1]
        elif column[:10] == "RT_SECTION":
            cty_rte_sec = column.split("  ")[1]
        elif column[:12] == "PROJECT_TYPE":
            proj_type = column.split("  ")[1]

    # Checks if a county value was found above and assigns NaN if not
    if not "county" in locals():
        county = np.nan

    # Converts 3 Character County Code to Full name
    if county in ohio_counties.values():
        county = list(ohio_counties.keys())[list(ohio_counties.values()).index(county)]

    return county, cty_rte_sec, pid, proj_type

# %%
get_county_from_proj_no(138012)
# Out:
# ('LICKING', 'IR-70-28.88', '81253', 'BRIDGE REPLACEMENT (1 BRIDGE)')

# %% [markdown]
# ## Creating the Database

# %%
import sqlite3

con = sqlite3.connect("output/ohio_bidtabs.db")

# %%
cur = con.cursor()

# %% [markdown]
# ## Database layout
#
# 3 Tables:
#
#     projects
#     contractors
#     bid_values

# %% [markdown]
# ```mermaid
# classDiagram
#     direction BT
#     class bid_values {
#        text item_code
#        text item_description
#        real quantity
#        real bid_amount
#        integer contractor
#        integer project
#        integer id
#     }
#     class contractors {
#        text contractor_name
#        integer number_of_wins
#        integer number_of_second
#        integer number_of_third
#        integer id
#     }
#     class projects {
#        integer number_of_sections
#        text low_bidder
#        real low_bid_amount
#        text county_cd
#        int odot_district
#        text item_codes
#        int let_date
#        integer project_number
#     }
#
#     bid_values  -->  contractors : contractor
#     bid_values  -->  projects : project
#     projects  -->  contractors : low_bidder
#
# ```

# %%
# Create the contractors table
cur.execute(
    """
create table contractors
(
    id               INTEGER not null
        constraint contractors_pk
            primary key autoincrement,
    contractor_name  TEXT,
    number_of_wins   INTEGER,
    number_of_second INTEGER,
    number_of_third  INTEGER
);
"""
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Create the contractors table
# ----> 2 cur.execute(
#       3     """
#       4 create table contractors
#       5 (
#       6     id               INTEGER not null
#       7         constraint contractors_pk
#       8             primary key autoincrement,
#       9     contractor_name  TEXT,
#      10     number_of_wins   INTEGER,
#      11     number_of_second INTEGER,
#      12     number_of_third  INTEGER
#      13 );
#      14 """
#      15 )
#
# OperationalError: table contractors already exists

# %%
# Create the projects table
cur.execute(
    """
create table projects
(
    project_number     INT not null
        constraint project_number
            primary key,
    number_of_sections INT,
    low_bidder         TEXT
        constraint projects_contractors_id_fk
            references contractors,
    low_bid_amount     REAL,
    county_cd          TEXT,
    odot_district      INT,
    cty_rte_sec        TEXT,
    pid                INT,
    proj_type          TEXT,
    let_date           TEXT,
    client             TEXT
);
"""
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Create the projects table
# ----> 2 cur.execute(
#       3     """
#       4 create table projects
#       5 (
#       6     project_number     INT not null
#       7         constraint project_number
#       8             primary key,
#       9     number_of_sections INT,
#      10     low_bidder         TEXT
#      11         constraint projects_contractors_id_fk
#      12             references contractors,
#      13     low_bid_amount     REAL,
#      14     county_cd          TEXT,
#      15     odot_district      INT,
#      16     cty_rte_sec        TEXT,
#      17     pid                INT,
#      18     proj_type          TEXT,
#      19     let_date           TEXT,
#      20     client             TEXT
#      21 );
#      22 """
#      23 )
#
# OperationalError: table projects already exists

# %%
# Create bid_values table
cur.execute(
    """
create table bid_values
(
    id         integer not null
        constraint id
            primary key autoincrement,
    item_code        TEXT,
    item_description TEXT,
    quantity         REAL,
    bid_amount       REAL,
    contractor       TEXT
        constraint contractor_name
            references contractors,
    project    integer not null
        constraint project
            references projects
);
"""
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Create bid_values table
# ----> 2 cur.execute(
#       3     """
#       4 create table bid_values
#       5 (
#       6     id         integer not null
#       7         constraint id
#       8             primary key autoincrement,
#       9     item_code        TEXT,
#      10     item_description TEXT,
#      11     quantity         REAL,
#      12     bid_amount       REAL,
#      13     contractor       TEXT
#      14         constraint contractor_name
#      15             references contractors,
#      16     project    integer not null
#      17         constraint project
#      18             references projects
#      19 );
#      20 """
#      21 )
#
# OperationalError: table bid_values already exists

# %%
import os
from pathlib import Path

file_list = [
    Path(r"C:\Users\dparks1\Documents\ODOT Bid tabs") / file
    for file in os.listdir(r"C:\Users\dparks1\Documents\ODOT Bid tabs")
]

# %% [markdown]
# ### Creating a Test Dataframe

# %%
import xlrd
import warnings
import pandas as pd
from pathlib import WindowsPath

# Use largest workbook in the list so others will be simpler (2013-03-28.xls)
test_wb_index = file_list.index(WindowsPath(r"C:\Users\dparks1\Documents\ODOT Bid tabs/2013-03-28.xls"))
excel_book = xlrd.open_workbook(
    file_list[test_wb_index], encoding_override="iso-8859-1"
)

# read by default 1st sheet of an excel file
df = pd.read_excel(excel_book, header=0)

# %%
import xlrd
import warnings
import pandas as pd
from pathlib import WindowsPath

# Use largest workbook in the list so others will be simpler (2013-03-28.xls)
test_wb_index = file_list.index(WindowsPath(r"C:\Users\dparks1\Documents\ODOT Bid tabs\2013-03-28.xls"))
excel_book = xlrd.open_workbook(
    file_list[test_wb_index], encoding_override="iso-8859-1"
)

# read by default 1st sheet of an excel file
df = pd.read_excel(excel_book, header=0)

# %% [markdown]
# ### Reformatting the Data
#
# The data needs to match the established schema layout. So three tables of bid values, contractors, and projects, while making sure we're not duplicating entries, and incrementing values when necessary for things like the contractors `number_of_wins` columns.
#
# Helper Definitions:

# %%
# After civilpy 0.0.88 can be imported with:
# from civilpy.state.ohio.dot import odot_districts

odot_district_by_county = {
    "ALLEN": 1,
    "DEFIANCE": 1,
    "HANCOCK": 1,
    "HARDIN": 1,
    "PAULDING": 1,
    "PUTNAM": 1,
    "VAN WERT": 1,
    "WYANDOT": 1,
    "FULTON": 2,
    "HENRY": 2,
    "LUCAS": 2,
    "OTTAWA": 2,
    "SANDUSKY": 2,
    "SENECA": 2,
    "WILLIAMS": 2,
    "WOOD": 2,
    "ASHLAND": 3,
    "CRAWFORD": 3,
    "ERIE": 3,
    "HURON": 3,
    "LORAIN": 3,
    "MEDINA": 3,
    "RICHLAND": 3,
    "WAYNE": 3,
    "ASHTABULA": 4,
    "MAHONING": 4,
    "PORTAGE": 4,
    "STARK": 4,
    "SUMMIT": 4,
    "TRUMBULL": 4,
    "COSHOCTON": 5,
    "FAIRFIELD": 5,
    "GUERNSEY": 5,
    "KNOX": 5,
    "LICKING": 5,
    "MUSKINGUM": 5,
    "PERRY": 5,
    "DELAWARE": 6,
    "FAYETTE": 6,
    "FRANKLIN": 6,
    "MADISON": 6,
    "MARION": 6,
    "MORROW": 6,
    "PICKAWAY": 6,
    "UNION": 6,
    "AUGLAIZE": 7,
    "CHAMPAIGN": 7,
    "CLARK": 7,
    "DARKE": 7,
    "LOGAN": 7,
    "MERCER": 7,
    "MIAMI": 7,
    "MONTGOMERY": 7,
    "SHELBY": 7,
    "BUTLER": 8,
    "CLERMONT": 8,
    "CLINTON": 8,
    "GREENE": 8,
    "HAMILTON": 8,
    "PREBLE": 8,
    "WARREN": 8,
    "ADAMS": 9,
    "BROWN": 9,
    "HIGHLAND": 9,
    "JACKSON": 9,
    "LAWRENCE": 9,
    "PIKE": 9,
    "ROSS": 9,
    "SCIOTO": 9,
    "ATHENS": 10,
    "GALLIA": 10,
    "HOCKING": 10,
    "MEIGS": 10,
    "MONROE": 10,
    "MORGAN": 10,
    "NOBLE": 10,
    "VINTON": 10,
    "WASHINGTON": 10,
    "BELMONT": 11,
    "CARROLL": 11,
    "COLUMBIANA": 11,
    "HARRISON": 11,
    "HOLMES": 11,
    "JEFFERSON": 11,
    "TUSCARAWAS": 11,
    "CUYAHOGA": 12,
    "GEAUGA": 12,
    "LAKE": 12,
}

# %%
import datetime
import xlrd
import warnings
import pandas as pd

# %% [markdown]
# #### projects Table

# %%
def get_projects_from_excel(excel_file):
    """
    Function that takes the ODOT BidTabs Excel File, Loads it into a Dataframe,
    Extracts the necessary details out of it, pushes the formatted table to a database
    and returns the formatted dataframe object

    :param:
        excel_file (Path): Path to the excel file containing the data
    """
    # load the excel file
    excel_book = xlrd.open_workbook(excel_file, encoding_override="iso-8859-1")

    # read by default 1st sheet of an excel file
    df = pd.read_excel(excel_book, header=0)

    # Extract the projects that are included in the data
    projects = pd.DataFrame(df["Project#"].unique(), columns=["project_number"])

    # Create a column for number of sections and fill it with values:
    projects.insert(1, "number_of_sections", None)

    # Fill the above row with the calculated values
    for index, project in projects.iterrows():
        projects.at[index, "number_of_sections"] = len(
            df[df["Project#"] == project.values[0]]["Section"].unique()
        )

    # Create low_bidder column
    projects.insert(2, "low_bidder", None)

    # Fill low_bidder with the values
    for index, project in projects.iterrows():
        projects.at[index, "low_bidder"] = df.loc[
            (df["Project#"] == project.project_number) & (df["BidderOrder"] == 1)
        ]["Name"].values[0]

    # Create low_bid_amount Column
    projects.insert(3, "low_bid_amount", None)

    # Fill low_bid_amount column
    for index, project in projects.iterrows():
        projects.at[index, "low_bid_amount"] = df.loc[
            (df["Project#"] == project.project_number) & (df["BidderOrder"] == 1)
        ]["Bid$"].values[0]

    # Create county_cd Column
    projects.insert(4, "county_cd", None)

    # Fill county_cd column
    for index, project in projects.iterrows():
        try:
            county_code, cty_rte_sec, pid, proj_type = get_county_from_proj_no(
                project.project_number
            )
        except:
            county_code, cty_rte_sec, pid, proj_type = np.nan, np.nan, np.nan, np.nan
        projects.at[index, "county_cd"] = county_code

    # Create odot_distric Column
    projects.insert(5, "odot_district", None)

    # Fill odot_district column
    for index, project in projects.iterrows():
        if project.county_cd in odot_district_by_county:
            projects.at[index, "odot_district"] = odot_district_by_county[
                project.county_cd
            ]
        elif str(project.county_cd)[0] == "D":
            projects.at[index, "odot_district"] = project.county_cd[1:].strip("0")
        else:
            print(project.county_cd)

    # Create cty_rte_sec Column
    projects.insert(6, "cty_rte_sec", None)

    # Fill cty_rte_sec column
    for index, project in projects.iterrows():
        projects.at[index, "cty_rte_sec"] = cty_rte_sec

    # Create pid Column
    projects.insert(7, "pid", None)

    # Fill pid column
    for index, project in projects.iterrows():
        projects.at[index, "pid"] = pid

    # Create proj_type Column
    projects.insert(8, "proj_type", None)

    # Fill proj_type column
    for index, project in projects.iterrows():
        projects.at[index, "proj_type"] = proj_type

    # Create let_date Column
    projects.insert(9, "let_date", None)

    # Store time as string
    for index, project in projects.iterrows():
        excel_date = str(df[df["Project#"] == project.values[0]]["LetDate"].values[0])[
            :10
        ]
        projects.at[index, "let_date"] = excel_date

    # Create client Column - Can use a default value since all projects are ODOT
    projects.insert(10, "client", "ODOT")

    # Push the new table to the database
    projects.to_sql("projects", con, if_exists="append", index=False)

# %% [markdown]
# #### item_codes Table

# %% [raw]
# # Not needed since bid_values contains both columns
#
# def get_item_codes(excel_file):
#     # Extract the projects that are included in the data
#     projects = pd.DataFrame(df['Project#'].unique(), columns=['project_number'])
#
#     # Create item_codes Column
#     projects.insert(1, 'item_code', '')
#     item_codes = pd.DataFrame(columns=['project_number', 'item_code'])
#
#     # Fill the item_codes column
#     for index, project in projects.iterrows():
#         item_code_list = list(df[df['Project#'] == project.values[0]]['ItemCode'].unique())
#
#         for item_code in item_code_list:
#             item_codes.loc[len(item_codes)] = [project.values[0], item_code]
#
#     item_codes.to_sql("item_codes", con, if_exists='append', index=False)

# %% [markdown]
# #### contractors Table

# %%
def get_contractors_from_excel(excel_file):
    """
    Function that takes the ODOT BidTabs Excel File, Loads it into a Dataframe,
    Extracts the necessary details out of it, pushes the formatted table to a database
    and returns the formatted dataframe object

    :param:
        excel_file (Path): Path to the excel file containing the data
    """
    # load the excel file
    excel_book = xlrd.open_workbook(excel_file, encoding_override="iso-8859-1")

    # read by default 1st sheet of an excel file
    df = pd.read_excel(excel_book, header=0)

    # Get the counts for first, second and third place bidders
    contractor_finishes = {}

    # First Place
    for project in list(df["Project#"].unique()):
        contractor = df[(df["Project#"] == project) & (df["BidderOrder"] == 1)][
            "Name"
        ].values[0]

        if contractor in contractor_finishes:
            if 1 in contractor_finishes[contractor]:
                contractor_finishes[contractor][1] += 1
            else:
                contractor_finishes[contractor][1] = 1
        else:
            contractor_finishes[contractor] = {}
            contractor_finishes[contractor][1] = 1

    # Second Place
    for project in list(df["Project#"].unique()):
        try:
            contractor = df[(df["Project#"] == project) & (df["BidderOrder"] == 2)][
                "Name"
            ].values[0]
        except:
            continue

        if contractor in contractor_finishes:
            if 2 in contractor_finishes[contractor]:
                contractor_finishes[contractor][2] += 1
            else:
                contractor_finishes[contractor][2] = 1
        else:
            contractor_finishes[contractor] = {}
            contractor_finishes[contractor][2] = 1

    # Third Place
    for project in list(df["Project#"].unique()):
        try:
            contractor = df[(df["Project#"] == project) & (df["BidderOrder"] == 3)][
                "Name"
            ].values[0]
        except:
            continue

        if contractor in contractor_finishes:
            if 3 in contractor_finishes[contractor]:
                contractor_finishes[contractor][3] += 1
            else:
                contractor_finishes[contractor][3] = 1
        else:
            contractor_finishes[contractor] = {}
            contractor_finishes[contractor][3] = 1

    # Check with the existing entries in the database to avoid duplications
    existing_contractors_values = pd.read_sql_query("SELECT * from contractors", con)
    new_contractors_values = list(pd.DataFrame(df["Name"].unique())[0])

    # Starting with the contractors already in the database, update their values
    for contractor in existing_contractors_values["contractor_name"].values:
        if contractor in contractor_finishes:
            database_index = existing_contractors_values.index[
                existing_contractors_values["contractor_name"] == contractor
            ].values[0]
            current_wins = existing_contractors_values.iloc[database_index][
                "number_of_wins"
            ]
            current_second = existing_contractors_values.iloc[database_index][
                "number_of_second"
            ]
            current_third = existing_contractors_values.iloc[database_index][
                "number_of_third"
            ]

            if 1 in contractor_finishes[contractor]:
                existing_contractors_values.at[database_index, "number_of_wins"] = (
                    current_wins + contractor_finishes[contractor][1]
                )
                del contractor_finishes[contractor][1]
            if 2 in contractor_finishes[contractor]:
                existing_contractors_values.at[database_index, "number_of_second"] = (
                    current_second + contractor_finishes[contractor][2]
                )
                del contractor_finishes[contractor][2]
            if 3 in contractor_finishes[contractor]:
                existing_contractors_values.at[database_index, "number_of_third"] = (
                    current_third + contractor_finishes[contractor][3]
                )
                del contractor_finishes[contractor][3]
            del contractor_finishes[contractor]

    # Add the new contractors to the table
    for contractor in contractor_finishes:
        if 1 in contractor_finishes[contractor]:
            first = contractor_finishes[contractor][1]
            del contractor_finishes[contractor][1]
        else:
            first = 0
        if 2 in contractor_finishes[contractor]:
            second = contractor_finishes[contractor][2]
            del contractor_finishes[contractor][2]
        else:
            second = 0
        if 3 in contractor_finishes[contractor]:
            third = contractor_finishes[contractor][3]
            del contractor_finishes[contractor][3]
        else:
            third = 0

        # Add the new contractors to the dataframe
        existing_contractors_values.loc[len(existing_contractors_values)] = [
            len(existing_contractors_values) + 1,
            contractor,
            first,
            second,
            third,
        ]

    # Push Results to database, this one recreates the table because of the id value
    existing_contractors_values.to_sql(
        "contractors", con, if_exists="replace", index=False, index_label="id"
    )

    return existing_contractors_values

# %% [markdown]
# #### bid_values Table

# %%
def get_bid_values_from_excel(excel_file):
    """
    Function that takes the ODOT BidTabs Excel File, Loads it into a Dataframe,
    Extracts the necessary details out of it, pushes the formatted table to a database
    and returns the formatted dataframe object

    :param:
        excel_file (Path): Path to the excel file containing the data
    """
    # load the excel file
    excel_book = xlrd.open_workbook(excel_file, encoding_override="iso-8859-1")

    # read by default 1st sheet of an excel file
    df = pd.read_excel(excel_book, header=0)

    bid_values = pd.DataFrame()

    # Create item_code Column
    bid_values.insert(0, "item_code", "")
    # Create item_description Column
    bid_values.insert(1, "item_description", "")
    # Create quantity Column
    bid_values.insert(2, "quantity", "")
    # Create bid_amount Column
    bid_values.insert(3, "bid_amount", "")
    # Create contractor Column
    bid_values.insert(4, "contractor", "")
    # Create project Column
    bid_values.insert(5, "project", "")

    # id auto_increments again
    for index, value in df.iterrows():
        contract_query = "SELECT id FROM contractors WHERE contractor_name IS ?"
        try:
            contractor_index = cur.execute(contract_query, (value.Name,)).fetchone()[0]
        except:
            existing_contractors_values = pd.DataFrame(
                {
                    "contractor_name": value.Name,
                    "number_of_wins": 0,
                    "number_of_second": 0,
                    "number_of_third": 0,
                },
                index=[0],
            )
            existing_contractors_values.to_sql(
                "contractors", con, if_exists="append", index=False, index_label="id"
            )
            contractor_index = cur.execute(contract_query, (value.Name,)).fetchone()[0]

        bid_values.at[index, "item_code"] = value["ItemCode"]
        bid_values.at[index, "item_description"] = value["ItemDesc"]
        bid_values.at[index, "quantity"] = value["Qty"]
        bid_values.at[index, "bid_amount"] = value["Bid$"]
        bid_values.at[index, "contractor"] = value["Name"]
        bid_values.at[index, "project"] = value["Project#"]

    # Push Results to database, this one recreates the table because of the id value
    bid_values.to_sql(
        "bid_values", con, if_exists="append", index=False, index_label="id"
    )

# %% [markdown]
# # Running the Script to Build the Database

# %%
"""
Failed Files:
    files: D:/Data/ODOT Bid Tabs/2018-07-26.xls - Unique ID number, 
        projects were exactly the same as D:/Data/ODOT Bid Tabs/2018-07-20.xls, but with less values,
        so file 266 was deleted

Modified files to eliminate errors:
One file was converted from .xlsx to .xls format
2019-12-12.xls, 2019-12-19.xls - misformatted dates were adjusted
2021-07-01.xls - No '1' bidder, values adjusted
"""

file_list[266]
# Out:
# WindowsPath('C:/Users/dparks1/Documents/ODOT Bid tabs/2018-07-20.xls')

# %%
# Failed files: 266 - Unique ID number
start_val = 359
for index, file in enumerate(file_list[start_val:]):
    print(start_val + index, file)
    get_projects_from_excel(file)
    get_contractors_from_excel(file)
    get_bid_values_from_excel(file)
# Out:
# 359 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-07-15.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 360 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-07-16.xls
# 361 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-07-29.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 362 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-08-12.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 363 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-08-26.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 364 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-09-15.xls
# nan
# 365 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-09-16.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 366 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-09-30.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 367 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-10-14.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 368 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-10-28.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 369 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-11-18.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 370 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-12-02.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 371 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-12-15.xls
# nan
# 372 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-12-16.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 373 C:\Users\dparks1\Documents\ODOT Bid tabs\2021-12-17.xls
# 374 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-01-13.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 375 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-01-27.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 376 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-02-17.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 377 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-03-10.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 378 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-03-17.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 379 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-03-31.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 380 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-04-14.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 381 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-04-28.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 382 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-05-12.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 383 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-05-26.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 384 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-06-16.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 385 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-06-30.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 386 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-07-14.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 387 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-07-28.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 388 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-08-11.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 389 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-08-25.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 390 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-09-15.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 391 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-09-29.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 392 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-10-13.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 393 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-11-03.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 394 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-11-17.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 395 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-12-01.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 396 C:\Users\dparks1\Documents\ODOT Bid tabs\2022-12-15.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 397 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-01-12.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 398 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-01-26.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 399 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-02-16.xls
# nan
# 400 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-02-23.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 401 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-03-09.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 402 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-03-30.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 403 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-04-13.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 404 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-04-20.xls
# 405 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-04-27.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 406 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-05-11.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 407 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-05-24.xls
# 408 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-05-25.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 409 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-06-08.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 410 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-06-22.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 411 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-07-13.xls
# nan
# nan
# nan
# nan
# 412 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-07-27.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 413 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-08-10.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 414 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-08-24.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 415 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-08-31.xls
# nan
# 416 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-09-14.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 417 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-09-28.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 418 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-10-12.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 419 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-10-26.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 420 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-11-08.xls
# 421 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-11-09.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 422 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-11-17.xls
# nan
# 423 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-11-30.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 424 C:\Users\dparks1\Documents\ODOT Bid tabs\2023-12-14.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 425 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-01-11.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 426 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-01-18.xls
# nan
# 427 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-01-25.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 428 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-02-08.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 429 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-02-09.xls
# 430 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-02-22.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 431 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-03-01.xls
# nan
# nan
# 432 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-03-21.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 433 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-04-04.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 434 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-04-18.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 435 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-05-09.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 436 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-05-16.xls
# 437 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-05-23.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 438 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-06-13.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 439 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-06-27.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 440 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-07-11.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 441 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-07-18.xls
# 442 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-07-25.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 443 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-08-01.xls
# 444 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-08-08.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 445 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-08-22.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 446 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-09-12.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 447 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-09-26.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 448 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-10-04.xls
# nan
# 449 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-10-17.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 450 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-10-31.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 451 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-11-14.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 452 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-12-05.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 453 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-12-12.xls
# nan
# 454 C:\Users\dparks1\Documents\ODOT Bid tabs\2024-12-19.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 455 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-01-16.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 456 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-01-30.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 457 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-02-13.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 458 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-02-14.xls
# nan
# 459 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-02-27.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 460 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-03-20.xls
# 461 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-03-27.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 462 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-04-10.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 463 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-04-17.xls
# 464 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-04-18.xls
# 465 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-04-23.xls
# nan
# 466 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-04-24.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 467 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-05-01.xls
# nan
# 468 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-05-08.xls
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# 469 C:\Users\dparks1\Documents\ODOT Bid tabs\2025-05-15.xls
# nan
# nan
# nan

# %% [markdown]
# # Fixing Errors in the Data

# %%
"""
The Following Projects had Pointers as 'low_bid_amount' values, they were converted to 'null' values
163000,12,GREAT LAKES CONSTRUCTION CO
183001,8,AMERICAN BRIDGE COMPANY
197051,6,GEDDIS PAVING & EXCAVATING INC
173000,18,KOKOSING CONSTRUCTION COMPANY INC
122005,2,YORK MAHONING MECHANICAL CONTRACTORS INC
135003,3,SHELLY & SANDS INC
122014,3,JESS HOWARD ELECTRIC CO
122004,2,ENVIROCORE LIMITED
122017,2,RIGHTER COMPANY INC
243000,7,CAPITOL TUNNELING INC
172005,4,BUTCHER & SON EXCAVATING
122019,2,SCHIRMER CONSTRUCTION LLC
135008,3,EAGLE BRIDGE CO
132005,2,BRUMBAUGH CONSTRUCTION INC
122000,2,MORRISON INC
122007,2,PROLINE ELECTRIC INC
""";

# %% [markdown]
# # Adding Table to Link Projects to Files

# %%
# Create the files link
cur.execute(
    """
create table file_paths
(
    project_number INTEGER not null
        constraint table_name_pk
            primary key,
    file_path      TEXT
);
"""
)

# %%
def get_file_for_projects(excel_file):
    """
    Function that takes the ODOT BidTabs Excel File, Loads it into a Dataframe,
    Extracts the necessary details out of it, pushes the formatted table to a database
    and returns the formatted dataframe object

    :param:
        excel_file (Path): Path to the excel file containing the data
    """
    # load the excel file
    excel_book = xlrd.open_workbook(excel_file, encoding_override="iso-8859-1")

    # read by default 1st sheet of an excel file
    df = pd.read_excel(excel_book, header=0)

    # Extract the projects that are included in the data
    projects = pd.DataFrame(df["Project#"].unique(), columns=["project_number"])
    projects["file_path"] = str(excel_file)

    return projects
    # projects.to_sql("table_name", con, if_exists='append', index=False)

# %%
start_val = 0
for index, file in enumerate(file_list[start_val:]):
    projects = get_file_for_projects(file)
    print(file)
# Out:
# C:\Users\dparks1\Documents\ODOT Bid tabs\2011-12-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-01-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-01-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-01-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-02-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-02-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-02-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-02-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-02-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-03-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-03-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-03-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-04-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-04-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-04-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-05-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-05-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-06-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-06-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-06-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-06-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-07-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-07-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-07-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-07-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-08-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-08-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-08-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-08-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-08-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-09-06.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-09-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-09-28.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-10-04.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-10-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-11-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-11-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-11-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-11-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-11-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-12-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-12-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2012-12-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-01-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-01-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-01-31.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-02-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-02-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-02-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-02-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-03-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-03-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-03-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-03-28.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-04-04.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-04-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-04-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-04-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-05-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-05-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-05-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-05-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-05-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-05-31.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-06-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-06-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-06-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-07-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-07-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-07-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-07-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-08-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-08-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-08-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-08-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-08-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-09-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-09-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-09-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-10-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-10-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-10-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-11-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-11-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-11-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-11-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-12-05.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2013-12-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-01-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-01-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-01-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-01-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-02-06.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-02-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-02-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-02-28.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-03-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-03-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-03-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-04-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-04-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-04-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-04-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-04-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-05-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-05-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-05-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-05-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-05-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-06-05.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-06-06.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-06-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-07-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-07-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-08-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-08-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-08-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-09-04.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-09-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-09-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-10-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-10-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-10-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-10-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-10-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-10-31.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-11-06.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-11-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-11-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-11-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-12-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-12-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2014-12-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-01-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-01-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-01-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-02-05.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-02-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-02-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-03-05.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-03-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-04-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-04-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-04-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-05-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-05-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-05-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-06-04.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-06-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-06-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-06-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-07-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-07-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-07-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-07-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-07-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-07-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-07-31.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-08-06.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-08-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-08-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-09-03.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-09-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-09-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-09-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-10-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-10-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-10-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-11-05.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-11-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-12-03.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-12-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2015-12-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-01-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-01-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-01-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-01-28.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-02-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-02-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-03-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-03-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-04-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-04-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-05-05.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-05-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-05-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-05-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-06-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-06-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-06-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-07-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-07-28.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-08-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-08-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-08-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-09-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-09-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-10-06.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-10-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-10-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-11-03.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-11-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-12-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-12-06.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-12-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2016-12-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-01-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-02-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-02-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-02-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-02-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-03-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-03-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-03-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-03-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-04-06.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-04-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-04-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-05-04.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-05-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-05-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-05-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-05-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-06-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-06-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-06-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-06-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-07-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-07-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-08-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-08-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-09-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-09-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-09-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-10-05.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-10-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-11-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-11-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-11-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-12-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2017-12-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-01-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-01-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-02-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-02-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-02-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-02-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-03-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-03-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-03-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-03-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-04-05.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-04-06.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-04-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-05-03.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-05-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-05-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-05-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-06-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-06-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-06-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-06-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-06-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-06-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-07-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-07-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-07-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-08-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-08-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-09-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-10-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-10-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-10-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-11-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-11-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-11-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-12-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-12-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2018-12-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-01-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-01-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-01-31.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-02-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-02-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-03-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-03-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-03-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-04-04.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-04-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-04-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-04-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-05-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-05-03.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-05-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-05-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-06-06.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-06-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-07-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-07-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-08-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-08-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-08-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-08-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-09-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-09-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-09-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-10-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-10-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-11-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-11-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-12-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-12-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2019-12-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-01-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-01-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-01-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-02-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-02-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-02-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-03-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-03-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-04-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-04-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-04-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-04-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-04-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-05-07.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-05-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-05-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-06-04.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-06-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-06-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-07-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-07-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-07-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-08-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-08-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-09-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-10-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-10-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-11-05.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-11-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-12-03.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2020-12-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-01-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-01-28.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-02-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-02-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-03-04.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-03-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-04-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-04-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-04-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-04-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-05-06.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-05-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-05-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-06-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-07-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-07-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-07-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-07-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-08-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-08-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-09-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-09-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-09-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-10-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-10-28.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-11-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-12-02.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-12-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-12-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2021-12-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-01-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-01-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-02-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-03-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-03-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-03-31.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-04-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-04-28.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-05-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-05-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-06-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-06-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-07-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-07-28.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-08-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-08-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-09-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-09-29.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-10-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-11-03.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-11-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-12-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2022-12-15.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-01-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-01-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-02-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-02-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-03-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-03-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-04-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-04-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-04-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-05-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-05-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-05-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-06-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-06-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-07-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-07-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-08-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-08-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-08-31.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-09-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-09-28.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-10-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-10-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-11-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-11-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-11-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-11-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2023-12-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-01-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-01-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-01-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-02-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-02-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-02-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-03-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-03-21.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-04-04.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-04-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-05-09.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-05-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-05-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-06-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-06-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-07-11.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-07-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-07-25.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-08-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-08-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-08-22.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-09-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-09-26.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-10-04.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-10-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-10-31.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-11-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-12-05.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-12-12.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2024-12-19.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-01-16.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-01-30.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-02-13.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-02-14.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-02-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-03-20.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-03-27.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-04-10.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-04-17.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-04-18.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-04-23.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-04-24.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-05-01.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-05-08.xls
# C:\Users\dparks1\Documents\ODOT Bid tabs\2025-05-15.xls

# %% [markdown]
# # Query the Database and Graph a Result

# %%
query = """
SELECT * FROM bid_values
    WHERE item_code
        is '202E11001'
            ORDER BY item_description
"""

# %%
results = cur.execute(query)

# %%
item_202E11001 = results.fetchall()

# %%
item_202E11001
# Out:
# [(5422,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   818205.6,
#   'SHELLY & SANDS INC',
#   120004),
#  (5423,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   824217.6,
#   'BUDS INC',
#   120004),
#  (5424,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   826321.75,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   120004),
#  (5425,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   869889.94,
#   'DOUBLE Z CONSTRUCTION COMPANY',
#   120004),
#  (5426,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   969196.43,
#   'GEORGE J IGEL & CO INC',
#   120004),
#  (8930,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   89440.52,
#   'ACI CONST CO INC',
#   120016),
#  (8931,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   93999.0,
#   'HELMS AND SONS EXCAVATING',
#   120016),
#  (8932,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   104133.05,
#   'R & I CONSTRUCTION INC',
#   120016),
#  (8933,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   107165.5,
#   'GEDDIS PAVING & EXCAVATING INC',
#   120016),
#  (8934,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   108907.41,
#   'CRESTLINE PAVING & EXCAVATING CO INC',
#   120016),
#  (8935,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   110345.28,
#   'BCC OHIO INC',
#   120016),
#  (8936,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   110523.78,
#   'R G ZACHRICH CONSTRUCTION INC',
#   120016),
#  (8937,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   111969.5,
#   'RIETSCHLIN CONSTRUCTION INC',
#   120016),
#  (8938,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   112169.23,
#   'SCHALK BROTHERS INC',
#   120016),
#  (8939,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   113841.4,
#   'MARK HAYNES CONSTRUCTION INC',
#   120016),
#  (8940,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   129792.0,
#   'PAGE EXCAVATING INC',
#   120016),
#  (18490,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   362868.59,
#   'HELMS AND SONS EXCAVATING',
#   120034),
#  (18491,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   373167.92,
#   'SAND RIDGE EXCAVATING',
#   120034),
#  (18492,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   388507.0,
#   'VTF EXCAVATING LLC',
#   120034),
#  (18493,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   419146.55,
#   'ACI CONST CO INC',
#   120034),
#  (18494,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   423535.19,
#   'R G ZACHRICH CONSTRUCTION INC',
#   120034),
#  (18495,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   423913.95,
#   'DIGIOIA-SUBURBAN EXCAVATING LLC',
#   120034),
#  (18496,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   426759.8,
#   'MILLER CONTRACTING GROUP INC',
#   120034),
#  (18497,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   466766.07,
#   'GERKEN PAVING INC',
#   120034),
#  (18498,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   472917.04,
#   'BCC OHIO INC',
#   120034),
#  (18499,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   491235.0,
#   'RIETSCHLIN CONSTRUCTION INC',
#   120034),
#  (18500,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   504703.74,
#   'SHELLY COMPANY',
#   120034),
#  (18501,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   552517.84,
#   'CRESTLINE PAVING & EXCAVATING CO INC',
#   120034),
#  (18502,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   566241.37,
#   'VERNON NAGEL INC',
#   120034),
#  (18620,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   362868.59,
#   'HELMS AND SONS EXCAVATING',
#   120034),
#  (18621,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   373167.92,
#   'SAND RIDGE EXCAVATING',
#   120034),
#  (18622,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   388507.0,
#   'VTF EXCAVATING LLC',
#   120034),
#  (18623,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   419146.55,
#   'ACI CONST CO INC',
#   120034),
#  (18624,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   423535.19,
#   'R G ZACHRICH CONSTRUCTION INC',
#   120034),
#  (18625,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   423913.95,
#   'DIGIOIA-SUBURBAN EXCAVATING LLC',
#   120034),
#  (18626,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   426759.8,
#   'MILLER CONTRACTING GROUP INC',
#   120034),
#  (18627,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   466766.07,
#   'GERKEN PAVING INC',
#   120034),
#  (18628,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   472917.04,
#   'BCC OHIO INC',
#   120034),
#  (18629,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   491235.0,
#   'RIETSCHLIN CONSTRUCTION INC',
#   120034),
#  (18630,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   504703.74,
#   'SHELLY COMPANY',
#   120034),
#  (18631,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   552517.84,
#   'CRESTLINE PAVING & EXCAVATING CO INC',
#   120034),
#  (18632,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   566241.37,
#   'VERNON NAGEL INC',
#   120034),
#  (23384,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   189757.05,
#   'GERKEN PAVING INC',
#   120054),
#  (23385,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   191713.87,
#   'HELMS AND SONS EXCAVATING',
#   120054),
#  (23386,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   198653.02,
#   'SCHALK BROTHERS INC',
#   120054),
#  (23387,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   198744.26,
#   'MILLER CONTRACTING GROUP INC',
#   120054),
#  (23388,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   205996.07,
#   'R G ZACHRICH CONSTRUCTION INC',
#   120054),
#  (23389,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   207963.4,
#   'DIGIOIA-SUBURBAN EXCAVATING LLC',
#   120054),
#  (23390,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   208441.69,
#   'VTF EXCAVATING LLC',
#   120054),
#  (23391,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   211827.0,
#   'ACI CONST CO INC',
#   120054),
#  (23392,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   213404.15,
#   'NOREASTERN OF OHIO CONTRACTING INC',
#   120054),
#  (23393,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   214777.2,
#   'SCHOEN INC',
#   120054),
#  (23394,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   215468.96,
#   'BCC OHIO INC',
#   120054),
#  (23395,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   222746.0,
#   'RIETSCHLIN CONSTRUCTION INC',
#   120054),
#  (23396,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   229079.85,
#   'VERNON NAGEL INC',
#   120054),
#  (23397,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   232474.7,
#   'GEDDIS PAVING & EXCAVATING INC',
#   120054),
#  (23398,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   244856.16,
#   'CRESTLINE PAVING & EXCAVATING CO INC',
#   120054),
#  (23399,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   258731.46,
#   'GEO GRADEL CO',
#   120054),
#  (167593,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   4541367.97,
#   'MARUCCI & GAFFNEY EXCAVATING CO',
#   120568),
#  (167594,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   3938911.84,
#   'FECHKO EXCAVATING INC',
#   120568),
#  (167595,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   4597255.04,
#   'KARVO PAVING COMPANY',
#   120568),
#  (167596,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   4606043.64,
#   'S E T INC',
#   120568),
#  (167597,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   4764139.9,
#   'WENGER EXCAVATING INC',
#   120568),
#  (167598,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   5225331.18,
#   'CENTRAL-ALLIED ENTERPRISES INC',
#   120568),
#  (167689,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   4541367.97,
#   'MARUCCI & GAFFNEY EXCAVATING CO',
#   120568),
#  (167690,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   3938911.84,
#   'FECHKO EXCAVATING INC',
#   120568),
#  (167691,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   4597255.04,
#   'KARVO PAVING COMPANY',
#   120568),
#  (167692,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   4606043.64,
#   'S E T INC',
#   120568),
#  (167693,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   4764139.9,
#   'WENGER EXCAVATING INC',
#   120568),
#  (167694,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   5225331.18,
#   'CENTRAL-ALLIED ENTERPRISES INC',
#   120568),
#  (175561,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   402687.9,
#   'SUBURBAN MAINTENANCE & CONSTRUCTION INC',
#   120597),
#  (175562,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   399646.25,
#   'SHELLY & SANDS INC',
#   120597),
#  (175563,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   419111.5,
#   'UNION INDUSTRIAL CONTRACTORS INC',
#   120597),
#  (188603,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   5247539.88,
#   'MILLER BROS CONST INC',
#   120607),
#  (188604,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   5297373.23,
#   'VERNON NAGEL INC',
#   120607),
#  (188605,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   5460283.98,
#   'SUBURBAN MAINTENANCE & CONSTRUCTION INC',
#   120607),
#  (225076,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1937018.42,
#   'MARUCCI & GAFFNEY EXCAVATING CO',
#   138001),
#  (225077,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1971000.0,
#   "A P O'HORO COMPANY",
#   138001),
#  (225078,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2009974.2,
#   'J D WILLIAMSON CONSTRUCTION CO INC',
#   138001),
#  (225079,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2130032.01,
#   'DOT CONSTRUCTION CORP',
#   138001),
#  (225080,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2323338.4,
#   'BECDIR CONSTRUCTION COMPANY',
#   138001),
#  (272561,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2717392.16,
#   'JOHN R JURGENSEN COMPANY',
#   130131),
#  (272562,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2830613.31,
#   'SUNESIS CONSTRUCTION CO',
#   130131),
#  (272563,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2888759.01,
#   'EAGLE BRIDGE CO',
#   130131),
#  (272564,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2932054.02,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   130131),
#  (272565,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2943235.28,
#   'BARRETT PAVING MATERIALS INC',
#   130131),
#  (272566,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   3005083.93,
#   'BECDIR CONSTRUCTION COMPANY',
#   130131),
#  (273165,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   599679.75,
#   'MOSSER CONSTRUCTION INC',
#   130135),
#  (273166,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   628325.5,
#   'BECDIR CONSTRUCTION COMPANY',
#   130135),
#  (273167,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   657376.25,
#   'ECLIPSE CO LLC',
#   130135),
#  (273168,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   699283.17,
#   'STEVENS ENGINEERS & CONSTRUCTORS INC',
#   130135),
#  (273169,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   885415.39,
#   'SUBURBAN MAINTENANCE & CONSTRUCTION INC',
#   130135),
#  (279412,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   217025.4,
#   'PARKER CORPORATION',
#   130157),
#  (279413,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   218836.5,
#   'CROSS ROADS CONSTRUCTION INC',
#   130157),
#  (279414,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   221350.0,
#   'FOILL INC',
#   130157),
#  (279415,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   225666.6,
#   'D G M INC',
#   130157),
#  (279416,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   235033.31,
#   'BUDS INC',
#   130157),
#  (279417,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   247187.5,
#   'D V WEBER CONSTRUCTION',
#   130157),
#  (279418,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   248609.43,
#   'MCVOYT CONSTRUCTION COMPANY INC',
#   130157),
#  (279419,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   253695.65,
#   'SHELLY & SANDS INC',
#   130157),
#  (279420,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   269723.4,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   130157),
#  (323211,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   647419.42,
#   'VTF EXCAVATING LLC',
#   130272),
#  (323212,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   654443.17,
#   'R B JERGENS CONTRACTORS INC',
#   130272),
#  (323213,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   658809.73,
#   'JOHN R JURGENSEN COMPANY',
#   130272),
#  (323214,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   690957.9,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   130272),
#  (323215,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   713678.52,
#   'EAGLE BRIDGE CO',
#   130272),
#  (323216,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   737578.0,
#   'BRUMBAUGH CONSTRUCTION INC',
#   130272),
#  (339989,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   408765.56,
#   'R W ROBINSON INC',
#   130325),
#  (379784,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   732952.67,
#   'RIGHTER COMPANY INC',
#   130511),
#  (379785,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   765330.25,
#   'RATZLAFF CONSTRUCTION COMPANY INC',
#   130511),
#  (379786,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   802445.75,
#   'RIETSCHLIN CONSTRUCTION INC',
#   130511),
#  (379787,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   805833.27,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   130511),
#  (379788,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   821626.35,
#   'SHELLY & SANDS INC',
#   130511),
#  (379789,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   888116.0,
#   'DOT CONSTRUCTION CORP',
#   130511),
#  (379790,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   946229.9,
#   'D G M INC',
#   130511),
#  (390890,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2770719.12,
#   'KARVO PAVING COMPANY',
#   130540),
#  (390891,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2798794.39,
#   'DIGIOIA-SUBURBAN EXCAVATING LLC',
#   130540),
#  (390892,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   3103049.25,
#   'RONYAK PAVING INC',
#   130540),
#  (390893,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   3149053.95,
#   'SHELLY & SANDS INC',
#   130540),
#  (390894,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   3390686.22,
#   'FECHKO EXCAVATING INC',
#   130540),
#  (403288,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   713341.0,
#   'ALAN STONE CO INC',
#   138047),
#  (403289,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   719908.5,
#   'D G M INC',
#   138047),
#  (403290,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   733561.85,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   138047),
#  (403291,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   736960.85,
#   'SHELLY & SANDS INC',
#   138047),
#  (403292,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   762566.99,
#   'VELOTTA COMPANY',
#   138047),
#  (403293,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   765514.34,
#   'RIGHTER COMPANY INC',
#   138047),
#  (403294,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   788383.0,
#   'DOUBLE Z CONSTRUCTION COMPANY',
#   138047),
#  (403295,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   869991.7,
#   'TOM MAYLE & SONS CONSTRUCTION INC',
#   138047),
#  (403296,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   913417.4,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   138047),
#  (403648,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   713341.0,
#   'ALAN STONE CO INC',
#   138047),
#  (403649,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   719908.5,
#   'D G M INC',
#   138047),
#  (403650,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   733561.85,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   138047),
#  (403651,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   736960.85,
#   'SHELLY & SANDS INC',
#   138047),
#  (403652,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   762566.99,
#   'VELOTTA COMPANY',
#   138047),
#  (403653,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   765514.34,
#   'RIGHTER COMPANY INC',
#   138047),
#  (403654,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   788383.0,
#   'DOUBLE Z CONSTRUCTION COMPANY',
#   138047),
#  (403655,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   869991.7,
#   'TOM MAYLE & SONS CONSTRUCTION INC',
#   138047),
#  (403656,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   913417.4,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   138047),
#  (446796,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2710831.04,
#   'R B JERGENS CONTRACTORS INC',
#   140067),
#  (446797,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2751106.6,
#   'MILCON CONCRETE INC',
#   140067),
#  (446798,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2852663.74,
#   'JOHN R JURGENSEN COMPANY',
#   140067),
#  (446799,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2973472.45,
#   'BARRETT PAVING MATERIALS INC',
#   140067),
#  (446800,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   3088420.0,
#   'BRUMBAUGH CONSTRUCTION INC',
#   140067),
#  (446801,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   3735963.54,
#   'SUNESIS CONSTRUCTION CO',
#   140067),
#  (446926,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   168393.56,
#   'STANLEY MILLER CONSTRUCTION COMPANY',
#   140068),
#  (446927,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   168857.95,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   140068),
#  (446928,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   172780.25,
#   'CROSS ROADS CONSTRUCTION INC',
#   140068),
#  (446929,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   177139.3,
#   'DENNISON BRIDGE INC',
#   140068),
#  (446930,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   184870.5,
#   'LOCKHART CONCRETE CO',
#   140068),
#  (446931,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   207503.0,
#   'BOG CONSTRUCTION INC',
#   140068),
#  (446932,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   208719.1,
#   'DOT CONSTRUCTION CORP',
#   140068),
#  (446933,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   214655.5,
#   'CENTRAL-ALLIED ENTERPRISES INC',
#   140068),
#  (446934,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   256575.2,
#   'ALAN STONE CO INC',
#   140068),
#  (446935,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   279909.35,
#   'JAMES WHITE CONSTRUCTION COMPANY',
#   140068),
#  (470490,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   660800.9,
#   'CROSS ROADS CONSTRUCTION INC',
#   140139),
#  (470491,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   712961.6,
#   'MR EXCAVATOR INC',
#   140139),
#  (470492,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   718109.0,
#   'R W ROBINSON INC',
#   140139),
#  (470493,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   735030.6,
#   'SHELLY & SANDS INC',
#   140139),
#  (470494,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   747915.0,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   140139),
#  (470495,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   749897.8,
#   'WENGER EXCAVATING INC',
#   140139),
#  (470496,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   774680.91,
#   'STANLEY MILLER CONSTRUCTION COMPANY',
#   140139),
#  (470497,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   789891.0,
#   'LOCKHART CONCRETE CO',
#   140139),
#  (470498,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   792189.75,
#   'BLACK HORSE BRIDGE CONSTRUCTION INC',
#   140139),
#  (568781,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1255242.4,
#   'R & I CONSTRUCTION INC',
#   140442),
#  (568782,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1256723.95,
#   'RIETSCHLIN CONSTRUCTION INC',
#   140442),
#  (568783,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1261134.06,
#   'MOSSER CONSTRUCTION INC',
#   140442),
#  (568784,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1286058.43,
#   'R G ZACHRICH CONSTRUCTION INC',
#   140442),
#  (568785,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1298222.45,
#   'VERNON NAGEL INC',
#   140442),
#  (568786,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1359872.11,
#   'EAGLE BRIDGE CO',
#   140442),
#  (568787,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1471241.75,
#   'DOT CONSTRUCTION CORP',
#   140442),
#  (610770,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   132063941.1,
#   'KOKOSING CONSTRUCTION COMPANY INC',
#   140485),
#  (610771,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   139631896.16,
#   'MOSSER - MILLER - BEAVER - JV',
#   140485),
#  (610772,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   143307017.39,
#   'WALSH CONSTRUCTION COMPANY',
#   140485),
#  (610773,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   147588461.86,
#   'TRUMBULL CORPORATION',
#   140485),
#  (616510,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   520958.8,
#   'D G M INC',
#   140561),
#  (616511,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   539995.55,
#   'TOM MAYLE & SONS CONSTRUCTION INC',
#   140561),
#  (616512,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   581183.05,
#   'RIETSCHLIN CONSTRUCTION INC',
#   140561),
#  (616513,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   587472.9,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   140561),
#  (616514,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   605512.28,
#   'SHELLY & SANDS INC',
#   140561),
#  (616515,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   609572.19,
#   'SUNESIS CONSTRUCTION CO',
#   140561),
#  (616516,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   656580.12,
#   'OHIO BRIDGE CORPORATION',
#   140561),
#  (626228,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   434308.25,
#   'SUBURBAN MAINTENANCE & CONSTRUCTION INC',
#   148038),
#  (626229,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   441990.0,
#   'BURTON SCOT CONTRACTORS LLC',
#   148038),
#  (626230,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   527724.0,
#   'F BUDDIE CONTRACTING LTD',
#   148038),
#  (626231,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   599333.0,
#   'INDEPENDENCE EXCAVATING INC',
#   148038),
#  (626232,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   740170.63,
#   'RUHLIN COMPANY',
#   148038),
#  (626268,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   141536.0,
#   'APEX CONSTRUCTION AND MANAGEMENT CO INC',
#   142011),
#  (626269,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   119693.8,
#   'M DOWNING CONSTRUCTION COMPANY INC',
#   142011),
#  (626270,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   143466.7,
#   'STERLING PROFESSIONAL GROUP LLC',
#   142011),
#  (626271,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   158744.0,
#   'ALABASI CONSTRUCTION INC',
#   142011),
#  (626272,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   195887.0,
#   'UNION INDUSTRIAL CONTRACTORS INC',
#   142011),
#  (626273,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   216668.5,
#   'ANTHONY ALLEGA CEMENT CONTRACTOR INC',
#   142011),
#  (626274,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   235902.5,
#   'SCHIRMER CONSTRUCTION COMPANY',
#   142011),
#  (633905,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   413944.24,
#   'COX PAVING LLC',
#   150009),
#  (633906,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   414711.2,
#   'BUDS INC',
#   150009),
#  (633907,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   419000.0,
#   'DOUBLE Z CONSTRUCTION COMPANY',
#   150009),
#  (633908,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   421184.5,
#   'SHELLY & SANDS INC',
#   150009),
#  (633909,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   422359.3,
#   'D G M INC',
#   150009),
#  (633910,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   426887.4,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   150009),
#  (633911,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   451356.72,
#   'EAGLE BRIDGE CO',
#   150009),
#  (633912,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   459124.0,
#   'MC DANIELS CONSTRUCTION CORP INC',
#   150009),
#  (633913,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   484704.25,
#   'COLUMBUS ASPHALT PAVING INC',
#   150009),
#  (646810,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   412165.35,
#   'OHIO-WEST VIRGINIA EXCAVATING CO',
#   150047),
#  (646811,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   669990.0,
#   'TOM MAYLE & SONS CONSTRUCTION INC',
#   150047),
#  (646812,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   698415.2,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   150047),
#  (646813,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   834169.2,
#   'SHELLY & SANDS INC',
#   150047),
#  (677476,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   322075.35,
#   'RIETSCHLIN CONSTRUCTION INC',
#   150125),
#  (677477,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   328178.82,
#   'CRAWFORD CONSTRUCTION COMPANY INC',
#   150125),
#  (677478,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   369999.96,
#   'SHELLY & SANDS INC',
#   150125),
#  (677479,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   373822.2,
#   'RIGHTER COMPANY INC',
#   150125),
#  (677480,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   505422.85,
#   'R W ROBINSON INC',
#   150125),
#  (684362,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   311574.61,
#   'PAGE EXCAVATING INC',
#   150140),
#  (684363,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   325227.73,
#   'ECLIPSE CO LLC',
#   150140),
#  (684364,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   334490.6,
#   'MARK HAYNES CONSTRUCTION INC',
#   150140),
#  (684365,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   337661.8,
#   'FABRIZI TRUCKING & PAVING CO INC',
#   150140),
#  (684366,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   341119.9,
#   'R W ROBINSON INC',
#   150140),
#  (684367,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   346335.15,
#   'SIMONSON CONSTRUCTION SERVICES INC',
#   150140),
#  (684368,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   364325.91,
#   'MR EXCAVATOR INC',
#   150140),
#  (684369,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   382140.0,
#   'LOCKHART CONCRETE CO',
#   150140),
#  (690205,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   198198.75,
#   'GEDDIS PAVING & EXCAVATING INC',
#   150160),
#  (690206,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   219241.0,
#   'VERNON NAGEL INC',
#   150160),
#  (690207,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   228734.2,
#   'CRESTLINE PAVING & EXCAVATING CO INC',
#   150160),
#  (690208,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   235121.35,
#   'SAND RIDGE EXCAVATING',
#   150160),
#  (693160,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   41496959.26,
#   'GREAT LAKES CONSTRUCTION CO',
#   150057),
#  (693161,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   42848591.98,
#   'TERRACE CONSTRUCTION CO INC',
#   150057),
#  (693162,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   45935294.3,
#   'ANTHONY ALLEGA CEMENT CONTRACTOR INC',
#   150057),
#  (693163,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   48814353.65,
#   'KARVO PAVING COMPANY',
#   150057),
#  (705661,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   172310.0,
#   'SCHALK BROTHERS INC',
#   150194),
#  (705662,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   179241.4,
#   'MARK HAYNES CONSTRUCTION INC',
#   150194),
#  (705663,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   194837.55,
#   'DELLINGER EXCAVATING INC',
#   150194),
#  (705664,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   205312.4,
#   'VERNON NAGEL INC',
#   150194),
#  (705665,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   206373.75,
#   'UNILLIANCE INC',
#   150194),
#  (705666,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   238247.0,
#   'R W ROBINSON INC',
#   150194),
#  (705667,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   305067.98,
#   'ECLIPSE CO LLC',
#   150194),
#  (714379,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   398444.9,
#   'BUDS INC',
#   150218),
#  (714380,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   483452.15,
#   'SHELLY & SANDS INC',
#   150218),
#  (737777,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   457933.1,
#   'BUDS INC',
#   150305),
#  (737778,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   513000.0,
#   'FOILL INC',
#   150305),
#  (737779,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   629506.25,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   150305),
#  (739084,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   239409.45,
#   'VERNON NAGEL INC',
#   150312),
#  (739085,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   251848.9,
#   'UNILLIANCE INC',
#   150312),
#  (739086,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   258038.9,
#   'MARK HAYNES CONSTRUCTION INC',
#   150312),
#  (739087,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   267118.0,
#   "B HILL'Z EXCAVATING INC",
#   150312),
#  (740223,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   255038.1,
#   'VERNON NAGEL INC',
#   150322),
#  (752686,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   506149.01,
#   'SIMONSON CONSTRUCTION SERVICES INC',
#   150357),
#  (752687,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   649786.0,
#   'LOCKHART CONCRETE CO',
#   150357),
#  (752688,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   675815.0,
#   'MARK HAYNES CONSTRUCTION INC',
#   150357),
#  (762753,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   315433.08,
#   'VERNON NAGEL INC',
#   150406),
#  (762754,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   457151.0,
#   'DELLINGER EXCAVATING INC',
#   150406),
#  (762755,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   567870.96,
#   'MASSANA CONSTRUCTION INC',
#   150406),
#  (779107,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   425143.0,
#   'VERNON NAGEL INC',
#   157007),
#  (779108,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   439236.08,
#   'RIETSCHLIN CONSTRUCTION INC',
#   157007),
#  (779109,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   583837.72,
#   'R & I CONSTRUCTION INC',
#   157007),
#  (784965,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1542532.8,
#   'BEAVER EXCAVATING COMPANY',
#   150498),
#  (784966,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1694969.48,
#   'MOUNTAINEER CONTRACTORS INC',
#   150498),
#  (784967,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1767081.62,
#   'DENNISON BRIDGE INC',
#   150498),
#  (784968,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1839450.05,
#   'TRUCCO CONSTRUCTION CO INC',
#   150498),
#  (784969,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1893351.0,
#   'SHELLY & SANDS INC',
#   150498),
#  (784970,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2098913.83,
#   'TUCSON INC',
#   150498),
#  (792338,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1639068.29,
#   'FOILL INC',
#   158036),
#  (792339,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1792370.11,
#   'ANDERZACK-PITZEN CONSTRUCTION INC',
#   158036),
#  (792340,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2181674.74,
#   'SUNESIS CONSTRUCTION CO',
#   158036),
#  (792341,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2231068.71,
#   'COX PAVING LLC',
#   158036),
#  (814861,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1342059.24,
#   'S E T INC',
#   150593),
#  (814862,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1409442.13,
#   'BURTON SCOT CONTRACTORS LLC',
#   150593),
#  (814863,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1449975.63,
#   'KARVO PAVING COMPANY',
#   150593),
#  (823607,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1388013.0,
#   'FOILL INC',
#   150613),
#  (823608,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1428716.3,
#   'BUDS INC',
#   150613),
#  (823609,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1504568.11,
#   'SHELLY & SANDS INC',
#   150613),
#  (823610,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1523196.54,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   150613),
#  (823611,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1665578.51,
#   'TRUCCO CONSTRUCTION CO INC',
#   150613),
#  (823612,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1717198.51,
#   'MASSANA CONSTRUCTION INC',
#   150613),
#  (823697,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1388013.0,
#   'FOILL INC',
#   150613),
#  (823698,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1428716.3,
#   'BUDS INC',
#   150613),
#  (823699,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1504568.11,
#   'SHELLY & SANDS INC',
#   150613),
#  (823700,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1523196.54,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   150613),
#  (823701,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1665578.51,
#   'TRUCCO CONSTRUCTION CO INC',
#   150613),
#  (823702,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1717198.51,
#   'MASSANA CONSTRUCTION INC',
#   150613),
#  (854540,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   3994196.65,
#   'OHIO-WEST VIRGINIA EXCAVATING CO',
#   160084),
#  (854541,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   4189851.0,
#   'SHELLY & SANDS INC',
#   160084),
#  (856095,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   200879.44,
#   'VTF EXCAVATION LLC',
#   160091),
#  (856096,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   207976.29,
#   'BCC OHIO INC',
#   160091),
#  (856097,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   218674.46,
#   'R G ZACHRICH CONSTRUCTION INC',
#   160091),
#  (856098,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   226066.82,
#   'VERNON NAGEL INC',
#   160091),
#  (883030,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   427184.5,
#   'BURTON SCOT CONTRACTORS LLC',
#   160146),
#  (883031,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   474115.05,
#   'ECLIPSE CO LLC',
#   160146),
#  (883032,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   474681.0,
#   'BOG CONSTRUCTION INC',
#   160146),
#  (883033,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   583911.74,
#   'MR EXCAVATOR INC',
#   160146),
#  (903020,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   941807.89,
#   'AMERICON INDUSTRIAL SERVICES LLC',
#   160258),
#  (903021,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   952650.0,
#   'R & I CONSTRUCTION INC',
#   160258),
#  (903022,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1177391.65,
#   'TRUCCO CONSTRUCTION CO INC',
#   160258),
#  (903023,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1380921.05,
#   'RIETSCHLIN CONSTRUCTION INC',
#   160258),
#  (913385,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   907984.8,
#   'JET EXCAVATING COMPANY',
#   164005),
#  (913386,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1134277.25,
#   'BOG CONSTRUCTION INC',
#   164005),
#  (913387,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1209302.55,
#   'UNION INDUSTRIAL CONTRACTORS INC',
#   164005),
#  (917953,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   9359380.87,
#   'GEORGE J IGEL & CO INC',
#   168006),
#  (917954,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   9383065.58,
#   'KOKOSING CONSTRUCTION COMPANY INC',
#   168006),
#  (917955,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   9406580.86,
#   'SHELLY & SANDS INC',
#   168006),
#  (917956,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   9868611.74,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   168006),
#  (933046,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   271556.0,
#   'RIETSCHLIN CONSTRUCTION INC',
#   160351),
#  (934499,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   438824.54,
#   'SIMONSON CONSTRUCTION SERVICES INC',
#   160358),
#  (934500,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   477997.9,
#   'RIETSCHLIN CONSTRUCTION INC',
#   160358),
#  (934501,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   575576.44,
#   'AMERICON INDUSTRIAL SERVICES LLC',
#   160358),
#  (934502,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   590749.5,
#   'MARK HAYNES CONSTRUCTION INC',
#   160358),
#  (934503,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   682061.38,
#   'STEVENS ENGINEERS & CONSTRUCTORS INC',
#   160358),
#  (935527,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   342897.3,
#   'R & I CONSTRUCTION INC',
#   160370),
#  (935528,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   359650.0,
#   'KELSTIN INC',
#   160370),
#  (935529,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   379623.75,
#   'SIMONSON CONSTRUCTION SERVICES INC',
#   160370),
#  (935530,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   463866.6,
#   'ELITE EXCAVATING COMPANY OF OHIO INC',
#   160370),
#  (938621,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   460955.55,
#   'SHELLY & SANDS INC',
#   160382),
#  (938622,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   792989.0,
#   'CRAIG EDWARD SUSANY INC',
#   160382),
#  (945884,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   866791.7,
#   'D G M INC',
#   160393),
#  (945885,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   883488.55,
#   'SUNESIS CONSTRUCTION CO',
#   160393),
#  (945886,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   921869.39,
#   'BUDS INC',
#   160393),
#  (945887,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   956900.09,
#   'SHELLY & SANDS INC',
#   160393),
#  (945888,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   973075.35,
#   'CROSS ROADS CONSTRUCTION INC',
#   160393),
#  (945889,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   988439.79,
#   'GEORGE J IGEL & CO INC',
#   160393),
#  (945890,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1022260.4,
#   'KOKOSING CONSTRUCTION COMPANY INC',
#   160393),
#  (945891,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1069318.8,
#   'TRUCCO CONSTRUCTION CO INC',
#   160393),
#  (957141,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   17024509.22,
#   'DIGIOIA-SUBURBAN EXCAVATING LLC',
#   160430),
#  (957142,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   17746082.02,
#   'FECHKO EXCAVATING INC',
#   160430),
#  (957143,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   18107857.55,
#   'FABRIZI TRUCKING & PAVING CO INC',
#   160430),
#  (957144,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   18744569.2,
#   'GREAT LAKES CONSTRUCTION CO',
#   160430),
#  (957145,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   20006615.45,
#   'KARVO COMPANIES INC',
#   160430),
#  (957146,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   21408054.08,
#   'SHELLY & SANDS INC',
#   160430),
#  (957147,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   21461768.45,
#   'S E T INC',
#   160430),
#  (957148,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   31563585.36,
#   'MOUNTAINEER CONTRACTORS INC',
#   160430),
#  (965768,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   131231.5,
#   'MARK HAYNES CONSTRUCTION INC',
#   160470),
#  (965769,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   137533.58,
#   'RUHLIN COMPANY',
#   160470),
#  (965770,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   144473.3,
#   'BAUMANN ENTERPRISES INC',
#   160470),
#  (965771,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   172911.7,
#   'TUCSON INC',
#   160470),
#  (965772,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   179416.01,
#   'STANLEY MILLER CONSTRUCTION COMPANY',
#   160470),
#  (965773,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   185383.2,
#   'GREAT LAKES CONSTRUCTION CO',
#   160470),
#  (965774,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   193339.0,
#   'LOCKHART CONCRETE CO',
#   160470),
#  (965775,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   198755.5,
#   'ECLIPSE CO LLC',
#   160470),
#  (976071,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1110048.66,
#   'AMERICON INDUSTRIAL SERVICES LLC',
#   160491),
#  (976072,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1244718.6,
#   'OHIO-WEST VIRGINIA EXCAVATING CO',
#   160491),
#  (976073,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1266523.0,
#   'BUDS INC',
#   160491),
#  (976074,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1623939.4,
#   'SHELLY & SANDS INC',
#   160491),
#  (976075,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1810527.89,
#   'MOUNTAINEER CONTRACTORS INC',
#   160491),
#  (984705,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   338435.36,
#   'PARKER CORPORATION',
#   160517),
#  (984706,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   373469.85,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   160517),
#  (984707,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   408828.35,
#   'BUDS INC',
#   160517),
#  (984708,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   418000.0,
#   'FOILL INC',
#   160517),
#  (984709,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   432284.35,
#   'SHELLY & SANDS INC',
#   160517),
#  (984710,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   433690.6,
#   'D G M INC',
#   160517),
#  (984711,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   465676.58,
#   'DISTEL CONSTRUCTION INC',
#   160517),
#  (984712,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   557104.49,
#   'ECLIPSE CO LLC',
#   160517),
#  (984713,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   680694.6,
#   'GEIGER BROTHERS INC',
#   160517),
#  (1023988,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1308133.97,
#   'ALAN STONE CO INC',
#   160613),
#  (1023989,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1349506.8,
#   'SUNESIS CONSTRUCTION CO',
#   160613),
#  (1023990,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1386990.95,
#   'SHELLY & SANDS INC',
#   160613),
#  (1023991,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1444000.0,
#   'FOILL INC',
#   160613),
#  (1023992,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1460605.14,
#   'D G M INC',
#   160613),
#  (1023993,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1506390.71,
#   'JOHN R JURGENSEN COMPANY',
#   160613),
#  (1052751,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   688129.75,
#   'ALLARD EXCAVATION LLC',
#   170067),
#  (1052752,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   893320.31,
#   'SOLID ROCK CONSTRUCTION SERVICES LLC',
#   170067),
#  (1055022,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   236176.25,
#   'BCC OHIO INC',
#   174001),
#  (1055023,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   197177.85,
#   'GREAT LAKES DEMOLITION COMPANY',
#   174001),
#  (1055024,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   230115.0,
#   'BUCKEYE EXCAVATING & CONSTRUCTION INC',
#   174001),
#  (1055025,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   232699.95,
#   'HELMS AND SONS EXCAVATING',
#   174001),
#  (1055026,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   279430.33,
#   'VERNON NAGEL INC',
#   174001),
#  (1055027,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   293998.1,
#   'ECLIPSE CO LLC',
#   174001),
#  (1066876,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1016902.88,
#   'VTF EXCAVATION LLC',
#   170119),
#  (1066877,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1044278.59,
#   'VERNON NAGEL INC',
#   170119),
#  (1066878,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1046863.0,
#   'BRUMBAUGH CONSTRUCTION INC',
#   170119),
#  (1066879,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1064785.0,
#   'CRESTLINE PAVING & EXCAVATING CO INC',
#   170119),
#  (1066880,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1145720.08,
#   'BEAVERDAM CONTRACTING INC',
#   170119),
#  (1066881,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1150685.85,
#   'GEDDIS PAVING & EXCAVATING INC',
#   170119),
#  (1085519,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   217892.51,
#   'A & B ASPHALT CORPORATION',
#   170178),
#  (1085520,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   226959.2,
#   'BARRETT PAVING MATERIALS INC',
#   170178),
#  (1101730,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   784151.85,
#   'VERNON NAGEL INC',
#   174005),
#  (1101731,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1002234.54,
#   'ECLIPSE CO LLC',
#   174005),
#  (1116128,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   3366771.0,
#   'LOCKHART CONCRETE CO',
#   170287),
#  (1116129,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   3400507.2,
#   'MOSSER CONSTRUCTION INC',
#   170287),
#  (1124216,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   688888.17,
#   'ALLARD EXCAVATION LLC',
#   170322),
#  (1124217,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   715925.55,
#   'AXIS CIVIL CONSTRUCTION LLC',
#   170322),
#  (1124218,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   824918.5,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   170322),
#  (1124219,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   899836.7,
#   'D G M INC',
#   170322),
#  (1124220,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   953685.37,
#   'FOILL INC',
#   170322),
#  (1124221,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   965940.95,
#   'SHELLY & SANDS INC',
#   170322),
#  (1128506,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   274240.6,
#   'R W ROBINSON INC',
#   170336),
#  (1128507,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   296505.5,
#   'LOCKHART CONCRETE CO',
#   170336),
#  (1128508,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   310762.91,
#   'STANLEY MILLER CONSTRUCTION COMPANY',
#   170336),
#  (1128509,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   316214.89,
#   'SIMONSON CONSTRUCTION SERVICES INC',
#   170336),
#  (1128510,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   325158.65,
#   'RIETSCHLIN CONSTRUCTION INC',
#   170336),
#  (1128511,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   347920.01,
#   'RUHLIN COMPANY',
#   170336),
#  (1128512,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   384664.34,
#   'SHELLY & SANDS INC',
#   170336),
#  (1128513,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   464741.65,
#   'PARK ENTERPRISE CONSTRUCTION CO INC',
#   170336),
#  (1139902,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   281550.0,
#   'KELSTIN INC',
#   170377),
#  (1139903,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   306933.25,
#   'RIETSCHLIN CONSTRUCTION INC',
#   170377),
#  (1139904,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   317911.6,
#   'PAGE EXCAVATING INC',
#   170377),
#  (1139905,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   320042.56,
#   'AMERICON INDUSTRIAL SERVICES LLC',
#   170377),
#  (1139906,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   338001.0,
#   'SHELLY & SANDS INC',
#   170377),
#  (1146168,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   269282.3,
#   'OHIO-WEST VIRGINIA EXCAVATING CO',
#   177015),
#  (1146169,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   279205.5,
#   'SHELLY & SANDS INC',
#   177015),
#  (1146170,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   291343.95,
#   'ALAN STONE CO INC',
#   177015),
# ...
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   403563.16,
#   'GREAT LAKES DEMOLITION COMPANY',
#   244004),
#  (2315971,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   410289.39,
#   'VERNON NAGEL INC',
#   244004),
#  (2348678,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   333432.0,
#   'SCIOTO VALLEY PAVING LLC',
#   240221),
#  (2348679,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   366480.08,
#   'COOPERS EXCAVATING LLC',
#   240221),
#  (2348680,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   366883.7,
#   'FILLMORE CONSTRUCTION',
#   240221),
#  (2348681,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   413014.2,
#   'ALAN STONE CO INC',
#   240221),
#  (2348682,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   431835.2,
#   'D G M INC',
#   240221),
#  (2348683,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   458996.8,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   240221),
#  (2348684,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   473343.28,
#   'AXIS CIVIL CONSTRUCTION LLC',
#   240221),
#  (2355777,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   554294.62,
#   'ADENA CORPORATION',
#   240257),
#  (2355778,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   566253.0,
#   'ECLIPSE CO LLC',
#   240257),
#  (2355779,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   607712.0,
#   'DIGIOIA-SUBURBAN EXCAVATING LLC',
#   240257),
#  (2355780,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   616415.45,
#   'FABRIZI TRUCKING & PAVING CO INC',
#   240257),
#  (2355781,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   674774.21,
#   'STANLEY MILLER CONSTRUCTION COMPANY',
#   240257),
#  (2355782,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   948199.64,
#   'TRIAD ENGINEERING & CONTRACTING CO',
#   240257),
#  (2355783,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   1100007.0,
#   'LOCKHART CONCRETE CO',
#   240257),
#  (2373510,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   644179.05,
#   'AXIS CIVIL CONSTRUCTION LLC',
#   244016),
#  (2373511,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   604278.23,
#   'CRAWFORD CONSTRUCTION COMPANY INC',
#   244016),
#  (2373512,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   728453.25,
#   'BUDS INC',
#   244016),
#  (2373513,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   738207.5,
#   'RIETSCHLIN CONSTRUCTION INC',
#   244016),
#  (2373514,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   920237.65,
#   'ALAN STONE CO INC',
#   244016),
#  (2376513,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   277851.49,
#   'BCC OHIO INC',
#   240366),
#  (2376514,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   297347.36,
#   'ADENA CORPORATION',
#   240366),
#  (2376515,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   309490.94,
#   'RIETSCHLIN CONSTRUCTION INC',
#   240366),
#  (2376516,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   315933.33,
#   'ECLIPSE CO LLC',
#   240366),
#  (2376517,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   334194.2,
#   'DIGIOIA-SUBURBAN EXCAVATING LLC',
#   240366),
#  (2376518,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   357577.3,
#   'OHIO CONCRETE MAINTENANCE LLC',
#   240366),
#  (2426986,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   263543.1,
#   'BCC OHIO INC',
#   244026),
#  (2426987,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   283379.12,
#   'CRAWFORD CONSTRUCTION COMPANY INC',
#   244026),
#  (2426988,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   297541.37,
#   'GREAT LAKES DEMOLITION COMPANY',
#   244026),
#  (2426989,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   337597.0,
#   'KELSTIN INC',
#   244026),
#  (2435483,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   329617.91,
#   'CRAWFORD CONSTRUCTION COMPANY INC',
#   250038),
#  (2435484,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   358736.65,
#   'BCC OHIO INC',
#   250038),
#  (2435485,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   378501.0,
#   'LAYTON SERVICES',
#   250038),
#  (2435486,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   385691.48,
#   'ADENA CORPORATION',
#   250038),
#  (2435487,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   406610.09,
#   'ECLIPSE CO LLC',
#   250038),
#  (2435488,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   430209.4,
#   'ADVANCED EXCAVATING & DEMOLITION LLC',
#   250038),
#  (2435489,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   491650.0,
#   'V3 CONSTRUCTION GROUP LTD',
#   250038),
#  (2435490,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   526233.99,
#   'STANLEY MILLER CONSTRUCTION COMPANY',
#   250038),
#  (2452898,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2069998.83,
#   'SHELLY & SANDS INC',
#   250095),
#  (2452899,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2448276.71,
#   'KARVO COMPANIES INC',
#   250095),
#  (2452900,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   2740887.7,
#   'SHELLY COMPANY',
#   250095),
#  (2453316,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   473958.87,
#   'R B JERGENS CONTRACTORS INC',
#   250097),
#  (2453317,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   487831.0,
#   'DOUBLE Z CONSTRUCTION COMPANY',
#   250097),
#  (2453318,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   530000.0,
#   'BRUMBAUGH CONSTRUCTION INC',
#   250097),
#  (2453319,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   558540.0,
#   'KT HOLDEN CONSTRUCTION LLC',
#   250097),
#  (2453320,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   594155.38,
#   'JOHN R JURGENSEN COMPANY',
#   250097),
#  (2453321,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   660320.66,
#   'SUNESIS CONSTRUCTION CO',
#   250097),
#  (2453322,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   672604.25,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   250097),
#  (2456220,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   528982.65,
#   'GREAT LAKES DEMOLITION COMPANY',
#   254007),
#  (2456221,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   583897.68,
#   'CRAWFORD CONSTRUCTION COMPANY INC',
#   254007),
#  (2456228,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   528982.65,
#   'GREAT LAKES DEMOLITION COMPANY',
#   254007),
#  (2456229,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   583897.68,
#   'CRAWFORD CONSTRUCTION COMPANY INC',
#   254007),
#  (2458734,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   89805069.66,
#   'SHELLY & SANDS INC',
#   250076),
#  (2468884,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   585274.0,
#   'BOG CONSTRUCTION INC',
#   254009),
#  (2468885,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   549605.5,
#   'ED WILSON SERVICES LLC',
#   254009),
#  (2468886,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   647000.0,
#   'SHOOK COMPANY LLC',
#   254009),
#  (2468887,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   946336.07,
#   'MADEX CONSTRUCTION CO',
#   254009),
#  (2501065,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   370071.41,
#   'BCC OHIO INC',
#   250260),
#  (2501066,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   410454.0,
#   'ECLIPSE CO LLC',
#   250260),
#  (2501067,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN',
#   1.0,
#   439206.62,
#   'ADENA CORPORATION',
#   250260),
#  (1824879,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN  (60"x108" BOX CULV',
#   1.0,
#   218448.92,
#   'AXIS CIVIL CONSTRUCTION LLC',
#   214001),
#  (1824880,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN  (60"x108" BOX CULV',
#   1.0,
#   245234.69,
#   'HEAVY HIGHWAY CONSTRUCTION COMPANY LLC',
#   214001),
#  (1824881,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN  (60"x108" BOX CULV',
#   1.0,
#   284285.15,
#   'ALAN STONE CO INC',
#   214001),
#  (1824882,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN  (60"x108" BOX CULV',
#   1.0,
#   296676.02,
#   'ECLIPSE CO LLC',
#   214001),
#  (1824883,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN  (60"x108" BOX CULV',
#   1.0,
#   303340.8,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   214001),
#  (1761124,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (EXISTING 60"x96" B',
#   1.0,
#   473229.32,
#   'SHELLY COMPANY',
#   200518),
#  (1761125,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (EXISTING 60"x96" B',
#   1.0,
#   486833.3,
#   'FILLMORE CONSTRUCTION',
#   200518),
#  (1761126,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (EXISTING 60"x96" B',
#   1.0,
#   489916.03,
#   'ALLARD EXCAVATION LLC',
#   200518),
#  (1761127,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (EXISTING 60"x96" B',
#   1.0,
#   490467.5,
#   'D G M INC',
#   200518),
#  (1761128,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (EXISTING 60"x96" B',
#   1.0,
#   507849.27,
#   'ECLIPSE CO LLC',
#   200518),
#  (1761129,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (EXISTING 60"x96" B',
#   1.0,
#   524176.67,
#   'ALAN STONE CO INC',
#   200518),
#  (1761130,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (EXISTING 60"x96" B',
#   1.0,
#   567800.0,
#   'SUNESIS CONSTRUCTION CO',
#   200518),
#  (1761131,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (EXISTING 60"x96" B',
#   1.0,
#   570539.1,
#   'DISTEL CONSTRUCTION INC',
#   200518),
#  (1761132,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (EXISTING 60"x96" B',
#   1.0,
#   572851.55,
#   'AXIS CIVIL CONSTRUCTION LLC',
#   200518),
#  (1761133,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (EXISTING 60"x96" B',
#   1.0,
#   572863.1,
#   'JOHN R JURGENSEN COMPANY',
#   200518),
#  (2349964,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WOO-65-9.38)',
#   1.0,
#   1619196.45,
#   'VERNON NAGEL INC',
#   240226),
#  (147802,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT:  NR)',
#   1.0,
#   125564984.85,
#   'KOKOSING CONSTRUCTION COMPANY INC',
#   120494),
#  (147803,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT:  NR)',
#   1.0,
#   129282739.75,
#   'MOSSER CONSTRUCTION INC/BEAVER EXCAVATING COMPANY - JV',
#   120494),
#  (147804,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT:  NR)',
#   1.0,
#   134795986.16,
#   'RUHLIN/GREAT LAKES 1-75 - JV',
#   120494),
#  (532043,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: 19)',
#   1.0,
#   1819956.76,
#   'BUDS INC',
#   140313),
#  (532044,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: 19)',
#   1.0,
#   1918937.25,
#   'DOUBLE Z CONSTRUCTION COMPANY',
#   140313),
#  (532045,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: 19)',
#   1.0,
#   2000680.01,
#   'SHELLY & SANDS INC',
#   140313),
#  (532046,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: 19)',
#   1.0,
#   2050467.45,
#   'TRUCCO CONSTRUCTION CO INC',
#   140313),
#  (532047,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: 19)',
#   1.0,
#   2094025.27,
#   'EAGLE BRIDGE CO',
#   140313),
#  (532048,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: 19)',
#   1.0,
#   2149243.5,
#   'RIETSCHLIN CONSTRUCTION INC',
#   140313),
#  (532049,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: 19)',
#   1.0,
#   2169530.21,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   140313),
#  (506249,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   561290.6,
#   'R C CONSTRUCTION COMPANY AND SON INC',
#   140238),
#  (506250,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   655693.96,
#   'SHELLY & SANDS INC',
#   140238),
#  (506251,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   658703.4,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   140238),
#  (506252,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   684632.3,
#   'ARMSTRONG STEEL ERECTORS INC',
#   140238),
#  (506253,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   735156.61,
#   'VELOTTA COMPANY',
#   140238),
#  (506254,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   754294.79,
#   'GEORGE J IGEL & CO INC',
#   140238),
#  (513268,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   177736.77,
#   'SIMONSON CONSTRUCTION SERVICES INC',
#   140282),
#  (513269,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   221880.98,
#   'BCC OHIO INC',
#   140282),
#  (513270,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   226186.5,
#   'R W ROBINSON INC',
#   140282),
#  (513271,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   250403.84,
#   'RIETSCHLIN CONSTRUCTION INC',
#   140282),
#  (513272,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   287558.5,
#   'LOCKHART CONCRETE CO',
#   140282),
#  (537617,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   229542.25,
#   'MARK HAYNES CONSTRUCTION INC',
#   140344),
#  (537618,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   343379.68,
#   'SCHALK BROTHERS INC',
#   140344),
#  (571477,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   808904.34,
#   'BOONE COLEMAN CONSTRUCTION INC',
#   140457),
#  (571478,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   885032.8,
#   'SUNESIS CONSTRUCTION CO',
#   140457),
#  (571479,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   890791.55,
#   'GEORGE J IGEL & CO INC',
#   140457),
#  (571480,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   918229.4,
#   'SHELLY & SANDS INC',
#   140457),
#  (571481,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   930100.0,
#   'FOILL INC',
#   140457),
#  (571482,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   938030.92,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   140457),
#  (571483,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   941660.94,
#   'D G M INC',
#   140457),
#  (571484,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   971096.74,
#   'BUDS INC',
#   140457),
#  (571605,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   808904.34,
#   'BOONE COLEMAN CONSTRUCTION INC',
#   140457),
#  (571606,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   885032.8,
#   'SUNESIS CONSTRUCTION CO',
#   140457),
#  (571607,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   890791.55,
#   'GEORGE J IGEL & CO INC',
#   140457),
#  (571608,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   918229.4,
#   'SHELLY & SANDS INC',
#   140457),
#  (571609,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   930100.0,
#   'FOILL INC',
#   140457),
#  (571610,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   938030.92,
#   'COMPLETE GENERAL CONSTRUCTION COMPANY',
#   140457),
#  (571611,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   941660.94,
#   'D G M INC',
#   140457),
#  (571612,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN (WT: NR)',
#   1.0,
#   971096.74,
#   'BUDS INC',
#   140457),
#  (1932560,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN - SLOPE DRAPE REMOV',
#   1.0,
#   836487.8,
#   'OHIO-WEST VIRGINIA EXCAVATING CO',
#   210435),
#  (1932561,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN - SLOPE DRAPE REMOV',
#   1.0,
#   929262.03,
#   'SHELLY & SANDS INC',
#   210435),
#  (1932562,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN - SLOPE DRAPE REMOV',
#   1.0,
#   964060.15,
#   'GEORGE J IGEL & CO INC',
#   210435),
#  (1932563,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN - SLOPE DRAPE REMOV',
#   1.0,
#   1094715.6,
#   'TUCSON INC',
#   210435),
#  (1932564,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN - SLOPE DRAPE REMOV',
#   1.0,
#   1391819.82,
#   'WOLF CREEK CONTRACTING COMPANY LLC',
#   210435),
#  (1932565,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN - SLOPE DRAPE REMOV',
#   1.0,
#   1586506.63,
#   'ECLIPSE CO LLC',
#   210435),
#  (1932566,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN - SLOPE DRAPE REMOV',
#   1.0,
#   1616386.5,
#   'CAST & BAKER CORPORATION',
#   210435),
#  (2068053,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN, BRIDGE NO. ATH-50-',
#   1.0,
#   9520786.98,
#   'ALAN STONE CO INC',
#   220230),
#  (2068054,
#   '202E11001',
#   'STRUCTURE REMOVED, AS PER PLAN, BRIDGE NO. ATH-50-',
#   1.0,
#   9982558.0,
#   'SHELLY & SANDS INC',
#   220230)]
