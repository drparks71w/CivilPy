# %% [markdown]
# # Getting Bridge Data from Various Sources

# %%
sfn = "2102374"

# %% [markdown]
# ## TIMs

# %%
from src.civilpy.state.ohio.DOT.TIMS import TIMSBridge

bridge = TIMSBridge(sfn)  # replace with your SFN
print(bridge)
# Out:
# <TIMSBridge SFN: '2102374'>
#   Route Carried: I-71 NB
#   NLFID:         SDELIR00071**C
#   Location:      DEL County, District 06
#   Location Map:  https://www.google.com/maps?q=40.209175,-82.930444
#
#   -- Characteristics --
#   Lanes On:      2
#   Year Built:    1959
#   Material/Type: Concrete Continuous / Slab (2/01) (Main Span)
#
#   -- Condition Ratings --
#   Sufficiency:   089.9
#   Deck:          6
#   Superstructure:6
#   Substructure:  6
#
# For a full list of available attributes, use help(TIMSBridge).

# %% [markdown]
# ## Assetwise

# %%
from src.civilpy.state.ohio.DOT.AssetWise import AssetWiseBridge

bridge = AssetWiseBridge(sfn)  # replace with your SFN
print(bridge)
# Out:
# Fetching approved inspection reports...
# Requesting all approved inspection reports for asset ID: 78656 at URL: https://ohiodot-it-api.bentley.com/api/InspectionReport/GetAllApproved/78656
# Successfully retrieved all approved inspection reports for asset 78656.
# <AssetWiseBridge SFN: '2102374'>
#   Asset Name:    DEL-00071-0572R_(2102374)
#   Asset ID:      78656
#   Asset Type:    N/A
#   Description:   No Description
#   Location Map:  https://www.google.com/maps?q=40.209181,-82.930439
#   Elements:      Not yet fetched defined
#   Latest Insp:   09/17/2024 (N/A)
#
# For full data, access properties like .elements, .inspections, or .snbi_data

# %%
# bridge.inspections, bridge.elements, bridge.snbi_data

# %%
# Get and display the cover photo from the latest inspection
cover_photo_data = bridge.get_cover_photo()
# Out:
# Searching for the designated cover photo file...
# Requesting cover image for asset ID: 78656 at URL: https://ohiodot-it-api.bentley.com/api/AssetFile/GetAssetCoverImage/78656
# Successfully retrieved cover image for asset 78656.
# Displaying cover photo:

# %% [markdown]
# ## BRR
