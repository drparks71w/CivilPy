# %% [markdown]
# # ODOT Prestressed Box Beam Design

# %% [markdown]
# ## B17-48 - Design Check Verification
#
# Non-Composite Design Data
#
# 20' & 35' Span Considered:
#
# ![image.png](attachment:a8069b9c-863e-4b68-9555-72a83a8b1add.png)

# %% [markdown]
# Draw out framing plans and cross sections,
#
# ![image.png](attachment:a6451195-c4e1-4076-8d3e-9fab7f14b0a0.png)

# %%
f_prime_c = 7000

# Concrete Modulus of Elasticity
E_concrete = 57000 * f_prime_c ** 0.5
E_concrete
# Out:
# 4768962.151244231

# %% [markdown]
# ![image.png](attachment:48dc3d92-468a-4354-a938-ee5d090fd4c4.png)
#
# ![image.png](attachment:bfa8c020-11f6-4eb5-ad0d-3f182c73fca2.png)

# %% [markdown]
# ## Material Values
#
# ![image.png](attachment:b788efba-d35f-4f49-bbb6-3ad2a454efd4.png)
#
# ![image.png](attachment:9c1184e1-f4e2-43ee-b7b8-da4075142a7c.png)
#
# ![image.png](attachment:01722741-fa98-481d-b0dd-ea81e4cb497f.png)

# %% [markdown]
# ## Enter the Section Values into Midas
#
# ![image.png](attachment:555c5703-7b1f-4332-8c33-7d547e6a8c0c.png)
#
# ![image.png](attachment:a599b8da-a3f9-4be7-8a71-dc8e4a38038b.png)
#
# Add the diaphragm section to the girder,
#
# ![image.png](attachment:2daef11b-92af-4d7a-ac01-1c10927f1993.png)

# %% [markdown]
# MIDAS dxf export settings,
#
# ![image.png](attachment:06cab6b3-cb3c-4bee-b877-9be7a3d37323.png)

# %% [markdown]
# Section Properties used,
#
# ![image.png](attachment:8d6e9b13-6e17-42d3-a614-5ab79936a890.png)
#
# finish import of linework,
#
# ![image.png](attachment:13982627-feda-4357-8b78-7431db6734d7.png)

# %% [markdown]
# Define bearing support locations,
#
# beam was referenced from bottom center so that bearing boundary conditions
# and bottom of beam will be coplanar.
#
# Lines were added to the import dxf to allow the user to know which nodes to
# assign as boundary conditions.
#
# ![image.png](attachment:d8882dfb-f44a-4d15-acdc-73c384bdf8a0.png)
#
# Boundary conditions were assigned, DX/DY/DZ, boundaries grouped into two
# locations abutment one and abutment 2.
#
# ![image.png](attachment:3223b1f8-a290-4e45-a0e5-f94ea9f5d813.png)

# %% [markdown]
# # Using Wizard
#
# ![image.png](attachment:ce69e7de-45b8-4ce8-ac80-7a255b0d901e.png)

# %% [markdown]
# ![image.png](attachment:4670a8ff-2f31-4ad9-a2af-9de2083a2ae9.png)

# %%
h1 = 1.25
strand_coords = [0.5, 0.33, 6 @ 0.16666, 0.33333, 6@0.16666, 0.33, 0.5]

# %% [markdown]
# ![image.png](attachment:35b5a9aa-11d5-479d-9f45-17ff1586fa84.png)

# %%
.333, 6@0.16667, .3333, 6@0.16667, .3333

# %%
8/12
# Out:
# 0.6666666666666666
