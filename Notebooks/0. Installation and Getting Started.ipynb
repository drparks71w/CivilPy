# %% [markdown]
# There are three common ways to utilize jupyter notebooks, personally I recommend utilizing Anaconda to create edit and run notebooks. If VCS is required, you can either use the github web interface, Pycharm/VSCode's vcs controls, or use the git command line interface. Each method of running notebooks has benefits and drawbacks.

# %% [markdown]
# # Web/Browser Based Rendering
#
# [Google colab](https://colab.research.google.com/) - requires no installation but does require a google account to run, believe compute resources are limited without a subscription.
#
# [Jupyterlite](https://jupyter.org/try-jupyter/lab/) - WASM based, early in its development but promising, requires no installation and runs directly from the browser. Only allows the use of pure python libraries and can't interact with local files without significant amounts of additional work.

# %% [markdown]
# ## Why Python?
#
# from Google Gemini 2.5 pro, on whether it has more resources on python or
# C# in its training data.
#
# This holds true for most, if not all, programming situations.  Python was
# open source from the get go and being a microsoft product has always left a
# cloud over the head of C# when it comes to open-source developers who are
# most likely to share and trade code.
#
# I definitely have more resources and examples available to me from my training on the **Python libraries**.
#
# This isn't a reflection of the quality or capability of the C# libraries, but rather a direct result of how these languages are used in the geospatial community and the nature of the content available on the public internet.
#
# ***
#
# ## Why Python is More Prevalent 🧑‍💻
#
# The sheer volume of public-facing content for Python in the GIS world is immense. My training data is a snapshot of the public web, and that's where Python dominates for a few key reasons:
#
# * **Community and Open Source:** The Python GIS community is vast and incredibly active. This results in a massive number of public GitHub repositories, Stack Overflow questions, tutorials, university courses, and blog posts sharing `arcpy` and `ArcGIS API for Python` scripts.
# * **Scripting and Data Science:** Python is the go-to language for scripting, automation, and data analysis. GIS analysts, scientists, and researchers frequently share their work as standalone scripts or Jupyter notebooks, creating a huge corpus of examples.
# * **Low Barrier to Sharing:** It's much easier and more common for someone to share a 50-line Python script that solves a specific problem than it is to share an entire C# project.
#
# ***
#
# ## The C# Landscape 🏢
#
# C# is predominantly used for building formal applications and deep integrations, which changes the nature of the available training data:
#
# * **Proprietary Code:** A significant amount of ArcGIS C# development happens within companies to build internal tools or commercial products. This code is typically kept in private repositories and is not part of my public training data.
# * **Structured Development:** C# development is more structured, often involving entire Visual Studio projects and solutions. This is less likely to be shared publicly compared to simple scripts.
# * **Focused Resources:** While Esri provides excellent, high-quality documentation, sample repositories, and dedicated developer forums for C#, the total volume of informal, community-generated examples is smaller than Python's.
#
# In short, the difference in available training data reflects the real-world usage patterns: **Python for widespread scripting and analysis**, and **C# for more focused application development**.

# %% [markdown]
# # Anaconda
#
# Anaconda is my preferred method of running notebooks. They define the standard and most of the features seem to produce the most expected results when run in their software. It should be noted that it is [only free and open source for private and small business use](https://www.anaconda.com/pricing), enterprise groups of over 200 people are required to pay for Anaconda.
#
# [Download and install anaconda](https://docs.anaconda.com/free/anaconda/install/index.html)
#
# Run anaconda prompt.

# %% [markdown]
# ## Create a New Environment
#
# by running `conda create -n civilpy python=3.10`. Replace `3.10` with
# whichever version of python you want to use. Naming the environment
# `civilpy` keeps it matched to the library you install into it next.

# %% [markdown]
# ## Install packages
#
# Activate the environment you just created with the command `conda activate civilpy` then install the required packages with `pip install civilpy`
#
# once it's done running the installation script, run `jupyter lab`
#
# if you want to run or edit the notebooks from the civilpy package, first navigate to wherever you downloaded the Notebooks folder with `cd "C:\Path\to\civilpy\Notebooks"` then run `jupyter lab`.
#
# For all future times when you want to run jupyter you no longer have to create or install the packages, just run;
#
# ```bash
# (base) $ conda activate civilpy
# (civilpy) $ jupyter lab
# ```
#
# to stop the application, just close your browser window and terminal in which it's running.

# %% [markdown]
# ## Readable Text Width (Optional)
#
# By default JupyterLab stretches markdown cells across the full width of
# your screen, which makes long paragraphs hard to read. If you'd like to
# cap the text at a comfortable reading measure (~70 characters, the
# typographic sweet spot for prose) without affecting code cells, civilpy
# ships a small stylesheet you can install locally. The next notebook,
# *1. Intro to Jupyter and Python*, walks through installing it and also
# covers how PDF exports apply the same reading width automatically.

# %% [markdown]
# # Pycharm
#
# [Install Pycharm](https://www.jetbrains.com/pycharm/)
#
# when [first opening](https://www.jetbrains.com/help/pycharm/run-for-the-first-time.html) it will ask you if you want to open an existing project, select `Get from VCS`

# %% [markdown]
# <img src="......">

# %% [markdown]
# enter `https://github.com/drparks71/civilpy.git` (Note: you can download any github project this way by clicking on the `code` button on the project homepage, and pasting the HTTPS option it provides here).
#
# Once the project is done cloning open the terminal,

# %% [markdown]
# <img src="......">

# %% [markdown]
# make sure the path on the left side of your terminal is in the 'project root folder' (should be by default) and run `pip install -r requirements.txt`
#
# you can manage which interpreter pycharm utilizes on the bottom right of the screen by clicking on your environment name and using the available tools there to create or maintain your environments,

# %% [markdown]
# <img src="......">

# %% [markdown]
# Note that jupyter notebooks aren't able to run natively in the free version of pycharm. However, you can open a terminal after configuring the jupyter environment and run `jupyter lab` just like with your conda environment which will open jupyter in the browser for you.
