# %% [markdown]
# # Notes on attempting to utilize LLMs to improve programming speed

# %% [markdown]
# # NotebookLM
#
# ![image.png](attachment:5102f7fc-41ab-4c34-81eb-67a34c2acef5.png)

# %% [markdown]
# I just let it use the 10 sources it found, I also threw in FEA proceedures
# by KJ Bathe
#
# ![image.png](attachment:82d4f643-cfa5-476a-aa6c-49d52761bf5f.png)

# %% [markdown]
# ## Querying the model
#
# ![image.png](attachment:b7522e7c-8e8c-41e0-ac9b-586bc166d2bd.png)
